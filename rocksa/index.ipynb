# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# ffa1ac6e230fc3ea7b8bc5e17b22c11a74a1d848bc0328c0c7e7af452ec1776a

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update sebastian/phpcpd
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Package sebastian/phpcpd is abandoned, you should avoid using it. No replacement was suggested.
# Generating autoload files
# 5 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   andreiio/blade-remix-icon ............................................. DONE
#   blade-ui-kit/blade-icons .............................................. DONE
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/pail .......................................................... DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#
# 104 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.65.0 Persian Successor by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.6
# Running analysis on 1 core sequentially.
# You can enable parallel runner and speed up the analysis! Please see ]8;;https://cs.symfony.com/doc/usage.html\usage docs]8;;\ for more information.
# Loaded config default from "/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    0/118 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  12/118 [▓▓░░░░░░░░░░░░░░░░░░░░░░░░░░]  10%  24/118 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20%  36/118 [▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░]  30%  48/118 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  40%  95/118 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 107/118 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 118/118 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#    1) app/Models/Rock.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# @@ -29,4 +29,3 @@
#      }
#
#  }
# -
#
#       ----------- end diff -----------
#
#    2) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# @@ -8,7 +8,6 @@
#  // use Database\Seeders\InsertTestSeeder;
#  use Database\Seeders\InsertTestSeeder;
#
# -
#  class DatabaseSeeder extends Seeder
#  {
#      /**
#
#       ----------- end diff -----------
#
#    3) database/seeders/InsertTestSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# @@ -6,7 +6,6 @@
#  use Illuminate\Support\Facades\DB;
#  use Illuminate\Support\Facades\Hash;
#
# -
#  class InsertTestSeeder extends Seeder
#  {
#      /**
# @@ -63,4 +62,3 @@
#          ]);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    4) database/migrations/create_orders_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/create_orders_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/create_orders_table.php
# @@ -5,7 +5,6 @@
#  use Illuminate\Support\Facades\Schema;
#
#  return new class () extends Migration {
# -
#      /**
#       * Run the migrations.
#       *
# @@ -36,4 +35,3 @@
#          Schema::dropIfExists('orders');
#      }
#  };
# -
#
#       ----------- end diff -----------
#
#    5) database/migrations/2025_01_14_151420_add_user_id_to_rocks_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_14_151420_add_user_id_to_rocks_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_14_151420_add_user_id_to_rocks_table.php
# @@ -4,8 +4,7 @@
#  use Illuminate\Database\Schema\Blueprint;
#  use Illuminate\Support\Facades\Schema;
#
# -return new class extends Migration
# -{
# +return new class () extends Migration {
#      /**
#       * Run the migrations.
#       */
#
#       ----------- end diff -----------
#
#
# Found 5 of 118 files that can be fixed in 1.474 seconds, 20.00 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#    0/109 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0% 109/109 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Http/Requests/StoreOrderRequest.php
#  ------ --------------------------------------------------------------------------------------
#   21     PHPDoc tag @return has invalid value (array<string,
#          ValidationRule|array<mixed|string>): Unexpected token "*/", expected
#          '>' at offset 139 on line 5
#          🪪  phpDoc.parseError
#   23     Method App\Http\Requests\StoreOrderRequest::rules() return type has
#          no value type specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#  ------ --------------------------------------------------------------------------------------
#
#  ------ -------------------------------------------------------------------
#   Line   app/Models/Order.php
#  ------ -------------------------------------------------------------------
#   21     Method App\Models\Order::create() has no return type specified.
#          🪪  missingType.return
#   37     Method App\Models\Order::user() has no return type specified.
#          🪪  missingType.return
#   42     Method App\Models\Order::products() has no return type specified.
#          🪪  missingType.return
#  ------ -------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------
#   Line   resources/views/orders/create.blade.php
#  ------ --------------------------------------------------------------------
#   1      File ends with a trailing whitespace. This may cause problems when
#          running the code in the web browser. Remove the closing ?> mark or
#          remove the whitespace.
#          🪪  whitespace.fileEnd
#  ------ --------------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   tests/Unit/ExampleTest.php
#  ------ -----------------------------------------------------------------------
#   19     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   19     No error with identifier method.alreadyNarrowedType is reported on
#          line 19.
#   24     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   24     No error with identifier method.alreadyNarrowedType is reported on
#          line 24.
#   29     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   29     No error with identifier method.alreadyNarrowedType is reported on
#          line 29.
#   33     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   33     No error with identifier method.alreadyNarrowedType is reported on
#          line 33.
#   37     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   37     No error with identifier method.alreadyNarrowedType is reported on
#          line 37.
#   41     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   41     No error with identifier method.alreadyNarrowedType is reported on
#          line 41.
#   46     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   46     No error with identifier method.alreadyNarrowedType is reported on
#          line 46.
#   51     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   51     No error with identifier method.alreadyNarrowedType is reported on
#          line 51.
#   56     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   56     No error with identifier method.alreadyNarrowedType is reported on
#          line 56.
#   61     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   61     No error with identifier method.alreadyNarrowedType is reported on
#          line 61.
#   66     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   66     No error with identifier method.alreadyNarrowedType is reported on
#          line 66.
#  ------ -----------------------------------------------------------------------
#
#
#  [ERROR] Found 28 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# No clones found.
#
# Time: 00:00.024, Memory: 2.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done

# %%
! php artisan migrate:fresh
# Out:
#    INFO  Preparing database.
#
#   Creating migration table ...................................... 40.37ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ......................... 191.82ms DONE
#   0001_01_01_000001_create_cache_table .......................... 59.81ms DONE
#   0001_01_01_000002_create_jobs_table .......................... 148.21ms DONE
#   2024_11_29_145411_create_comments_table ....................... 30.36ms DONE
#   2024_12_07_094911_create_books_table .......................... 34.82ms DONE
#   2025_01_14_151419_create_rocks_table .......................... 50.35ms DONE
#   2025_01_14_151420_add_user_id_to_rocks_table ................. 174.49ms DONE
#   create_orders_table ........................................... 55.40ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 222 ms DONE
#
#   Database\Seeders\InsertTestSeeder .................................. RUNNING
#   Database\Seeders\InsertTestSeeder .............................. 226 ms DONE

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇
# up to date, audited 171 packages in 2s
# ⠇
# ⠇40 packages are looking for funding
# ⠇  run `npm fund` for details
# ⠇
# found 0 vulnerabilities
# ⠇

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.4.11 building for production...
# transforming (1) resources/js/app.jstransforming (2) node_modules/alpinejs/dist/module.esm.jstransforming (4) resources/css/app.csstransforming (36) node_modules/axios/lib/helpers/AxiosURLSearchParams.js[2✓ 54 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-Dn1F5TRg.css  38.72 kB │ gzip:  7.08 kB
# public/build/assets/app-5Xb-APZy.js   79.37 kB │ gzip: 29.63 kB
# ✓ built in 2.44s
# ⠙

# %%
! php artisan test
# Out:
#    FAIL  Tests\Unit\ExampleTest
#   ✓ that true is true
#   ⨯ add to cart                                                          0.01s
#   ⨯ remove from cart
#   ⨯ edit name
#   ⨯ edit email
#   ⨯ edit phone number
#   ⨯ edit password
#   ⨯ calculate cost
#   ⨯ add rock
#   ⨯ remove rock
#   ⨯ add filter
#   ⨯ remove filter
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                         2.11s
#   ✓ users can authenticate using the login screen                        0.50s
#   ✓ users can not authenticate with invalid password                     0.62s
#   ✓ users can logout                                                     0.38s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.44s
#   ✓ email can be verified                                                0.37s
#   ✓ email is not verified with invalid hash                              0.32s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.34s
#   ✓ password can be confirmed                                            0.28s
#   ✓ password is not confirmed with invalid password                      0.47s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.26s
#   ✓ reset password link can be requested                                 0.29s
#   ✓ reset password screen can be rendered                                0.28s
#   ✓ password can be reset with valid token                               0.25s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.26s
#   ✓ correct password must be provided to update password                 0.31s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.28s
#   ✓ new users can register                                               0.27s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.24s
#
#    PASS  Tests\Feature\ProfileTest
#   ✓ profile page is displayed                                            0.27s
#   ✓ profile information can be updated                                   0.28s
#   ✓ email verification status is unchanged when the email address is un… 0.27s
#   ✓ user can delete their account                                        0.29s
#   ✓ correct password must be provided to delete account                  0.27s
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add to cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:19
#      15▕     }
#      16▕     // Add to cart
#      17▕     public function test_add_to_cart(): void
#      18▕     {
#   ➜  19▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#
#   1   tests/Unit/ExampleTest.php:19
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove from cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:24
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#   ➜  24▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#
#   1   tests/Unit/ExampleTest.php:24
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit name
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:29
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#   ➜  29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:29
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit email
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:33
#      29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#   ➜  33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:33
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit phone number
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:37
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#   ➜  37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#      41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:37
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit password
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:41
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#   ➜  41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#
#   1   tests/Unit/ExampleTest.php:41
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > calculate cost
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:46
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#   ➜  46▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#
#   1   tests/Unit/ExampleTest.php:46
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:51
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#   ➜  51▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#
#   1   tests/Unit/ExampleTest.php:51
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:56
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#   ➜  56▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#
#   1   tests/Unit/ExampleTest.php:56
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:61
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#   ➜  61▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#
#   1   tests/Unit/ExampleTest.php:61
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:66
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#   ➜  66▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      67▕     }
#      68▕ }
#      69▕
#
#   1   tests/Unit/ExampleTest.php:66
#
#
#   Tests:    11 failed, 25 passed (74 assertions)
#   Duration: 9.89s

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.24.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done
# Out:
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 18:10:07.483 INFO [LoggingOptions.configureLogEncoding] - Using the system default encoding
# 18:10:07.494 INFO [OpenTelemetryTracer.createTracer] - Using OpenTelemetry for tracing
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 18:10:09.056 INFO [NodeOptions.getSessionFactories] - Detected 4 available processors
# 18:10:09.059 INFO [NodeOptions.discoverDrivers] - Looking for existing drivers on the PATH.
# 18:10:09.059 INFO [NodeOptions.discoverDrivers] - Add '--selenium-manager true' to the startup command to setup drivers automatically.
# 18:10:09.499 WARN [SeleniumManager.lambda$runCommand$1] - Exception managing chrome: Unable to discover proper chromedriver version in offline mode
# 18:10:09.516 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper msedgedriver version in offline mode
# 18:10:09.532 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper geckodriver version in offline mode
# 18:10:09.561 INFO [NodeOptions.report] - Adding Edge for {"browserName": "MicrosoftEdge","platformName": "linux"} 4 times
# 18:10:09.562 INFO [NodeOptions.report] - Adding Firefox for {"browserName": "firefox","platformName": "linux"} 4 times
# 18:10:09.564 INFO [NodeOptions.report] - Adding Chrome for {"browserName": "chrome","platformName": "linux"} 4 times
# 18:10:09.661 INFO [Node.<init>] - Binding additional locator mechanisms: relative
# 18:10:09.704 INFO [GridModel.setAvailability] - Switching Node c4e35e22-3466-440b-a671-2dda674f83b9 (uri: http://172.17.0.1:4444) from DOWN to UP
# 18:10:09.705 INFO [LocalDistributor.add] - Added node c4e35e22-3466-440b-a671-2dda674f83b9 at http://172.17.0.1:4444. Health check every 120s
# 18:10:09.952 INFO [Standalone.execute] - Started Selenium Standalone 4.24.0 (revision 748ffc9bc3): http://172.17.0.1:4444

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done
# Out:
#   2025-01-14 18:10:10 .............................................. ~ 0.95ms
#   2025-01-14 18:10:21 /login ........................................... ~ 1s
#   2025-01-14 18:10:22 /static/logo.svg ............................. ~ 0.28ms
#   2025-01-14 18:10:22 /static/gradient.jpg ......................... ~ 0.77ms
#   2025-01-14 18:10:22 /favicon.ico ................................. ~ 0.25ms
#   2025-01-14 18:10:32 /login ..................................... ~ 533.23ms
#   2025-01-14 18:10:33 /login ..................................... ~ 507.07ms
#   2025-01-14 18:10:33 /static/logo.svg ............................. ~ 1.20ms
#   2025-01-14 18:10:33 /static/gradient.jpg ......................... ~ 0.93ms
#   2025-01-14 18:10:33 /favicon.ico ................................. ~ 0.82ms
#   2025-01-14 18:11:14 /login ..................................... ~ 502.79ms
#   2025-01-14 18:11:14 /static/logo.svg ............................. ~ 0.56ms
#   2025-01-14 18:11:14 /static/gradient.jpg ......................... ~ 0.24ms
#   2025-01-14 18:11:15 /favicon.ico ................................ ~ 13.93ms
#   2025-01-14 18:11:22 /login ........................................... ~ 1s
#   2025-01-14 18:11:23 /login ....................................... ~ 8.63ms
#   2025-01-14 18:11:24 /static/logo.svg ............................. ~ 0.29ms
#   2025-01-14 18:11:24 /static/gradient.jpg ....................... ~ 510.22ms
#   2025-01-14 18:11:24 /favicon.ico ................................. ~ 0.62ms
#   2025-01-14 18:33:49 /login ..................................... ~ 501.13ms
#   2025-01-14 18:33:49 /static/logo.svg ............................. ~ 0.34ms
#   2025-01-14 18:33:49 /static/gradient.jpg ......................... ~ 0.23ms
#   2025-01-14 18:33:49 /favicon.ico ................................. ~ 0.18ms
#   2025-01-14 18:33:57 /login ........................................... ~ 1s
#   2025-01-14 18:33:58 /dashboard ................................. ~ 509.67ms
#   2025-01-14 18:33:58 /static/logo.svg ............................. ~ 0.26ms
#   2025-01-14 18:33:58 /static/gradient.jpg ......................... ~ 0.28ms
#   2025-01-14 18:33:59 /favicon.ico ................................. ~ 0.20ms
#   2025-01-14 18:34:33 /rocks ..................................... ~ 501.20ms
#   2025-01-14 18:34:34 /static/logo.svg ............................. ~ 1.19ms
#   2025-01-14 18:34:34 /static/gradient.jpg ......................... ~ 0.50ms
#   2025-01-14 18:34:34 /favicon.ico ................................. ~ 0.33ms
#   2025-01-14 18:39:28 /rocks/1 ................................... ~ 501.54ms
#   2025-01-14 18:39:29 /static/logo.svg ............................. ~ 0.30ms
#   2025-01-14 18:39:29 /static/gradient.jpg ......................... ~ 0.27ms
#   2025-01-14 18:39:29 /favicon.ico ................................. ~ 0.35ms
#   2025-01-14 19:52:25 /rocks/1 ................................... ~ 500.80ms
#   2025-01-14 19:52:25 /login ....................................... ~ 0.21ms
#   2025-01-14 19:52:26 /static/logo.svg ............................. ~ 0.17ms
#   2025-01-14 19:52:26 /static/gradient.jpg ......................... ~ 0.23ms
#   2025-01-14 19:52:26 /favicon.ico ................................. ~ 0.17ms
#   2025-01-14 19:52:33 /login ..................................... ~ 500.97ms
#   2025-01-14 19:52:33 /rocks/1 ................................... ~ 503.68ms
#   2025-01-14 19:52:33 /static/logo.svg ............................. ~ 0.44ms
#   2025-01-14 19:52:33 /static/gradient.jpg ......................... ~ 0.55ms
#   2025-01-14 19:52:34 /favicon.ico ................................. ~ 0.67ms
#   2025-01-14 19:52:38 /rocks ..................................... ~ 501.27ms
#   2025-01-14 19:52:39 /static/logo.svg ............................. ~ 0.14ms
#   2025-01-14 19:52:39 /static/gradient.jpg ......................... ~ 0.15ms
#   2025-01-14 19:52:39 /favicon.ico ................................. ~ 0.50ms
#   2025-01-14 19:52:56 /rocks/1 ................................... ~ 504.61ms
#   2025-01-14 19:52:56 /static/logo.svg ............................. ~ 0.46ms
#   2025-01-14 19:52:56 /static/gradient.jpg ......................... ~ 0.22ms
#   2025-01-14 19:52:56 /favicon.ico ................................. ~ 0.64ms
#   2025-01-14 19:54:30 /rocks/1 ................................... ~ 501.26ms
#   2025-01-14 19:54:30 /static/logo.svg ............................. ~ 0.21ms
#   2025-01-14 19:54:30 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-14 19:54:30 /favicon.ico ................................. ~ 0.12ms
#   2025-01-14 19:54:37 /login ..................................... ~ 502.44ms
#   2025-01-14 19:54:37 /dashboard ................................... ~ 3.52ms
#   2025-01-14 19:54:37 /static/logo.svg ............................. ~ 0.26ms
#   2025-01-14 19:54:37 /static/gradient.jpg ......................... ~ 0.18ms
#   2025-01-14 19:54:38 /favicon.ico ................................. ~ 0.25ms
#   2025-01-14 19:54:41 /logout .................................... ~ 524.16ms
#   2025-01-14 19:54:41 / .......................................... ~ 505.88ms
#   2025-01-14 19:54:42 /static/logo.svg ............................. ~ 2.48ms
#   2025-01-14 19:54:42 /static/gradient.jpg ......................... ~ 1.11ms
#   2025-01-14 19:54:42 /favicon.ico ................................. ~ 1.22ms
#   2025-01-14 19:54:45 /login ..................................... ~ 501.20ms
#   2025-01-14 19:54:46 /static/logo.svg ............................. ~ 0.15ms
#   2025-01-14 19:54:46 /static/gradient.jpg ......................... ~ 0.14ms
#   2025-01-14 19:54:47 /favicon.ico ................................. ~ 0.47ms
#   2025-01-14 19:54:52 /login ..................................... ~ 501.49ms
#   2025-01-14 19:54:53 /dashboard ................................... ~ 3.11ms
#   2025-01-14 19:54:53 /static/logo.svg ............................. ~ 0.21ms
#   2025-01-14 19:54:53 /static/gradient.jpg ......................... ~ 2.01ms
#   2025-01-14 19:54:54 /favicon.ico ................................. ~ 0.50ms
#   2025-01-14 19:54:56 /rocks ....................................... ~ 0.27ms
#   2025-01-14 19:54:56 /static/logo.svg ............................. ~ 0.37ms
#   2025-01-14 19:54:56 /static/gradient.jpg ......................... ~ 0.26ms
#   2025-01-14 19:54:57 /favicon.ico ................................. ~ 0.29ms

# %%
! vendor/bin/codecept run
# Out:
#   2025-01-14 17:02:14 .............................................. ~ 0.42ms
# Codeception PHP Testing Framework v5.1.2 https://stand-with-ukraine.pp.ua
#
# TestsCodeception.Acceptance Tests (4) ------------------------------------------
# - Test00_HomepageCest: See Laravel links on homepage17:02:16.116 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 17:02:17.128 INFO [LocalNode.newSession] - Session created by the Node. Id: b7648c84d54201e6db125026e8f2fec7, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:36147}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 17:02:17.142 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: b7648c84d54201e6db125026e8f2fec7
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:36147}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 17:02:18.797 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "22e7f757943821c67926d954ebddd4d0","eventTime": 1736870538784428110,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002ftitle"}}
#
# 17:02:18.844 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "e7b006c59ff75d29d8b12678f7ce5fc3","eventTime": 1736870538843153107,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fscreenshot"}}
#
# 17:02:18.866 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "6a919283de715ba2b3740a86ca1895ef","eventTime": 1736870538865836247,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fsource"}}
#
# 17:02:18.886 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "885209b15e8b489c62c522c71c088c01","eventTime": 1736870538886003120,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fcookie"}}
#
# E Test00_HomepageCest: See Laravel links on homepage(0.79s)
# - Test01_CommentsCest: See comments from DB displayed on page  2025-01-14 17:02:18 / .......................................... ~ 500.58ms
#   2025-01-14 17:02:18 /build/assets/app-5Xb-APZy.js ................ ~ 0.23ms
#   2025-01-14 17:02:18 /static/logo.svg ............................. ~ 1.19ms
#   2025-01-14 17:02:18 /build/assets/app-Dn1F5TRg.css ............... ~ 2.72ms
#   2025-01-14 17:02:18 /static/gradient.jpg ......................... ~ 0.12ms
# 17:02:19.680 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "affcd6f82487253d5044e7b523f2f21a","eventTime": 1736870539679386718,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "43","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002furl"}}
#
# 17:02:19.703 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "f79d8ce2ff9ddfe01dfcc569a9c93482","eventTime": 1736870539702610083,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fscreenshot"}}
#
# 17:02:19.726 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "3d286393203311f0cdcf2505628b5fb7","eventTime": 1736870539725107230,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fsource"}}
#
# E Test01_CommentsCest: See comments from DB displayed on page(0.03s)
# 17:02:19.756 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "42663a3c6beabe5dca1fbe8b6b054480","eventTime": 1736870539755836965,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fcookie"}}
#
# - Test02_LoginCest: Login with existing user17:02:20.510 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "092cb096669796fbbf8111372629680e","eventTime": 1736870540509275578,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "44","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002furl"}}
#
# 17:02:20.529 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "2cac1b663ca32d9f91514638f8b024c6","eventTime": 1736870540528472617,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fscreenshot"}}
#
# 17:02:20.549 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "5ebfa23e15c1468d16334a4993ee5101","eventTime": 1736870540548604484,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fsource"}}
#
# 17:02:20.569 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "2a7967fde9aa2b225d6de466fe4d0afd","eventTime": 1736870540567990644,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fcookie"}}
#
# E Test02_LoginCest: Login with existing user(0.02s)
# - Test03_BooksCest: Have books page17:02:21.352 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "0fb94df6ad00fb0efa10ced79a4890a1","eventTime": 1736870541351415933,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "POST","http.request_content_length": "40","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002furl"}}
#
# 17:02:21.371 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "5f99727e8301216b20aa291442054f34","eventTime": 1736870541369665058,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fscreenshot"}}
#
# 17:02:21.393 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "a2e708c236427221355e66492f977ed0","eventTime": 1736870541392667051,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "GET","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fsource"}}
#
# E Test03_BooksCest: Have books page(0.02s)
# 17:02:21.417 WARN [SeleniumSpanExporter$1.lambda$export$3] - {"traceId": "ba707db897bcc277437b66dd37666c33","eventTime": 1736870541416385017,"eventName": "HTTP request execution complete","attributes": {"http.flavor": 1,"http.handler_class": "org.openqa.selenium.remote.http.Route$PredicatedRoute","http.host": "127.0.0.1:4444","http.method": "DELETE","http.request_content_length": "0","http.scheme": "HTTP","http.status_code": 404,"http.target": "\u002fsession\u002fb7648c84d54201e6db125026e8f2fec7\u002fcookie"}}
#
# 17:02:21.487 INFO [LocalSessionMap.remove] - Deleted session from local Session Map, Id: b7648c84d54201e6db125026e8f2fec7
# 17:02:21.488 INFO [GridModel.release] - Releasing slot for session id b7648c84d54201e6db125026e8f2fec7
# 17:02:21.489 INFO [SessionSlot.stop] - Stopping session b7648c84d54201e6db125026e8f2fec7
# --------------------------------------------------------------------------------
# Time: 00:06.376, Memory: 14.00 MB
#
# There were 4 errors:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.69)
#
#
# Scenario Steps:
#
#  2. $I->seeInTitle("Laravel") at tests_codeception/Acceptance/Test00_HomepageCest.php:15
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# #1  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:292
# #5  Codeception\Module\WebDriver->seeInTitle
# #6  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:3440
# #7  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test00_HomepageCest.php:15
# #8  TestsCodeception\Acceptance\Test00_HomepageCest->test
# #9  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.html
# 2) Test01_CommentsCest: See comments from DB displayed on page
#  Test  tests_codeception/Acceptance/Test01_CommentsCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.69)
#
#
# Scenario Steps:
#
#  3. $I->amOnPage("/comments") at tests_codeception/Acceptance/Test01_CommentsCest.php:22
#  2. $I->haveInDatabase("comments",{"title":"Title 1325905201","text":"Some ...}) at tests_codeception/Acceptance/Test01_CommentsCest.php:20
#  1. $I->seeNumRecords(0,"comments") at tests_codeception/Acceptance/Test01_CommentsCest.php:13
#
# #1  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test01_CommentsCest.php:22
# #8  TestsCodeception\Acceptance\Test01_CommentsCest->test
# #9  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test01.CommentsCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test01.CommentsCest.test.fail.html
# 3) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.69)
#
#
# Scenario Steps:
#
#  1. $I->amOnPage("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:13
#
# #1  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test02_LoginCest.php:13
# #8  TestsCodeception\Acceptance\Test02_LoginCest->test
# #9  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.html
# 4) Test03_BooksCest: Have books page
#  Test  tests_codeception/Acceptance/Test03_BooksCest.php:test
#
#   [Facebook\WebDriver\Exception\NoSuchWindowException] no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=130.0.6723.69)
#
#
# Scenario Steps:
#
#  1. $I->amOnPage("/books") at tests_codeception/Acceptance/Test03_BooksCest.php:13
#
# #1  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Exception/WebDriverException.php:124
# #2  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/HttpCommandExecutor.php:359
# #3  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:601
# #4  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/php-webdriver/webdriver/lib/Remote/RemoteWebDriver.php:260
# #5  Codeception\Module\WebDriver->amOnPage
# #6  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Support/_generated/AcceptanceTesterActions.php:585
# #7  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test03_BooksCest.php:13
# #8  TestsCodeception\Acceptance\Test03_BooksCest->test
# #9  /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/bin/codecept:119
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.html
#
# ERRORS!
# Tests: 4, Assertions: 1, Errors: 4.

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# Warning: Not allowed as a service: java.awt.Window.CustomTitleBarPeer
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# Warning: Service not supported: com.jetbrains.WindowDecorations
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:02:25,963 [   2954]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDefault.xml
# 2025-01-14 17:02:25,998 [   2989]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDarcula.xml
# 2025-01-14 17:02:26,105 [   3096] SEVERE - #c.i.c.i.ConversionContextImpl - Unexpected End-of-input in prolog
#  at [row,col {unknown-source}]: [1,1]
# com.fasterxml.aalto.WFCException: Unexpected End-of-input in prolog
#  at [row,col {unknown-source}]: [1,1]
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.throwWfe(StreamReaderImpl.java:1777)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.throwUnexpectedEOI(StreamReaderImpl.java:1796)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.handlePrologEoi(StreamReaderImpl.java:1756)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.next(StreamReaderImpl.java:810)
# 	at com.intellij.util.xml.dom.XmlDomReader.nextTag(xmlDom.kt:175)
# 	at com.intellij.util.xml.dom.XmlDomReader.readAndClose(xmlDom.kt:60)
# 	at com.intellij.util.xml.dom.XmlDomReader.readXmlAsModel(xmlDom.kt:51)
# 	at com.intellij.conversion.impl.ConversionContextImplKt.loadCachedConversionResult(ConversionContextImpl.kt:464)
# 	at com.intellij.conversion.impl.ConversionContextImplKt.access$loadCachedConversionResult(ConversionContextImpl.kt:1)
# 	at com.intellij.conversion.impl.ConversionContextImpl.loadConversionResult(ConversionContextImpl.kt:89)
# 	at com.intellij.impl.ConversionServiceImplKt.isConversionNeeded(ConversionServiceImpl.kt:184)
# 	at com.intellij.impl.ConversionServiceImplKt.access$isConversionNeeded(ConversionServiceImpl.kt:1)
# 	at com.intellij.impl.ConversionServiceImpl.convert(ConversionServiceImpl.kt:81)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$prepareProject$2.invokeSuspend(ProjectManagerImpl.kt:875)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$prepareProject$2.invoke(ProjectManagerImpl.kt)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$prepareProject$2.invoke(ProjectManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span(tracer.kt:56)
# 	at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span$default(tracer.kt:49)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl.prepareProject(ProjectManagerImpl.kt:874)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl.access$prepareProject(ProjectManagerImpl.kt:101)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$doOpenAsync$2.invokeSuspend(ProjectManagerImpl.kt:644)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$doOpenAsync$2.invoke(ProjectManagerImpl.kt)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$doOpenAsync$2.invoke(ProjectManagerImpl.kt)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2.invokeSuspend(ProjectFrameAllocator.kt:237)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2.invoke(ProjectFrameAllocator.kt)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2.invoke(ProjectFrameAllocator.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator.doRun(ProjectFrameAllocator.kt:176)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator.access$doRun(ProjectFrameAllocator.kt:151)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2.invokeSuspend(ProjectFrameAllocator.kt:165)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2.invoke(ProjectFrameAllocator.kt)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2.invoke(ProjectFrameAllocator.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.project.impl.ProjectUiFrameAllocator.run(ProjectFrameAllocator.kt:158)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl.doOpenAsync(ProjectManagerImpl.kt:637)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl.access$doOpenAsync(ProjectManagerImpl.kt:101)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$openProjectAsync$4.invokeSuspend(ProjectManagerImpl.kt:620)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$openProjectAsync$4.invoke(ProjectManagerImpl.kt)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl$openProjectAsync$4.invoke(ProjectManagerImpl.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span(tracer.kt:56)
# 	at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span$default(tracer.kt:49)
# 	at com.intellij.openapi.project.impl.ProjectManagerImpl.openProjectAsync(ProjectManagerImpl.kt:619)
# 	at com.intellij.ide.impl.ProjectUtil.openOrImportAsync(ProjectUtil.kt:179)
# 	at com.intellij.ide.CommandLineProcessor.doOpenFileOrProject(CommandLineProcessor.kt:76)
# 	at com.intellij.ide.CommandLineProcessor.openFileOrProject(CommandLineProcessor.kt:495)
# 	at com.intellij.ide.CommandLineProcessor.processOpenFile(CommandLineProcessor.kt:362)
# 	at com.intellij.ide.CommandLineProcessor.access$processOpenFile(CommandLineProcessor.kt:55)
# 	at com.intellij.ide.CommandLineProcessor$processOpenFile$1.invokeSuspend(CommandLineProcessor.kt)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:02:26,123 [   3114] SEVERE - #c.i.c.i.ConversionContextImpl - PhpStorm 2024.2.4  Build #PS-242.23726.107
# 2025-01-14 17:02:26,124 [   3115] SEVERE - #c.i.c.i.ConversionContextImpl - JDK: 21.0.4; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2025-01-14 17:02:26,124 [   3115] SEVERE - #c.i.c.i.ConversionContextImpl - OS: Linux
# 2025-01-14 17:02:26,134 [   3125] SEVERE - #c.i.c.i.ConversionContextImpl - Last Action:
# 2025-01-14 17:02:29,817 [   6808]   WARN - #c.i.s.ComponentManagerImpl - `preload=NOT_HEADLESS` must be used only for core services (service=com.jetbrains.rdserver.toolWindow.BackendServerToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,818 [   6809]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendUserManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,818 [   6809]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.ports.CwmPortForwardingToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,818 [   6809]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendCWMUserFocusHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,819 [   6810]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeManagerService, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,819 [   6810]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendProjectViewSync, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,819 [   6810]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeEditorsHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,819 [   6810]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeDebuggerHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:29,821 [   6812]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeLookupSynchronizer, plugin=com.jetbrains.codeWithMe)
# 2025-01-14 17:02:35,837 [  12828]   WARN - #c.i.u.x.Binding - No accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-14 17:02:36,714 [  13705]   WARN - #c.i.o.a.Application - issue detected: ide.script.launcher.used
# 2025-01-14 17:02:36,770 [  13761]   WARN - #c.i.f.f.h.FileHistoryPersistence - Cannot deserialize file sequence ngrams
# java.io.EOFException
# 	at java.base/java.io.ObjectInputStream$PeekInputStream.readFully(ObjectInputStream.java:2933)
# 	at java.base/java.io.ObjectInputStream$BlockDataInputStream.readShort(ObjectInputStream.java:3428)
# 	at java.base/java.io.ObjectInputStream.readStreamHeader(ObjectInputStream.java:985)
# 	at java.base/java.io.ObjectInputStream.<init>(ObjectInputStream.java:416)
# 	at com.intellij.internal.ml.ngram.NGramModelSerializer.loadNGrams(NGramModelSerializer.kt:36)
# 	at com.intellij.filePrediction.features.history.FileHistoryPersistence.loadNGrams(FileHistoryPersistence.kt:60)
# 	at com.intellij.filePrediction.features.history.FileHistoryManagerWrapper$lazyManager$1.invoke(FileHistoryManagerWrapper.kt:27)
# 	at com.intellij.filePrediction.features.history.FileHistoryManagerWrapper$lazyManager$1.invoke(FileHistoryManagerWrapper.kt:27)
# 	at kotlin.SynchronizedLazyImpl.getValue(LazyJVM.kt:74)
# 	at com.intellij.filePrediction.features.history.FileHistoryManagerWrapper.onFileOpened$lambda$2$lambda$1(FileHistoryManagerWrapper.kt:49)
# 	at com.intellij.openapi.progress.util.BackgroundTaskUtil.lambda$runUnderDisposeAwareIndicator$15(BackgroundTaskUtil.java:371)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$runProcess$2(CoreProgressManager.java:217)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.lambda$executeProcessUnderProgress$13(CoreProgressManager.java:660)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.registerIndicatorAndRun(CoreProgressManager.java:735)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computeUnderProgress(CoreProgressManager.java:691)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.executeProcessUnderProgress(CoreProgressManager.java:659)
# 	at com.intellij.openapi.progress.impl.ProgressManagerImpl.executeProcessUnderProgress(ProgressManagerImpl.java:79)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.runProcess(CoreProgressManager.java:202)
# 	at com.intellij.openapi.progress.util.BackgroundTaskUtil.runUnderDisposeAwareIndicator(BackgroundTaskUtil.java:366)
# 	at com.intellij.openapi.progress.util.BackgroundTaskUtil.runUnderDisposeAwareIndicator(BackgroundTaskUtil.java:349)
# 	at com.intellij.filePrediction.features.history.FileHistoryManagerWrapper.onFileOpened$lambda$2(FileHistoryManagerWrapper.kt:48)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at com.intellij.util.concurrency.ContextCallable.call(ContextCallable.java:32)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:317)
# 	at com.intellij.util.concurrency.ContextRunnable.run(ContextRunnable.java:27)
# 	at com.intellij.util.concurrency.BoundedTaskExecutor.doRun(BoundedTaskExecutor.java:249)
# 	at com.intellij.util.concurrency.BoundedTaskExecutor.access$200(BoundedTaskExecutor.java:30)
# 	at com.intellij.util.concurrency.BoundedTaskExecutor$1.executeFirstTaskAndHelpQueue(BoundedTaskExecutor.java:227)
# 	at com.intellij.util.ConcurrencyUtil.runUnderThreadName(ConcurrencyUtil.java:218)
# 	at com.intellij.util.concurrency.BoundedTaskExecutor$1.run(BoundedTaskExecutor.java:212)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:735)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:732)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:400)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1.run(Executors.java:732)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# 2025-01-14 17:02:36,917 [  13908]   WARN - #c.i.o.f.i.EditorComposite - Cannot focus editor (splitters=com.intellij.openapi.fileEditor.impl.EditorsSplitters[,442,0,1396x554,invalid,layout=java.awt.BorderLayout,alignmentX=0.0,alignmentY=0.0,border=,flags=9,maximumSize=,minimumSize=,preferredSize=], composite=EditorComposite(identityHashCode=1463559710, file=file:///home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_14_151419_create_rocks_table.php), currentComposite=EditorComposite(identityHashCode=1758661765, file=file:///home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/insert_example_user_seeder.php), reason=selection changed)
# 2025-01-14 17:02:37,181 [  14172]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./syntaxes/asp-vb-net.tmLanguage.json` in bundle `/opt/PhpStorm-242.23726.107/plugins/textmate/lib/bundles/vb`
# [JetBrains Runtime] Detected slow X11, switched off alpha compositing of images. Control with -Dremote.x11.workaround={true|false|auto}.
# 2025-01-14 17:02:38,276 [  15267]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./syntaxes/asp-vb-net.tmLanguage.json` in bundle `/opt/PhpStorm-242.23726.107/plugins/textmate/lib/bundles/vb`
# 2025-01-14 17:02:39,725 [  16716]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./syntaxes/asp-vb-net.tmLanguage.json` in bundle `/opt/PhpStorm-242.23726.107/plugins/textmate/lib/bundles/vb`
# 2025-01-14 17:02:41,530 [  18521]   WARN - #c.j.p.PhpIndex - Completing type '#π(#M#C\Illuminate\Support\Facades\DB.table)("users")' took 587ms, visited:[#π(#M#C\Illuminate\Support\Facades\DB.table)("users")]
# 2025-01-14 17:02:44,830 [  21821]   WARN - org.eclipse.lsp4j.jsonrpc.services.GenericEndpoint - Unsupported notification method: @/tailwindCSS/projectInitialized
# 2025-01-14 17:02:44,847 [  21838]   WARN - org.eclipse.lsp4j.jsonrpc.services.GenericEndpoint - Unsupported notification method: @/tailwindCSS/projectInitialized
# 2025-01-14 17:02:50,004 [  26995]   WARN - #c.j.p.PhpIndex - Completing type '#C\Illuminate\Support\Facades\DB' took 1521ms, visited:[#C\Illuminate\Support\Facades\DB]
# 2025-01-14 17:02:50,026 [  27017]   WARN - #c.j.p.PhpIndex - Completing type '#π(#M#C\Illuminate\Support\Facades\DB.table)("users")' took 1544ms, visited:[#π(#M#C\Illuminate\Support\Facades\DB.table)("users")]
# Warning: Not allowed as a service: com.jetbrains.RoundedCornersManager
# 	at com.jetbrains.JBR$RoundedCornersManager__Holder.<clinit>(JBR.java:514)
# 	at com.jetbrains.JBR.isRoundedCornersManagerSupported(JBR.java:524)
# 	at com.intellij.ui.WindowRoundedCornersManager.isAvailable(WindowRoundedCornersManager.java:36)
# 	at com.intellij.ui.popup.AbstractPopup.show(AbstractPopup.java:1033)
# 	at com.intellij.ui.popup.AbstractPopup.show(AbstractPopup.java:654)
# 	at com.intellij.ide.HelpTooltip.lambda$scheduleShow$2(HelpTooltip.java:621)
# 	at com.intellij.util.concurrency.QueueProcessor.runSafely(QueueProcessor.java:255)
# 	at com.intellij.util.Alarm$Request.runSafely(Alarm.java:377)
# 	at com.intellij.util.Alarm$Request.run(Alarm.java:356)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:317)
# 	at com.intellij.util.concurrency.SchedulingWrapper$MyScheduledFutureTask.run(SchedulingWrapper.java:272)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:229)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$100(TransactionGuardImpl.java:22)
# 	at com.intellij.openapi.application.TransactionGuardImpl$1.run(TransactionGuardImpl.java:191)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runIntendedWriteActionOnCurrentThread$lambda$1(AnyThreadWriteThreadingSupport.kt:184)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWriteIntentReadAction(AnyThreadWriteThreadingSupport.kt:84)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runIntendedWriteActionOnCurrentThread(AnyThreadWriteThreadingSupport.kt:183)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runIntendedWriteActionOnCurrentThread(ApplicationImpl.java:836)
# 	at com.intellij.openapi.application.impl.ApplicationImpl$2.run(ApplicationImpl.java:424)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWithImplicitRead(AnyThreadWriteThreadingSupport.kt:122)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWithImplicitRead(ApplicationImpl.java:1162)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:78)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:119)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:41)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:318)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:781)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:728)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:722)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:400)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:87)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:750)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.kt:696)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent$lambda$16(IdeEventQueue.kt:590)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWithoutImplicitRead(AnyThreadWriteThreadingSupport.kt:117)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.kt:590)
# 	at com.intellij.ide.IdeEventQueue.access$_dispatchEvent(IdeEventQueue.kt:73)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1$1.compute(IdeEventQueue.kt:357)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1$1.compute(IdeEventQueue.kt:356)
# 	at com.intellij.openapi.progress.impl.CoreProgressManager.computePrioritized(CoreProgressManager.java:843)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.invoke(IdeEventQueue.kt:356)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.invoke(IdeEventQueue.kt:351)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke$lambda$0(IdeEventQueue.kt:1035)
# 	at com.intellij.openapi.application.WriteIntentReadAction.lambda$run$0(WriteIntentReadAction.java:24)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWriteIntentReadAction(AnyThreadWriteThreadingSupport.kt:84)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWriteIntentReadAction(ApplicationImpl.java:910)
# 	at com.intellij.openapi.application.WriteIntentReadAction.compute(WriteIntentReadAction.java:55)
# 	at com.intellij.openapi.application.WriteIntentReadAction.run(WriteIntentReadAction.java:23)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1036)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1036)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$10(IdeEventQueue.kt:351)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:397)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)
# 2025-01-14 17:03:24,491 [  61482]   WARN - #c.i.u.x.Binding - No accessors for com.intellij.ide.util.TipsUsageManager$State. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-14 17:03:24,566 [  61557] SEVERE - #c.i.o.a.i.ActionUpdater - SurroundWithActionBase#presentation@EditorFloatingToolbar (com.intellij.codeInsight.generation.actions.SurroundWithActionBase), actionId=Floating.CodeToolbar.SurroundWithTryCatch, text='try / catch'
# java.lang.IllegalArgumentException: Invalid range specified: (188, 182);
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:288)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:283)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:279)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:42)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:31)
# 	at com.jetbrains.php.surroundWith.PhpStatementSurroundDescriptor.getElementsToSurround(PhpStatementSurroundDescriptor.java:51)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:54)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:49)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.update(SurroundWithActionBase.kt:38)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:202)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:196)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil.performDumbAwareUpdate(ActionUtil.kt:220)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:561)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$2$1.invoke(ActionUpdater.kt:155)
# 	at com.intellij.openapi.application.rw.InternalReadAction.insideReadAction(InternalReadAction.kt:104)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$insideReadAction(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:94)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1$lambda$0(cancellableReadAction.kt:31)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.tryRunReadAction(AnyThreadWriteThreadingSupport.kt:291)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:965)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1(cancellableReadAction.kt:29)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtilService.runActionAndCancelBeforeWrite(ProgressIndicatorUtilService.java:66)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtils.runActionAndCancelBeforeWrite(ProgressIndicatorUtils.java:155)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal(cancellableReadAction.kt:27)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadCancellable(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadAction(InternalReadAction.kt:77)
# 	at com.intellij.openapi.application.rw.InternalReadAction.readLoop(InternalReadAction.kt:64)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$readLoop(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invokeSuspend(InternalReadAction.kt:35)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.application.rw.InternalReadAction.runReadAction(InternalReadAction.kt:34)
# 	at com.intellij.openapi.application.rw.PlatformReadWriteActionSupport.executeReadAction(PlatformReadWriteActionSupport.kt:38)
# 	at com.intellij.openapi.application.ReadWriteActionSupport.executeReadAction$default(ReadWriteActionSupport.kt:15)
# 	at com.intellij.openapi.application.CoroutinesKt.constrainedReadActionUndispatched(coroutines.kt:82)
# 	at com.intellij.openapi.application.CoroutinesKt.readActionUndispatched(coroutines.kt:69)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invokeSuspend(trace.kt:163)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.callAction(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$callAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invokeSuspend(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invokeSuspend(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.updateAction(ActionUpdater.kt:979)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$updateAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invokeSuspend(ActionUpdater.kt:507)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invokeSuspend(ActionUpdater.kt:523)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.flow.SafeFlow.collectSafely(Builders.kt:57)
# 	at kotlinx.coroutines.flow.AbstractFlow.collect(Flow.kt:226)
# 	at kotlinx.coroutines.flow.FlowKt__CollectionKt.toCollection(Collection.kt:22)
# 	at kotlinx.coroutines.flow.FlowKt.toCollection(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$expandedChildren$1.invokeSuspend(ActionUpdater.kt:654)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$expandedChildren$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$expandedChildren$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invokeSuspend(trace.kt:161)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1.invokeSuspend(ActionUpdater.kt:939)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.internal.LimitedDispatcher$Worker.run(LimitedDispatcher.kt:111)
# 	at kotlinx.coroutines.scheduling.TaskImpl.run(Tasks.kt:99)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:03:24,586 [  61577] SEVERE - #c.i.o.a.i.ActionUpdater - PhpStorm 2024.2.4  Build #PS-242.23726.107
# 2025-01-14 17:03:24,586 [  61577] SEVERE - #c.i.o.a.i.ActionUpdater - JDK: 21.0.4; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2025-01-14 17:03:24,587 [  61578] SEVERE - #c.i.o.a.i.ActionUpdater - OS: Linux
# 2025-01-14 17:03:24,592 [  61583] SEVERE - #c.i.o.a.i.ActionUpdater - SurroundWithActionBase#presentation@EditorFloatingToolbar (com.intellij.codeInsight.generation.actions.SurroundWithActionBase), actionId=Floating.CodeToolbar.SurroundWithTryCatch, text='try / catch'
# java.lang.IllegalArgumentException: Invalid range specified: (188, 182);
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:288)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:283)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:279)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:42)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:31)
# 	at com.jetbrains.php.surroundWith.PhpStatementSurroundDescriptor.getElementsToSurround(PhpStatementSurroundDescriptor.java:51)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:54)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:49)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.update(SurroundWithActionBase.kt:38)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:202)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:196)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil.performDumbAwareUpdate(ActionUtil.kt:220)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:561)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$2$1.invoke(ActionUpdater.kt:155)
# 	at com.intellij.openapi.application.rw.InternalReadAction.insideReadAction(InternalReadAction.kt:104)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$insideReadAction(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:94)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1$lambda$0(cancellableReadAction.kt:31)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.tryRunReadAction(AnyThreadWriteThreadingSupport.kt:291)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:965)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1(cancellableReadAction.kt:29)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtilService.runActionAndCancelBeforeWrite(ProgressIndicatorUtilService.java:66)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtils.runActionAndCancelBeforeWrite(ProgressIndicatorUtils.java:155)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal(cancellableReadAction.kt:27)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadCancellable(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadAction(InternalReadAction.kt:77)
# 	at com.intellij.openapi.application.rw.InternalReadAction.readLoop(InternalReadAction.kt:64)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$readLoop(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invokeSuspend(InternalReadAction.kt:35)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.application.rw.InternalReadAction.runReadAction(InternalReadAction.kt:34)
# 	at com.intellij.openapi.application.rw.PlatformReadWriteActionSupport.executeReadAction(PlatformReadWriteActionSupport.kt:38)
# 	at com.intellij.openapi.application.ReadWriteActionSupport.executeReadAction$default(ReadWriteActionSupport.kt:15)
# 	at com.intellij.openapi.application.CoroutinesKt.constrainedReadActionUndispatched(coroutines.kt:82)
# 	at com.intellij.openapi.application.CoroutinesKt.readActionUndispatched(coroutines.kt:69)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invokeSuspend(trace.kt:163)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.callAction(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$callAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invokeSuspend(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invokeSuspend(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.updateAction(ActionUpdater.kt:979)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$updateAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$presentation$1.invokeSuspend(ActionUpdater.kt:668)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$presentation$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$UpdateSessionImpl$presentation$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invokeSuspend(trace.kt:161)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1$invokeSuspend$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$getSessionDataDeferred$1$1.invokeSuspend(ActionUpdater.kt:939)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.internal.LimitedDispatcher$Worker.run(LimitedDispatcher.kt:111)
# 	at kotlinx.coroutines.scheduling.TaskImpl.run(Tasks.kt:99)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:03:24,599 [  61590] SEVERE - #c.i.o.a.i.ActionUpdater - PhpStorm 2024.2.4  Build #PS-242.23726.107
# 2025-01-14 17:03:24,599 [  61590] SEVERE - #c.i.o.a.i.ActionUpdater - JDK: 21.0.4; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2025-01-14 17:03:24,599 [  61590] SEVERE - #c.i.o.a.i.ActionUpdater - OS: Linux
# 2025-01-14 17:03:24,602 [  61593] SEVERE - #c.i.o.a.i.ActionUpdater - SurroundWithActionBase#presentation@EditorFloatingToolbar (com.intellij.codeInsight.generation.actions.SurroundWithActionBase), actionId=Floating.CodeToolbar.SurroundWithTryCatch, text='try / catch'
# java.lang.IllegalArgumentException: Invalid range specified: (188, 182);
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:288)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:283)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:279)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:42)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:31)
# 	at com.jetbrains.php.surroundWith.PhpStatementSurroundDescriptor.getElementsToSurround(PhpStatementSurroundDescriptor.java:51)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:54)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:49)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.update(SurroundWithActionBase.kt:38)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:202)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:196)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil.performDumbAwareUpdate(ActionUtil.kt:220)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:561)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$2$1.invoke(ActionUpdater.kt:155)
# 	at com.intellij.openapi.application.rw.InternalReadAction.insideReadAction(InternalReadAction.kt:104)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$insideReadAction(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:94)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1$lambda$0(cancellableReadAction.kt:31)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.tryRunReadAction(AnyThreadWriteThreadingSupport.kt:291)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:965)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1(cancellableReadAction.kt:29)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtilService.runActionAndCancelBeforeWrite(ProgressIndicatorUtilService.java:66)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtils.runActionAndCancelBeforeWrite(ProgressIndicatorUtils.java:155)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal(cancellableReadAction.kt:27)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadCancellable(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadAction(InternalReadAction.kt:77)
# 	at com.intellij.openapi.application.rw.InternalReadAction.readLoop(InternalReadAction.kt:64)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$readLoop(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invokeSuspend(InternalReadAction.kt:35)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.application.rw.InternalReadAction.runReadAction(InternalReadAction.kt:34)
# 	at com.intellij.openapi.application.rw.PlatformReadWriteActionSupport.executeReadAction(PlatformReadWriteActionSupport.kt:38)
# 	at com.intellij.openapi.application.ReadWriteActionSupport.executeReadAction$default(ReadWriteActionSupport.kt:15)
# 	at com.intellij.openapi.application.CoroutinesKt.constrainedReadActionUndispatched(coroutines.kt:82)
# 	at com.intellij.openapi.application.CoroutinesKt.readActionUndispatched(coroutines.kt:69)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invokeSuspend(trace.kt:163)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.callAction(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$callAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invokeSuspend(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invokeSuspend(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.updateAction(ActionUpdater.kt:979)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$updateAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invokeSuspend(ActionUpdater.kt:507)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1$tree$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invokeSuspend(ActionUpdater.kt:523)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.flow.SafeFlow.collectSafely(Builders.kt:57)
# 	at kotlinx.coroutines.flow.AbstractFlow.collect(Flow.kt:226)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$take$$inlined$unsafeFlow$1.collect(SafeCollector.common.kt:115)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$$inlined$filter$1.collect(SafeCollector.common.kt:112)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$takeWhile$$inlined$unsafeFlow$1.collect(SafeCollector.common.kt:123)
# 	at kotlinx.coroutines.flow.FlowKt__CollectKt.collect(Collect.kt:26)
# 	at kotlinx.coroutines.flow.FlowKt.collect(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.expandGroupChild(ActionUpdater.kt:440)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$expandGroupChild(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$1.invokeSuspend(ActionUpdater.kt)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:277)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:99)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.internal.LimitedDispatcher$Worker.run(LimitedDispatcher.kt:111)
# 	at kotlinx.coroutines.scheduling.TaskImpl.run(Tasks.kt:99)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:03:24,609 [  61600] SEVERE - #c.i.o.a.i.ActionUpdater - PhpStorm 2024.2.4  Build #PS-242.23726.107
# 2025-01-14 17:03:24,609 [  61600] SEVERE - #c.i.o.a.i.ActionUpdater - JDK: 21.0.4; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2025-01-14 17:03:24,609 [  61600] SEVERE - #c.i.o.a.i.ActionUpdater - OS: Linux
# 2025-01-14 17:03:24,613 [  61604] SEVERE - #c.i.o.a.i.ActionUpdater - SurroundWithActionBase#presentation@EditorFloatingToolbar (com.intellij.codeInsight.generation.actions.SurroundWithActionBase), actionId=Floating.CodeToolbar.SurroundWithTryCatch, text='try / catch'
# java.lang.IllegalArgumentException: Invalid range specified: (188, 182);
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:288)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:283)
# 	at com.intellij.openapi.util.TextRange.assertProperRange(TextRange.java:279)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:42)
# 	at com.intellij.openapi.util.TextRange.<init>(TextRange.java:31)
# 	at com.jetbrains.php.surroundWith.PhpStatementSurroundDescriptor.getElementsToSurround(PhpStatementSurroundDescriptor.java:51)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:54)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.findSurroundContext(SurroundWithActionBase.kt:49)
# 	at com.intellij.codeInsight.generation.actions.SurroundWithActionBase.update(SurroundWithActionBase.kt:38)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:202)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil$performDumbAwareUpdate$runnable$1.invoke(ActionUtil.kt:196)
# 	at com.intellij.openapi.actionSystem.ex.ActionUtil.performDumbAwareUpdate(ActionUtil.kt:220)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:561)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1$1.invoke(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$2$1.invoke(ActionUpdater.kt:155)
# 	at com.intellij.openapi.application.rw.InternalReadAction.insideReadAction(InternalReadAction.kt:104)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$insideReadAction(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:94)
# 	at com.intellij.openapi.application.rw.InternalReadAction$tryReadCancellable$2.invoke(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1$lambda$0(cancellableReadAction.kt:31)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.tryRunReadAction(AnyThreadWriteThreadingSupport.kt:291)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.tryRunReadAction(ApplicationImpl.java:965)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal$lambda$2$lambda$1(cancellableReadAction.kt:29)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtilService.runActionAndCancelBeforeWrite(ProgressIndicatorUtilService.java:66)
# 	at com.intellij.openapi.progress.util.ProgressIndicatorUtils.runActionAndCancelBeforeWrite(ProgressIndicatorUtils.java:155)
# 	at com.intellij.openapi.application.rw.CancellableReadActionKt.cancellableReadActionInternal(cancellableReadAction.kt:27)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadCancellable(InternalReadAction.kt:93)
# 	at com.intellij.openapi.application.rw.InternalReadAction.tryReadAction(InternalReadAction.kt:77)
# 	at com.intellij.openapi.application.rw.InternalReadAction.readLoop(InternalReadAction.kt:64)
# 	at com.intellij.openapi.application.rw.InternalReadAction.access$readLoop(InternalReadAction.kt:15)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invokeSuspend(InternalReadAction.kt:35)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at com.intellij.openapi.application.rw.InternalReadAction$runReadAction$3.invoke(InternalReadAction.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.CoroutineScopeKt.coroutineScope(CoroutineScope.kt:261)
# 	at com.intellij.openapi.application.rw.InternalReadAction.runReadAction(InternalReadAction.kt:34)
# 	at com.intellij.openapi.application.rw.PlatformReadWriteActionSupport.executeReadAction(PlatformReadWriteActionSupport.kt:38)
# 	at com.intellij.openapi.application.ReadWriteActionSupport.executeReadAction$default(ReadWriteActionSupport.kt:15)
# 	at com.intellij.openapi.application.CoroutinesKt.constrainedReadActionUndispatched(coroutines.kt:82)
# 	at com.intellij.openapi.application.CoroutinesKt.readActionUndispatched(coroutines.kt:69)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invokeSuspend(trace.kt:163)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$callAction$$inlined$useWithScope$1.invoke(trace.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.callAction(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$callAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invokeSuspend(ActionUpdater.kt:560)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$success$1$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invokeSuspend(ActionUpdater.kt:939)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$updateAction$$inlined$retryOnAwaitSharedData$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 	at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.updateAction(ActionUpdater.kt:979)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$updateAction(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$3.invokeSuspend(ActionUpdater.kt:432)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$3.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$3.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$takeWhile$lambda$6$$inlined$collectWhile$1.emit(Limit.kt:139)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$$inlined$filter$1$2.emit(Emitters.kt:219)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$take$2$1.emit(Limit.kt:58)
# 	at kotlinx.coroutines.flow.internal.SafeCollectorKt$emitFun$1.invoke(SafeCollector.kt:11)
# 	at kotlinx.coroutines.flow.internal.SafeCollectorKt$emitFun$1.invoke(SafeCollector.kt:11)
# 	at kotlinx.coroutines.flow.internal.SafeCollector.emit(SafeCollector.kt:115)
# 	at kotlinx.coroutines.flow.internal.SafeCollector.emit(SafeCollector.kt:84)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invokeSuspend(ActionUpdater.kt:524)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$iterateGroupChildren$1.invoke(ActionUpdater.kt)
# 	at kotlinx.coroutines.flow.SafeFlow.collectSafely(Builders.kt:57)
# 	at kotlinx.coroutines.flow.AbstractFlow.collect(Flow.kt:226)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$take$$inlined$unsafeFlow$1.collect(SafeCollector.common.kt:115)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$$inlined$filter$1.collect(SafeCollector.common.kt:112)
# 	at kotlinx.coroutines.flow.FlowKt__LimitKt$takeWhile$$inlined$unsafeFlow$1.collect(SafeCollector.common.kt:123)
# 	at kotlinx.coroutines.flow.FlowKt__CollectKt.collect(Collect.kt:26)
# 	at kotlinx.coroutines.flow.FlowKt.collect(Unknown Source)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.expandGroupChild(ActionUpdater.kt:440)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater.access$expandGroupChild(ActionUpdater.kt:85)
# 	at com.intellij.openapi.actionSystem.impl.ActionUpdater$expandGroupChild$1.invokeSuspend(ActionUpdater.kt)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.UndispatchedCoroutine.afterResume(CoroutineContext.kt:277)
# 	at kotlinx.coroutines.AbstractCoroutine.resumeWith(AbstractCoroutine.kt:99)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:46)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.internal.LimitedDispatcher$Worker.run(LimitedDispatcher.kt:111)
# 	at kotlinx.coroutines.scheduling.TaskImpl.run(Tasks.kt:99)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-14 17:03:24,620 [  61611] SEVERE - #c.i.o.a.i.ActionUpdater - PhpStorm 2024.2.4  Build #PS-242.23726.107
# 2025-01-14 17:03:24,620 [  61611] SEVERE - #c.i.o.a.i.ActionUpdater - JDK: 21.0.4; VM: OpenJDK 64-Bit Server VM; Vendor: JetBrains s.r.o.
# 2025-01-14 17:03:24,620 [  61611] SEVERE - #c.i.o.a.i.ActionUpdater - OS: Linux
# 2025-01-14 17:07:08,293 [ 285284]   WARN - #c.i.o.a.i.ActionUpdater - 3159 ms total to grab EDT 4 times to expand ToolWindowHeader$2#expandGroup@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2). Use `ActionUpdateThread.BGT`.
# ^C

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3

# %%
seleniumServer.kill()

# %%
# %cd ..
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
# Out:
# mysql
