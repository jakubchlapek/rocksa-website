# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# ff8e4ba71fda4f8fa2556f648f84e4110640e2b57264228f745f4cac58be15a1

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update sebastian/phpcpd
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Package sebastian/phpcpd is abandoned, you should avoid using it. No replacement was suggested.
# Generating autoload files
# 5 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# [Errno 2] No such file or directory: 'project'
# /home/student/Desktop/php_2024_iad_rocksa/rocksa/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   andreiio/blade-remix-icon ............................................. DONE
#   blade-ui-kit/blade-icons .............................................. DONE
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/pail .......................................................... DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#
# 104 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.65.0 Persian Successor by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.6
# Running analysis on 1 core sequentially.
# You can enable parallel runner and speed up the analysis! Please see ]8;;https://cs.symfony.com/doc/usage.html\usage docs]8;;\ for more information.
# Loaded config default from "/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    0/129 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  13/129 [▓▓░░░░░░░░░░░░░░░░░░░░░░░░░░]  10%  26/129 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20%  39/129 [▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░]  30%  52/129 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  40% 104/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 117/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 129/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#    1) app/Models/OrderItems.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# @@ -19,7 +19,8 @@
#
#      }
#
# -    public function rocks(){
# +    public function rocks()
# +    {
#
#          return $this -> belongsTo(Rock::class);
#
#
#       ----------- end diff -----------
#
#    2) app/Models/Rock.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# @@ -37,4 +37,3 @@
#
#
#  }
# -
#
#       ----------- end diff -----------
#
#    3) app/Http/Controllers/OrderController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# @@ -1,4 +1,5 @@
#  <?php
# +
#  namespace App\Http\Controllers;
#
#  use App\Http\Requests\StoreOrderRequest;
#
#       ----------- end diff -----------
#
#    4) app/Http/Controllers/orderItemsController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# @@ -8,6 +8,7 @@
#  use App\Models\OrderItems;
#  use Illuminate\Http\RedirectResponse;
#  use Illuminate\View\View;
# +
#  class orderItemsController extends Controller
#  {
#      public function store(StoreOrderItemsRequest $request): RedirectResponse
#
#       ----------- end diff -----------
#
#    5) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# @@ -8,7 +8,6 @@
#  // use Database\Seeders\InsertTestSeeder;
#  use Database\Seeders\InsertTestSeeder;
#
# -
#  class DatabaseSeeder extends Seeder
#  {
#      /**
#
#       ----------- end diff -----------
#
#    6) database/seeders/InsertTestSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# @@ -5,6 +5,7 @@
#  use Illuminate\Database\Seeder;
#  use Illuminate\Support\Facades\DB;
#  use Illuminate\Support\Facades\Hash;
# +
#  // use Illuminate\Support\Facades\File;
#
#  class InsertTestSeeder extends Seeder
# @@ -73,4 +74,3 @@
#          ]);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    7) database/migrations/2025_01_11_create_orders_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# @@ -5,7 +5,6 @@
#  use Illuminate\Support\Facades\Schema;
#
#  return new class () extends Migration {
# -
#      /**
#       * Run the migrations.
#       *
# @@ -39,4 +38,3 @@
#          Schema::dropIfExists('orders');
#      }
#  };
# -
#
#       ----------- end diff -----------
#
#
# Found 7 of 129 files that can be fixed in 0.522 seconds, 20.00 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#    0/120 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  20/120 [▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░░]  16%  60/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░]  50%  80/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░]  66% 100/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░]  83% 120/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/Cart.php
#  ------ --------------------------------------------------------------------------------------
#   8      Class App\Livewire\Cart extends unknown class Livewire\Component.
#          💡 Learn more at https://phpstan.org/user-guide/discovering-symbols
#   10     Property App\Livewire\Cart::$cart type has no value type specified in
#          iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   14     Property App\Livewire\Cart::$listeners has no type specified.
#          🪪  missingType.property
#   21     Method App\Livewire\Cart::mount() has no return type specified.
#          🪪  missingType.return
#   26     Method App\Livewire\Cart::toggleCart() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has no return type
#          specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $image with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $name with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $price with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   32     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   34     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   35     Binary operation "+=" between mixed and 1 results in an error.
#          🪪  assignOp.invalid
#   35     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   37     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   48     Call to an undefined method App\Livewire\Cart::dispatch().
#          🪪  method.notFound
#   51     Method App\Livewire\Cart::updateQuantity() has no return type
#          specified.
#          🪪  missingType.return
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $change with
#          no type specified.
#          🪪  missingType.parameter
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   53     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   55     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   56     Binary operation "+=" between mixed and mixed results in an error.
#          🪪  assignOp.invalid
#   56     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Comparison operation "<=" between (array|float|int) and 0 results in
#          an error.
#          🪪  smallerOrEqual.invalid
#   64     Call to an undefined method App\Livewire\Cart::dispatch().
#          🪪  method.notFound
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has no return type
#          specified.
#          🪪  missingType.return
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has parameter
#          $productId with no type specified.
#          🪪  missingType.parameter
#   70     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   72     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   73     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   79     Call to an undefined method App\Livewire\Cart::dispatch().
#          🪪  method.notFound
#   82     Call to an undefined method App\Livewire\Cart::dispatch().
#          🪪  method.notFound
#   88     Method App\Livewire\Cart::clearCart() has no return type specified.
#          🪪  missingType.return
#   96     Call to an undefined method App\Livewire\Cart::dispatch().
#          🪪  method.notFound
#   100    Method App\Livewire\Cart::refreshCart() has no return type specified.
#          🪪  missingType.return
#   102    Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   105    Method App\Livewire\Cart::render() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/RockCard.php
#  ------ --------------------------------------------------------------------------------------
#   7      Class App\Livewire\RockCard extends unknown class Livewire\Component.
#          💡 Learn more at https://phpstan.org/user-guide/discovering-symbols
#   10     Property App\Livewire\RockCard::$data type has no value type
#          specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   17     Method App\Livewire\RockCard::mount() has no return type specified.
#          🪪  missingType.return
#   38     Method App\Livewire\RockCard::render() has invalid return type
#          App\Livewire\View.
#          🪪  class.notFound
#  ------ --------------------------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/Order.php
#  ------ ---------------------------------------------------------------------
#   22     Method App\Models\Order::user() has no return type specified.
#          🪪  missingType.return
#   27     Method App\Models\Order::orderItems() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/OrderItems.php
#  ------ ---------------------------------------------------------------------
#   15     Method App\Models\OrderItems::order() has no return type specified.
#          🪪  missingType.return
#   22     Method App\Models\OrderItems::rocks() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Models/Rock.php
#  ------ ----------------------------------------------------------------
#   31     Method App\Models\Rock::orders() has no return type specified.
#          🪪  missingType.return
#  ------ ----------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   tests/Unit/ExampleTest.php
#  ------ -----------------------------------------------------------------------
#   19     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   19     No error with identifier method.alreadyNarrowedType is reported on
#          line 19.
#   24     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   24     No error with identifier method.alreadyNarrowedType is reported on
#          line 24.
#   29     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   29     No error with identifier method.alreadyNarrowedType is reported on
#          line 29.
#   33     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   33     No error with identifier method.alreadyNarrowedType is reported on
#          line 33.
#   37     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   37     No error with identifier method.alreadyNarrowedType is reported on
#          line 37.
#   41     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   41     No error with identifier method.alreadyNarrowedType is reported on
#          line 41.
#   46     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   46     No error with identifier method.alreadyNarrowedType is reported on
#          line 46.
#   51     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   51     No error with identifier method.alreadyNarrowedType is reported on
#          line 51.
#   56     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   56     No error with identifier method.alreadyNarrowedType is reported on
#          line 56.
#   61     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   61     No error with identifier method.alreadyNarrowedType is reported on
#          line 61.
#   66     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   66     No error with identifier method.alreadyNarrowedType is reported on
#          line 66.
#  ------ -----------------------------------------------------------------------
#
#
#  [ERROR] Found 69 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# No clones found.
#
# Time: 00:00.052, Memory: 4.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Environment modified. Restarting server...
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
#
#    INFO  Application key set successfully.
#
#
#    INFO  Environment modified. Restarting server...

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done
# Out:
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server

# %%
! php artisan migrate:fresh
# Out:
#   Dropping all tables .......................................... 937.59ms DONE
#
#    INFO  Preparing database.
#
#   Creating migration table ..................................... 194.75ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ......................... 526.87ms DONE
#   0001_01_01_000001_create_cache_table ......................... 205.49ms DONE
#   0001_01_01_000002_create_jobs_table .......................... 350.14ms DONE
#   2024_11_29_145411_create_comments_table ....................... 57.96ms DONE
#   2024_12_07_094911_create_books_table ......................... 144.69ms DONE
#   2025_01_10_create_rocks_table ................................ 108.24ms DONE
#   2025_01_11_create_orders_table ............................... 348.43ms DONE
#   2025_01_14_151420_add_user_id_to_rocks_table ................. 281.04ms DONE
#   2025_01_14_153906_order_items_table .......................... 485.79ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 305 ms DONE
#
#   Database\Seeders\InsertTestSeeder .................................. RUNNING
#   Database\Seeders\InsertTestSeeder .............................. 308 ms DONE

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏
# up to date, audited 171 packages in 3s
# ⠏
# ⠏40 packages are looking for funding
# ⠏  run `npm fund` for details
# ⠏
# found 0 vulnerabilities
# ⠏

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.4.11 building for production...
# transforming (1) resources/js/app.jstransforming (2) node_modules/alpinejs/dist/module.esm.jstransforming (4) resources/css/app.csstransforming (24) node_modules/axios/lib/helpers/buildURL.js✓ 54 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-DxEV3bkS.css  38.99 kB │ gzip:  7.20 kB
# public/build/assets/app-5Xb-APZy.js   79.37 kB │ gzip: 29.63 kB
# ✓ built in 3.67s
# ⠙  2025-01-18 20:12:34 / .......................................... ~ 503.79ms
#   2025-01-18 20:12:35 /build/assets/app-DxEV3bkS.css ............... ~ 0.83ms
#   2025-01-18 20:12:35 /build/assets/app-5Xb-APZy.js ................ ~ 3.57ms
#   2025-01-18 20:12:35 /static/logo.svg ............................. ~ 7.25ms
#   2025-01-18 20:12:35 /static/gradient.jpg ......................... ~ 0.22ms
#   2025-01-18 20:12:35 /favicon.ico ................................. ~ 0.35ms
#   2025-01-18 20:12:43 /login ..................................... ~ 502.80ms
#   2025-01-18 20:12:44 /build/assets/app-DxEV3bkS.css ............... ~ 0.30ms
#   2025-01-18 20:12:44 /static/logo.svg ............................. ~ 4.11ms
#   2025-01-18 20:12:44 /build/assets/app-5Xb-APZy.js ............... ~ 17.62ms
#   2025-01-18 20:12:44 /static/gradient.jpg ......................... ~ 0.14ms
#   2025-01-18 20:12:44 /favicon.ico ................................. ~ 0.21ms
#   2025-01-18 20:13:03 /login ........................................... ~ 1s
#   2025-01-18 20:13:03 /dashboard .................................. ~ 20.74ms
#   2025-01-18 20:13:04 /build/assets/app-DxEV3bkS.css ............... ~ 1.17ms
#   2025-01-18 20:13:04 /static/logo.svg ............................ ~ 14.45ms
#   2025-01-18 20:13:04 /build/assets/app-5Xb-APZy.js ............... ~ 19.88ms
#   2025-01-18 20:13:04 /static/gradient.jpg ......................... ~ 0.62ms
#   2025-01-18 20:13:04 /static/amethyst1.jpg ...................... ~ 554.16ms
#   2025-01-18 20:13:04 /static/amethyst2.jpg ...................... ~ 556.94ms
#   2025-01-18 20:13:04 /static/amethyst.jpg ....................... ~ 560.92ms
#   2025-01-18 20:13:05 /favicon.ico ................................ ~ 17.16ms
#   2025-01-18 21:23:09 /dashboard ....................................... ~ 2s
#   2025-01-18 23:31:39 /dashboard ....................................... ~ 1s
#   2025-01-18 23:31:41 /login ........................................... ~ 1s
#   2025-01-18 23:31:42 /build/assets/app-5Xb-APZy.js .............. ~ 560.18ms
#   2025-01-18 23:31:42 /static/logo.svg ............................ ~ 13.50ms
#   2025-01-18 23:31:42 /build/assets/app-DxEV3bkS.css ............. ~ 574.77ms
#   2025-01-18 23:31:42 /static/gradient.jpg ......................... ~ 0.10ms
#   2025-01-18 23:31:43 /favicon.ico ............................... ~ 502.18ms
#   2025-01-18 23:32:05 /login ........................................... ~ 1s
#   2025-01-18 23:32:06 /dashboard ....................................... ~ 1s

# %%
! php artisan test
# Out:
#    FAIL  Tests\Unit\ExampleTest
#   ✓ that true is true
#   ⨯ add to cart                                                          0.01s
#   ⨯ remove from cart
#   ⨯ edit name
#   ⨯ edit email
#   ⨯ edit phone number
#   ⨯ edit password
#   ⨯ calculate cost
#   ⨯ add rock
#   ⨯ remove rock
#   ⨯ add filter
#   ⨯ remove filter
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                         3.34s
#   ✓ users can authenticate using the login screen                        0.54s
#   ✓ users can not authenticate with invalid password                     0.44s
#   ✓ users can logout                                                     0.35s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.35s
#   ✓ email can be verified                                                0.24s
#   ✓ email is not verified with invalid hash                              0.20s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.26s
#   ✓ password can be confirmed                                            0.31s
#   ✓ password is not confirmed with invalid password                      0.64s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.44s
#   ✓ reset password link can be requested                                 0.35s
#   ✓ reset password screen can be rendered                                0.25s
#   ✓ password can be reset with valid token                               0.27s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.32s
#   ✓ correct password must be provided to update password                 0.26s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.24s
#   ✓ new users can register                                               0.27s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.35s
#   2025-01-18 19:57:05 / ................................................ ~ 1s
#   2025-01-18 19:57:06 /build/assets/app-BaCk4Yae.css ............... ~ 0.24ms
#   2025-01-18 19:57:06 /build/assets/app-D-FaURHc.js ................ ~ 2.81ms
#   2025-01-18 19:57:06 /static/logo.svg ............................. ~ 3.53ms
#   2025-01-18 19:57:06 /static/gradient.jpg ......................... ~ 0.64ms
#   2025-01-18 19:57:07 /favicon.ico ................................. ~ 0.20ms
#
#    FAIL  Tests\Feature\ProfileTest
#   ⨯ profile page is displayed                                            1.41s
#   ✓ profile information can be updated                                   0.36s
#   ✓ email verification status is unchanged when the email address is un… 0.49s
#   ✓ user can delete their account                                        0.44s
#   ✓ correct password must be provided to delete account                  0.44s
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add to cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:19
#      15▕     }
#      16▕     // Add to cart
#      17▕     public function test_add_to_cart(): void
#      18▕     {
#   ➜  19▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#
#   1   tests/Unit/ExampleTest.php:19
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove from cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:24
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#   ➜  24▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#
#   1   tests/Unit/ExampleTest.php:24
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit name
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:29
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#   ➜  29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:29
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit email
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:33
#      29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#   ➜  33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:33
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit phone number
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:37
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#   ➜  37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#      41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:37
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit password
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:41
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#   ➜  41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#
#   1   tests/Unit/ExampleTest.php:41
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > calculate cost
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:46
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#   ➜  46▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#
#   1   tests/Unit/ExampleTest.php:46
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:51
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#   ➜  51▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#
#   1   tests/Unit/ExampleTest.php:51
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:56
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#   ➜  56▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#
#   1   tests/Unit/ExampleTest.php:56
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:61
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#   ➜  61▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#
#   1   tests/Unit/ExampleTest.php:61
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:66
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#   ➜  66▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      67▕     }
#      68▕ }
#      69▕
#
#   1   tests/Unit/ExampleTest.php:66
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Feature\ProfileTest > profile page is displayed
#   Expected response status code [200] but received 500.
# Failed asserting that 500 is identical to 200.
#
# The following exception occurred during the last request:
#
# Symfony\Component\Routing\Exception\RouteNotFoundException: Route [orders.index] not defined. in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:516
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/helpers.php(853): Illuminate\Routing\UrlGenerator->route()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/bc83c7878475f73afdc76d25b8e2e476.php(132): route()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/44ed49034fa6e57427d55e11fb4e7f3d.php(20): Illuminate\View\View->render()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(70): Illuminate\View\View->render()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Auth\Middleware\Authenticate->handle()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Session\Middleware\StartSession->handle()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #65 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\HandleCors->handle()
# #66 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #67 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\TrustProxies->handle()
# #68 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #69 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #70 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #71 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #72 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #73 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(605): Illuminate\Foundation\Http\Kernel->handle()
# #74 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(366): Illuminate\Foundation\Testing\TestCase->call()
# #75 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #76 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1234): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #77 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(515): PHPUnit\Framework\TestCase->runTest()
# #78 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #79 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(362): PHPUnit\Framework\TestRunner->run()
# #80 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #81 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #82 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #83 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #84 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #85 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #86 {main}
#
# Next Illuminate\View\ViewException: Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:516
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(60): Illuminate\View\Engines\CompilerEngine->handleViewException()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/44ed49034fa6e57427d55e11fb4e7f3d.php(20): Illuminate\View\View->render()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(70): Illuminate\View\View->render()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Auth\Middleware\Authenticate->handle()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Session\Middleware\StartSession->handle()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\HandleCors->handle()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\TrustProxies->handle()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #65 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #66 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #67 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #68 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #69 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(605): Illuminate\Foundation\Http\Kernel->handle()
# #70 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(366): Illuminate\Foundation\Testing\TestCase->call()
# #71 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #72 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1234): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #73 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(515): PHPUnit\Framework\TestCase->runTest()
# #74 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #75 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(362): PHPUnit\Framework\TestRunner->run()
# #76 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #77 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #78 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #79 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #80 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #81 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #82 {main}
#
# Next Illuminate\View\ViewException: Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:516
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(60): Illuminate\View\Engines\CompilerEngine->handleViewException()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(70): Illuminate\View\View->render()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Auth\Middleware\Authenticate->handle()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Session\Middleware\StartSession->handle()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# ...
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(74): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Illuminate\View\Engines\CompilerEngine->get()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(70): Illuminate\View\View->render()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Auth\Middleware\Authenticate->handle()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Session\Middleware\StartSession->handle()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(144): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\HandleCors->handle()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Http\Middleware\TrustProxies->handle()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(183): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(119): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(605): Illuminate\Foundation\Http\Kernel->handle()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(366): Illuminate\Foundation\Testing\TestCase->call()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1234): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(515): PHPUnit\Framework\TestCase->runTest()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(362): PHPUnit\Framework\TestRunner->run()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #65 {main}
#
# ----------------------------------------------------------------------------------
#
# Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php)
#
#   at tests/Feature/ProfileTest.php:21
#      17▕         $response = $this
#      18▕             ->actingAs($user)
#      19▕             ->get('/profile');
#      20▕
#   ➜  21▕         $response->assertOk();
#      22▕     }
#      23▕
#      24▕     public function test_profile_information_can_be_updated(): void
#      25▕     {
#
#
#   Tests:    12 failed, 24 passed (74 assertions)
#   Duration: 12.69s
#
#   2025-01-18 19:57:11 /login ..................................... ~ 500.83ms
#   2025-01-18 19:57:12 /build/assets/app-BaCk4Yae.css ............... ~ 0.40ms
#   2025-01-18 19:57:12 /build/assets/app-D-FaURHc.js ................ ~ 1.95ms
#   2025-01-18 19:57:12 /static/logo.svg ............................. ~ 2.85ms
#   2025-01-18 19:57:12 /static/gradient.jpg ......................... ~ 0.16ms
#   2025-01-18 19:57:12 /favicon.ico ................................. ~ 0.14ms
#   2025-01-18 19:57:26 /login ..................................... ~ 658.76ms
#   2025-01-18 19:57:27 /login ..................................... ~ 916.23ms
#   2025-01-18 19:57:27 /build/assets/app-BaCk4Yae.css ............... ~ 1.89ms
#   2025-01-18 19:57:27 /build/assets/app-D-FaURHc.js ................ ~ 6.30ms
#   2025-01-18 19:57:27 /static/logo.svg ............................. ~ 7.66ms
#   2025-01-18 19:57:27 /static/gradient.jpg ......................... ~ 0.10ms
#   2025-01-18 19:57:28 /favicon.ico ................................. ~ 0.12ms
#   2025-01-18 19:57:35 /login ..................................... ~ 501.11ms
#   2025-01-18 19:57:36 /login ..................................... ~ 501.94ms
#   2025-01-18 19:57:36 /build/assets/app-BaCk4Yae.css ............... ~ 2.46ms
#   2025-01-18 19:57:36 /build/assets/app-D-FaURHc.js ............... ~ 31.06ms
#   2025-01-18 19:57:36 /static/logo.svg ............................ ~ 32.44ms
#   2025-01-18 19:57:36 /static/gradient.jpg ......................... ~ 0.97ms
#   2025-01-18 19:57:36 /favicon.ico ................................. ~ 0.65ms
#   2025-01-18 19:58:17 /dashboard ....................................... ~ 1s
#   2025-01-18 19:58:18 /login ..................................... ~ 501.07ms
#   2025-01-18 19:58:19 /build/assets/app-BaCk4Yae.css .............. ~ 14.82ms
#   2025-01-18 19:58:19 /build/assets/app-D-FaURHc.js ............... ~ 25.53ms
#   2025-01-18 19:58:19 /static/logo.svg ............................ ~ 34.08ms
#   2025-01-18 19:58:19 /static/gradient.jpg ......................... ~ 4.40ms
#   2025-01-18 19:58:20 /favicon.ico ................................. ~ 0.20ms
#   2025-01-18 19:59:03 /favicon.ico ............................... ~ 507.33ms
#   2025-01-18 19:59:07 /register .................................. ~ 503.32ms
#   2025-01-18 19:59:07 /build/assets/app-D-FaURHc.js ................ ~ 0.24ms
#   2025-01-18 19:59:07 /build/assets/app-BaCk4Yae.css ............... ~ 1.48ms
#   2025-01-18 19:59:07 /static/logo.svg ............................. ~ 1.07ms
#   2025-01-18 19:59:07 /static/gradient.jpg ......................... ~ 0.40ms
#   2025-01-18 19:59:07 /favicon.ico ................................. ~ 1.81ms
#   2025-01-18 19:59:41 /register ........................................ ~ 1s
#   2025-01-18 19:59:42 /dashboard ....................................... ~ 1s
#   2025-01-18 20:08:04 /login ........................................... ~ 1s
#   2025-01-18 20:08:05 /build/assets/app-BaCk4Yae.css ............... ~ 0.43ms
#   2025-01-18 20:08:05 /build/assets/app-D-FaURHc.js ................ ~ 1.77ms
#   2025-01-18 20:08:05 /static/logo.svg ............................. ~ 3.34ms
#   2025-01-18 20:08:05 /static/gradient.jpg ......................... ~ 0.20ms
#   2025-01-18 20:08:05 /favicon.ico ................................. ~ 0.15ms

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.24.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done
# Out:
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
# 19:37:42.600 INFO [LoggingOptions.configureLogEncoding] - Using the system default encoding
# 19:37:42.617 INFO [OpenTelemetryTracer.createTracer] - Using OpenTelemetry for tracing
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 19:37:44.170 INFO [NodeOptions.getSessionFactories] - Detected 4 available processors
# 19:37:44.177 INFO [NodeOptions.discoverDrivers] - Looking for existing drivers on the PATH.
# 19:37:44.178 INFO [NodeOptions.discoverDrivers] - Add '--selenium-manager true' to the startup command to setup drivers automatically.
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 19:37:45.158 WARN [SeleniumManager.lambda$runCommand$1] - Exception managing chrome: Unable to discover proper chromedriver version in offline mode
# 19:37:45.211 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper msedgedriver version in offline mode
# 19:37:45.269 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper geckodriver version in offline mode
# 19:37:45.311 INFO [NodeOptions.report] - Adding Edge for {"browserName": "MicrosoftEdge","platformName": "linux"} 4 times
# 19:37:45.313 INFO [NodeOptions.report] - Adding Firefox for {"browserName": "firefox","platformName": "linux"} 4 times
# 19:37:45.314 INFO [NodeOptions.report] - Adding Chrome for {"browserName": "chrome","platformName": "linux"} 4 times
# 19:37:45.360 INFO [Node.<init>] - Binding additional locator mechanisms: relative
# 19:37:45.413 INFO [GridModel.setAvailability] - Switching Node a75fab75-02e4-49b8-adfb-a252d228e64e (uri: http://172.17.0.1:4444) from DOWN to UP
# 19:37:45.415 INFO [LocalDistributor.add] - Added node a75fab75-02e4-49b8-adfb-a252d228e64e at http://172.17.0.1:4444. Health check every 120s
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 19:37:45.737 INFO [Standalone.execute] - Started Selenium Standalone 4.24.0 (revision 748ffc9bc3): http://172.17.0.1:4444

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done

# %%
! vendor/bin/codecept run
# Out:
#   2025-01-18 19:37:47 .............................................. ~ 0.68ms
# Codeception PHP Testing Framework v5.1.2 https://stand-with-ukraine.pp.ua
#
# TestsCodeception.Acceptance Tests (4) ------------------------------------------
# - Test00_HomepageCest: See Laravel links on homepage19:37:50.146 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 19:37:54.711 INFO [LocalNode.newSession] - Session created by the Node. Id: bf97a9726017d17a5dbd4acd2eeddaea, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 19:37:54.733 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: bf97a9726017d17a5dbd4acd2eeddaea
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2025-01-18 19:37:58 / ................................................ ~ 1s
#   2025-01-18 19:37:59 /build/assets/app-PCkFcrRW.css ............... ~ 0.40ms
#   2025-01-18 19:37:59 /build/assets/app-D-FaURHc.js ................ ~ 2.49ms
#   2025-01-18 19:37:59 /static/logo.svg ............................. ~ 3.11ms
#   2025-01-18 19:37:59 /static/gradient.jpg ............................. ~ 2s
#   2025-01-18 19:38:04 /favicon.ico ................................. ~ 0.24ms
# ✖ Test00_HomepageCest: See Laravel links on homepage(6.53s)
# - Test01_CommentsCest: See comments from DB displayed on page  2025-01-18 19:38:10 /comments ........................................ ~ 1s
#   2025-01-18 19:38:11 /build/assets/app-PCkFcrRW.css ............... ~ 0.24ms
#   2025-01-18 19:38:11 /build/assets/app-D-FaURHc.js ................ ~ 4.43ms
#   2025-01-18 19:38:11 /static/logo.svg ............................. ~ 5.03ms
#   2025-01-18 19:38:11 /static/gradient.jpg ......................... ~ 0.10ms
#   2025-01-18 19:38:13 /favicon.ico ................................. ~ 0.22ms
#   2025-01-18 19:38:14 /comments/1 ...................................... ~ 1s
#   2025-01-18 19:38:15 /build/assets/app-PCkFcrRW.css ............... ~ 2.67ms
#   2025-01-18 19:38:15 /build/assets/app-D-FaURHc.js ................ ~ 3.80ms
#   2025-01-18 19:38:15 /static/logo.svg ............................. ~ 5.79ms
#   2025-01-18 19:38:15 /static/gradient.jpg ......................... ~ 4.78ms
#   2025-01-18 19:38:16 /favicon.ico ................................. ~ 0.37ms
# ✔ Test01_CommentsCest: See comments from DB displayed on page(7.87s)
# - Test02_LoginCest: Login with existing user  2025-01-18 19:38:21 /dashboard ................................. ~ 500.86ms
#   2025-01-18 19:38:21 /login ....................................... ~ 0.50ms
#   2025-01-18 19:38:21 /static/logo.svg ............................. ~ 0.31ms
#   2025-01-18 19:38:21 /build/assets/app-D-FaURHc.js .............. ~ 529.08ms
#   2025-01-18 19:38:21 /build/assets/app-PCkFcrRW.css ............. ~ 529.88ms
#   2025-01-18 19:38:21 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-18 19:38:25 /favicon.ico ................................. ~ 0.38ms
#   2025-01-18 19:38:26 /login ........................................... ~ 1s
#   2025-01-18 19:38:27 /dashboard ....................................... ~ 1s
# ✖ Test02_LoginCest: Login with existing user(9.22s)
# ✖ Test03_BooksCest: Have books page(0.64s)
#   2025-01-18 19:38:33 /books ..................................... ~ 502.05ms
#   2025-01-18 19:38:34 /favicon.ico ................................. ~ 0.20ms
# 19:38:54.678 INFO [LocalSessionMap.remove] - Deleted session from local Session Map, Id: bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.680 INFO [GridModel.release] - Releasing slot for session id bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.681 INFO [SessionSlot.stop] - Stopping session bf97a9726017d17a5dbd4acd2eeddaea
# --------------------------------------------------------------------------------
# Time: 01:07.277, Memory: 16.00 MB
#
# There were 3 failures:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:test
#  Step  See in title "Laravel"
#  Fail  Failed asserting that 'Rocksa' [ASCII](length: 6) contains "Laravel" [ASCII](length: 7).
#
# Scenario Steps:
#
#  2. $I->seeInTitle("Laravel") at tests_codeception/Acceptance/Test00_HomepageCest.php:15
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.html
# 2) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:test
#  Step  See "John Doe"
#  Fail  Failed asserting that on page /dashboard
# --> Internal Server Error
# ErrorException
# Undefined variable $rocks
# GET localhost:8888
# PHP 8.3.6 — Laravel 11.34.2
# resources/views/dashboard.blade.php :7
#     <div class="py-12">
#         <div class="max-w-7xl mx-auto sm:px-6 lg:px-8">
#             <div class="bg-white overflow-visible shadow-sm sm:rounded-
# [Content too long to display. See complete response in '/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/' directory]
# --> contains "John Doe".
#
# Scenario Steps:
#
#  9. $I->see("John Doe") at tests_codeception/Acceptance/Test02_LoginCest.php:19
#  8. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:17
#  7. $I->waitForJS("return document.oldPage !== "yes"") at tests_codeception/Support/AcceptanceTester.php:49
#  6. $I->click("Log in") at tests_codeception/Support/AcceptanceTester.php:35
#  5. $I->waitForJS("return document.oldPage = "yes"") at tests_codeception/Support/AcceptanceTester.php:42
#  4. $I->fillField("password","secret") at tests_codeception/Support/AcceptanceTester.php:34
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.html
# 3) Test03_BooksCest: Have books page
#  Test  tests_codeception/Acceptance/Test03_BooksCest.php:test
#  Step  See current url equals "/login"
#  Fail  Failed asserting that two strings are equal.
# - Expected | + Actual
# @@ @@
# -'/login'
# +'/books'
#
# Scenario Steps:
#
#  2. $I->seeCurrentUrlEquals("/login") at tests_codeception/Support/AcceptanceTester.php:32
#  1. $I->amOnPage("/books") at tests_codeception/Acceptance/Test03_BooksCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.html
#
# FAILURES!
# Tests: 4, Assertions: 12, Failures: 3.
#   2025-01-18 19:39:09 / .......................................... ~ 507.98ms
#   2025-01-18 19:39:09 /build/assets/app-PCkFcrRW.css ............... ~ 2.44ms
#   2025-01-18 19:39:09 /build/assets/app-D-FaURHc.js ................ ~ 2.94ms
#   2025-01-18 19:39:09 /static/logo.svg ............................. ~ 3.42ms
#   2025-01-18 19:39:09 /static/gradient.jpg ......................... ~ 4.13ms
#   2025-01-18 19:39:10 /favicon.ico ................................ ~ 17.70ms
#   2025-01-18 19:39:14 /login ..................................... ~ 508.37ms
#   2025-01-18 19:39:15 /static/logo.svg ............................. ~ 0.17ms
#   2025-01-18 19:39:15 /build/assets/app-PCkFcrRW.css ............... ~ 3.14ms
#   2025-01-18 19:39:15 /build/assets/app-D-FaURHc.js ............... ~ 20.43ms
#   2025-01-18 19:39:15 /static/gradient.jpg ......................... ~ 0.14ms
#   2025-01-18 19:39:15 /favicon.ico ................................. ~ 0.29ms
#   2025-01-18 19:39:31 /login ........................................... ~ 1s
#   2025-01-18 19:39:32 /dashboard ................................. ~ 503.25ms
#   2025-01-18 19:47:53 /dashboard ....................................... ~ 1s
#   2025-01-18 19:49:12 /favicon.ico ............................... ~ 504.08ms
#   2025-01-18 19:49:27 /login ..................................... ~ 500.84ms
#   2025-01-18 19:49:27 /favicon.ico ................................. ~ 0.14ms
#   2025-01-18 19:50:04 /login ........................................... ~ 1s
#   2025-01-18 19:50:08 /favicon.ico ................................. ~ 0.73ms
#   2025-01-18 19:50:13 /login ........................................... ~ 3s
#   2025-01-18 19:50:16 /dashboard ................................. ~ 528.04ms
#   2025-01-18 19:50:24 / ............................................ ~ 7.24ms
#   2025-01-18 19:50:25 /build/assets/app-PCkFcrRW.css ............... ~ 4.50ms
#   2025-01-18 19:50:25 /static/logo.svg ............................. ~ 5.58ms
#   2025-01-18 19:50:25 /build/assets/app-D-FaURHc.js ................ ~ 7.22ms
#   2025-01-18 19:50:25 /static/gradient.jpg ......................... ~ 5.73ms
#   2025-01-18 19:50:30 / ................................................ ~ 2s
#   2025-01-18 19:50:31 /login ........................................... ~ 2s
#   2025-01-18 19:50:34 /dashboard ....................................... ~ 1s
#   2025-01-18 19:51:34 /dashboard ....................................... ~ 1s

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# 2025-01-02 23:47:33,409 [   5103]   WARN - #c.i.o.v.n.p.FSRecords - Records storage [/home/student/.cache/JetBrains/PhpStorm2024.2/caches/records.dat] was in use by process [OwnershipInfo{owner pid: 7, acquired at: 1733791816379}] which is not exist now (wasn't closed properly/crashed?) -> re-acquiring forcibly (pid-collision with [user: Optional[student], cmd: /home/student/.miniconda3/bin/python3.12, args: [/home/student/.miniconda3/bin/jupyter-notebook, --port=9999, index.ipynb], startTime: Optional[2025-01-02T22:38:23.920Z], totalTime: Optional[PT15.37S]] was successfully resolved)
# 2025-01-02 23:47:33,875 [   5569]   WARN - #c.i.o.v.n.p.PersistentFSLoader - [VFS load problem]: VFS wasn't safely shut down: records.wasClosedProperly is false
# Warning: Not allowed as a service: java.awt.Window.CustomTitleBarPeer
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# Warning: Service not supported: com.jetbrains.WindowDecorations
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-02 23:47:36,013 [   7707]   WARN - #c.i.i.u.UIThemeBean - Do not set theme id in JSON (value=4b6007f7-b596-4ee2-96f9-968d3d3eb392)
# 2025-01-02 23:47:37,240 [   8934]   WARN - #c.i.o.v.n.p.PersistentFSLoader - [VFS load problem]: NOT_CLOSED_PROPERLY recovered, no problems remain
# 2025-01-02 23:47:37,597 [   9291]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDefault.xml
# 2025-01-02 23:47:37,629 [   9323]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDarcula.xml
# Warning: Not allowed as a service: com.jetbrains.RoundedCornersManager
# 	at com.jetbrains.JBR$RoundedCornersManager__Holder.<clinit>(JBR.java:514)
# 	at com.jetbrains.JBR.isRoundedCornersManagerSupported(JBR.java:524)
# 	at com.intellij.ui.WindowRoundedCornersManager.isAvailable(WindowRoundedCornersManager.java:36)
# 	at com.intellij.ui.WindowRoundedCornersManager.configure(WindowRoundedCornersManager.java:24)
# 	at com.intellij.ui.messages.AlertDialog.<init>(AlertMessagesManager.kt:202)
# 	at com.intellij.ui.messages.AlertMessagesManager.showMessageDialog(AlertMessagesManager.kt:67)
# 	at com.intellij.ui.messages.MessagesServiceImpl.showMessageDialog(MessagesServiceImpl.java:54)
# 	at com.jetbrains.rdserver.ui.BackendMessagesService.showMessageDialog(BackendMessagesService.kt:33)
# 	at com.intellij.openapi.ui.MessageDialogBuilder$Message.show(MessageDialogBuilder.kt:179)
# 	at com.intellij.openapi.ui.MessageDialogBuilder$Message.show$default(MessageDialogBuilder.kt:175)
# 	at com.intellij.ide.trustedProjects.TrustedProjectsDialog$confirmOpeningOrLinkingUntrustedProjectAsync$choice$1.invokeSuspend(TrustedProjectsDialog.kt:67)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at com.intellij.openapi.application.impl.DispatchedRunnable.run(DispatchedRunnable.kt:44)
# 	at com.intellij.openapi.application.TransactionGuardImpl.runWithWritingAllowed(TransactionGuardImpl.java:229)
# 	at com.intellij.openapi.application.TransactionGuardImpl.access$100(TransactionGuardImpl.java:22)
# 	at com.intellij.openapi.application.TransactionGuardImpl$2.run(TransactionGuardImpl.java:211)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWithImplicitRead(AnyThreadWriteThreadingSupport.kt:122)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWithImplicitRead(ApplicationImpl.java:1162)
# 	at com.intellij.openapi.application.impl.FlushQueue.doRun(FlushQueue.java:78)
# 	at com.intellij.openapi.application.impl.FlushQueue.runNextEvent(FlushQueue.java:119)
# 	at com.intellij.openapi.application.impl.FlushQueue.flushNow(FlushQueue.java:41)
# 	at java.desktop/java.awt.event.InvocationEvent.dispatch(InvocationEvent.java:318)
# 	at java.desktop/java.awt.EventQueue.dispatchEventImpl(EventQueue.java:781)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:728)
# 	at java.desktop/java.awt.EventQueue$4.run(EventQueue.java:722)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:400)
# 	at java.base/java.security.ProtectionDomain$JavaSecurityAccessImpl.doIntersectionPrivilege(ProtectionDomain.java:87)
# 	at java.desktop/java.awt.EventQueue.dispatchEvent(EventQueue.java:750)
# 	at com.intellij.ide.IdeEventQueue.defaultDispatchEvent(IdeEventQueue.kt:696)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent$lambda$16(IdeEventQueue.kt:590)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWithoutImplicitRead(AnyThreadWriteThreadingSupport.kt:117)
# 	at com.intellij.ide.IdeEventQueue._dispatchEvent(IdeEventQueue.kt:590)
# 	at com.intellij.ide.IdeEventQueue.access$_dispatchEvent(IdeEventQueue.kt:73)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.invoke(IdeEventQueue.kt:353)
# 	at com.intellij.ide.IdeEventQueue$dispatchEvent$processEventRunnable$1$1$1.invoke(IdeEventQueue.kt:351)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke$lambda$0(IdeEventQueue.kt:1035)
# 	at com.intellij.openapi.application.WriteIntentReadAction.lambda$run$0(WriteIntentReadAction.java:24)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport.runWriteIntentReadAction(AnyThreadWriteThreadingSupport.kt:84)
# 	at com.intellij.openapi.application.impl.ApplicationImpl.runWriteIntentReadAction(ApplicationImpl.java:910)
# 	at com.intellij.openapi.application.WriteIntentReadAction.compute(WriteIntentReadAction.java:55)
# 	at com.intellij.openapi.application.WriteIntentReadAction.run(WriteIntentReadAction.java:23)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1036)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1036)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$10(IdeEventQueue.kt:351)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:397)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)
# [JetBrains Runtime] Detected slow X11, switched off alpha compositing of images. Control with -Dremote.x11.workaround={true|false|auto}.
# 2025-01-02 23:49:10,266 [ 101960]   WARN - #c.i.s.ComponentManagerImpl - `preload=NOT_HEADLESS` must be used only for core services (service=com.jetbrains.rdserver.toolWindow.BackendServerToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,271 [ 101965]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendUserManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,273 [ 101967]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.ports.CwmPortForwardingToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,273 [ 101967]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendCWMUserFocusHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,273 [ 101967]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeManagerService, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,273 [ 101967]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendProjectViewSync, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,273 [ 101967]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeEditorsHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,274 [ 101968]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeDebuggerHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,277 [ 101971]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeLookupSynchronizer, plugin=com.jetbrains.codeWithMe)
# 2025-01-02 23:49:10,647 [ 102341]   WARN - #c.i.u.x.Binding - No accessors for com.intellij.toolWindow.ToolWindowLayoutStorageManagerState. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-02 23:49:13,920 [ 105614]   WARN - #c.i.u.x.Binding - No accessors for java.awt.Color. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-02 23:49:16,661 [ 108355]   WARN - #c.i.o.p.i.ProjectFrameAllocator - Cannot load project in 10 seconds:
# - BlockingCoroutine{Active} [BlockingEventLoop@58167a5a]
# 	- "startApplication":StandaloneCoroutine{Active} [StartupAbortedExceptionHandler, startApplication, kotlinx.coroutines.UndispatchedMarker@39ae2ac7, Dispatchers.Default]
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@39ae2ac7, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@7c10a7c2, Dispatchers.Default]
# 			at java.base/java.lang.Thread.getStackTrace(Thread.java:2450)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDumpImpl(DebugProbesImpl.kt:332)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDump(DebugProbesImpl.kt:317)
# 			at com.intellij.diagnostic.CoroutineDumperKt.traceToDump(coroutineDumper.kt:325)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:298)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:131)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:59)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines$default(coroutineDumper.kt:50)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2$debugTask$1.invokeSuspend(ProjectFrameAllocator.kt:161)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@39ae2ac7, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@7c10a7c2, Dispatchers.Default]
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1.invokeSuspend(ProjectFrameAllocator.kt:357)
# 			- "tool window pane creation":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, tool window pane creation, kotlinx.coroutines.UndispatchedMarker@39ae2ac7, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@7c10a7c2, Dispatchers.Default]
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$initUi$3.invokeSuspend(ToolWindowSetInitializer.kt:91)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer.initUi(ToolWindowSetInitializer.kt:88)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$doInit$2.invokeSuspend(ToolWindowManagerImpl.kt:521)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.doInit(ToolWindowManagerImpl.kt:504)
# 				at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1$1$1.invokeSuspend(ProjectFrameAllocator.kt:363)
# 	- "Application":supervisor:ChildScope{Active}
# 		- "ApplicationImpl@679665061 container":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.platform.ide.provisioner)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x intellij.grid.core.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			-[x7 of] "(ApplicationImpl@679665061 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.history.integration.LocalHistoryImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 					- "com.intellij.history.integration.LocalHistoryImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at com.intellij.history.integration.LocalHistoryImpl$init$3.invokeSuspend(LocalHistoryImpl.kt:99)
# 			- "(ApplicationImpl@679665061 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.ide.startup.importSettings.jb.JbAfterRestartSettingsApplier":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.searcheverywhere.ml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.settingsSync)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x intellij.charts)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.textmate)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.intellij.plugins.markdown)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			-[x2 of] "(ApplicationImpl@679665061 x org.jetbrains.plugins.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.completion.full.line)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x intellij.platform.ijent.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x intellij.indexing.shared.core)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x intellij.grid.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.database.loaders.DataLoaderManager$Associations":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 					- "com.intellij.database.loaders.DataLoaderManager$Associations":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at com.intellij.database.loaders.DataLoaderManager$Associations$1.invokeSuspend(DataLoaderManager.kt:217)
# 						- "com.intellij.database.loaders.DataLoaderManager$Associations":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 							at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 							at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 							at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 							at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 							- "com.intellij.database.loaders.DataLoaderManager$Associations":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "(ApplicationImpl@679665061 x XPathView)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.tasks)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.intellij.intelliLang)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			-[x4 of] "(ApplicationImpl@679665061 x Docker)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x tanvd.grazi)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x Git4Idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.github)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x JavaScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x JavaScriptDebugger)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.database)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.database.dataSource.DataSourceModelStorageImpl$App":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x NodeJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.node-remote-interpreter)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.php)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.twig)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.php.psalm)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.intellij.php.tools.quality.phpstan)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.github.copilot)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.intellij.qodana)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$2.invokeSuspend(RdSettingsStorageService.kt:61)
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.EDT]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$3.invokeSuspend(RdSettingsStorageService.kt:71)
# 						- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.EDT]
# 							at com.intellij.platform.util.coroutines.flow.FlowKt$debounceBatch$1.invokeSuspend(flow.kt:147)
# 				- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 					- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 						- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 							at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2.invokeSuspend(ActionManagerImpl.kt:1273)
# 							- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 								at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 								- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 									at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2$1.invokeSuspend(ActionManagerImpl.kt:1275)
# 				- "com.intellij.remoteDev.tests.impl.DistributedTestHost":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x com.jetbrains.gateway.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.docker.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x AngularJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			-[x2 of] "ApplicationImpl@679665061 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "ApplicationImpl@679665061 container":ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "ApplicationImpl@679665061 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "com.intellij.ide.ScreenReaderStateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.ide.ScreenReaderStateManager":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "ApplicationImpl@679665061 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 				at com.intellij.ide.AgreementUpdater$execute$2.invokeSuspend(AgreementUpdater.kt:33)
# 			- "ApplicationImpl@679665061 container":StandaloneCoroutine{Completing} [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 				- "ApplicationImpl@679665061 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.checkPreviousExternalUploadResult(StatisticsJobsScheduler.kt:129)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$2.invokeSuspend(StatisticsJobsScheduler.kt:44)
# 				- "ApplicationImpl@679665061 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.runValidationRulesUpdate(StatisticsJobsScheduler.kt:106)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$4.invokeSuspend(StatisticsJobsScheduler.kt:50)
# 			- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger.logApplicationStateRegularly(FUStateUsagesLogger.kt:152)
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger$1.invokeSuspend(FUStateUsagesLogger.kt:53)
# 			- "com.intellij.openapi.vfs.newvfs.persistent.ExecuteOnCoroutine":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "PersistentFsLoader":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061), Dispatchers.IO]
# 			- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents$1.invokeSuspend(FeatureUsageSettingsEvents.kt:66)
# 			- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "FileTypeManager Redetect":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061), LimitedDispatcher@1f73105b]
# 				- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.openapi.fileTypes.impl.AlarmAdapterKt$singleAlarm$1.invokeSuspend(AlarmAdapter.kt:24)
# 					- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "ApplicationImpl@679665061 container":ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.diagnostic.PerformanceWatcherImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.diagnostic.PerformanceWatcherImpl$1.invokeSuspend(PerformanceWatcherImpl.kt:96)
# 					- "com.intellij.diagnostic.PerformanceWatcherImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 				- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.diagnostic.SamplingTask$1.invokeSuspend(SamplingTask.kt:36)
# 			- "com.intellij.util.net.ssl.CertificateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.IdeTooltipManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.ui.customization.CustomActionsSchema":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.ui.laf.LafManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.plugins.marketplace.MarketplaceRequests":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.openapi.editor.impl.EditorFactoryImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "refresh requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), ModalityState.NON_MODAL, Dispatchers.Default]
# 					at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 					at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 					at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$1.invokeSuspend(SaveAndSyncHandlerImpl.kt:72)
# 					- "refresh requests flow processing":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), ModalityState.NON_MODAL, Dispatchers.Default]
# 				- "save requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$2.invokeSuspend(SaveAndSyncHandlerImpl.kt:86)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl.listenIdleAndActivate(SaveAndSyncHandlerImpl.kt:216)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$3.invokeSuspend(SaveAndSyncHandlerImpl.kt:116)
# 					- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":ProducerCoroutine{Completing} [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 							at kotlinx.coroutines.flow.internal.ChannelLimitedFlowMerge$collectTo$2$1.invokeSuspend(Merge.kt:92)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.util.CoroutinesKt$awaitCancellationAndInvoke$1.invokeSuspend(coroutines.kt:28)
# 			- "com.intellij.openapi.wm.impl.WindowButtonsConfiguration":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.openapi.progress.impl.PlatformTaskSupport":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.openapi.wm.impl.customFrameDecorations.frameButtons.LinuxIconThemeConfiguration":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.util.indexing.FileBasedIndexImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.util.indexing.diagnostic.IndexDiagnosticDumper":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.ide.RecentProjectsManagerBase$1.invokeSuspend(RecentProjectsManagerBase.kt:118)
# 					- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "org.jetbrains.ide.BuiltInServerManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.ui.laf.LafDynamicPluginManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 					at com.intellij.ide.ui.html.GlobalStyleSheetUpdateService$init$2.invokeSuspend(GlobalStyleSheetHolder.kt:102)
# 					- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "com.intellij.platform.ide.impl.presentationAssistant.PresentationAssistant":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.actionMacro.ActionMacroManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.codeInsight.intention.impl.IntentionShortcutManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "(ApplicationImpl@679665061 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.openapi.updateSettings.impl.UpdateCheckerHelper":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.openapi.updateSettings.impl.PluginAutoUpdateService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 			- "com.intellij.ide.IdleTracker":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 				- "com.intellij.ide.IdleTracker":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@679665061)]
# 					- "Idle listener: com.intellij.ide.L.r$$Lambda/0x0000000100d0c9a8":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at com.intellij.ide.IdleTracker$addIdleListener$1.invokeSuspend(IdleTracker.kt:79)
# 						- "Idle listener: com.intellij.ide.L.r$$Lambda/0x0000000100d0c9a8":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 			- "ApplicationImpl@679665061 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@679665061), Dispatchers.Default]
# 				at com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEventScheduler$initialize$1.invokeSuspend(FeatureUsageSettingsEventScheduler.kt:32)
# 			- "DefaultProjectImpl@990617196 container":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.editorconfig.editorconfigjetbrains)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				-[x6 of] "(DefaultProjectImpl@990617196 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.performancePlugin)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.apacheConfig)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.swagger)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x intellij.indexing.shared)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x intellij.grid.impl)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x XPathView)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.tasks)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.tasks.timeTracking)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.intellij.intelliLang)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x PerforceDirectPlugin)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x Git4Idea)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x JavaScript)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.database)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.stylelint)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x NodeJS)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x tslint)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.node-remote-interpreter)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x intellij.prettierJS)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.behat)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.phpspec)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.jetbrains.plugins.phpstorm-docker)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.drupal)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.joomla)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.twig)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.wordPress)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.phing)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.php.psalm)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.workshop)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.intellij.php.tools.quality.phpstan)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.php.blade)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x Karma)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x org.intellij.qodana)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# 				- "(DefaultProjectImpl@990617196 x AngularJS)":supervisor:ChildScope{Active} [ComponentManager(DefaultProjectImpl@990617196)]
# ...
# 				- "IdeMenuBarHelper":ProducerCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.EDT]
# 					at com.intellij.platform.util.coroutines.flow.FlowKt$throttle$1.invokeSuspend(flow.kt:46)
# 					- "IdeMenuBarHelper":StandaloneCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.EDT]
# 						at com.intellij.platform.util.coroutines.flow.FlowKt$throttle$1$latchJob$1.invokeSuspend(flow.kt:41)
# 					- "IdeMenuBarHelper":ProducerCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.EDT]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 	- "IdeRootPane":StandaloneCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.Default]
# 		at com.intellij.openapi.wm.impl.IdeRootPane$installNorthComponents$2.invokeSuspend(IdeRootPane.kt:624)
# 		- "IdeRootPane":ProducerCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.Default]
# 			- "IdeRootPane":ProducerCoroutine{Active}, state: SUSPENDED [ModalityState.ANY, Dispatchers.Default]
# 				at com.intellij.platform.navbar.frontend.NavBarRootPaneExtension$component$1.invokeSuspend(NavBarRootPaneExtension.kt:79)
#
# - StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.EDT]
# 	at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanel$1.invokeSuspend(StaticNavBarPanel.kt:86)
# 	- ProducerCoroutine{Active}, state: CREATED [Dispatchers.EDT]
#
# - StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanelKt$staticNavBarPanel$1.invokeSuspend(StaticNavBarPanel.kt:58)
# 	- ProducerCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 		at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 		- StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 			at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanelKt$staticNavBarPanel$1$1.invokeSuspend(StaticNavBarPanel.kt:60)
# 			- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 				at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanelKt$staticNavBarPanel$handleWindow$2.invokeSuspend(StaticNavBarPanel.kt:48)
# 				at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanelKt.staticNavBarPanel$handleWindow(StaticNavBarPanel.kt:39)
# 				at com.intellij.platform.navbar.frontend.ui.StaticNavBarPanelKt$staticNavBarPanel$1$1$1$1.invokeSuspend(StaticNavBarPanel.kt:64)
# 				- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 					at com.intellij.platform.navbar.frontend.vm.impl.NavBarVmImpl$1.invokeSuspend(NavBarVmImpl.kt:41)
# 					- "com.intellij.platform.navbar.frontend.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.platform.navbar.frontend.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 							at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 							- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 								at com.intellij.platform.navbar.frontend.NavBarService$contextItems$1.invokeSuspend(NavBarService.kt:87)
# 				- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 					at com.intellij.platform.navbar.frontend.vm.impl.NavBarVmImpl$2.invokeSuspend(NavBarVmImpl.kt:51)
# 					- "com.intellij.platform.navbar.frontend.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 							at com.intellij.platform.util.coroutines.flow.FlowKt$zipWithNext$1.invokeSuspend(flow.kt:107)
# 							at kotlinx.coroutines.flow.AbstractFlow.collect(Flow.kt:226)
# 							at com.intellij.platform.navbar.frontend.vm.impl.NavBarVmImpl$handleSelectionChange$2.invokeSuspend(NavBarVmImpl.kt:114)
# 				- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 					at com.intellij.platform.navbar.frontend.vm.impl.NavBarVmImpl$3.invokeSuspend(NavBarVmImpl.kt:54)
# 					- "com.intellij.platform.navbar.frontend.NavBarService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 				- "com.intellij.platform.navbar.frontend.NavBarService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@1029193701), LimitedDispatcher@646d5c80]
# 					at kotlinx.coroutines.flow.FlowKt__CollectKt$launchIn$1.invokeSuspend(Collect.kt:46)
#
# -[x2 of] StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.ide.Q.U.invokeSuspend(helper.kt)
#
# - SupervisorJobImpl{Active}
# 	- "PreconditionsService":StandaloneCoroutine{Active}, state: SUSPENDED [Dispatchers.Default]
# 		at kotlinx.coroutines.TimeoutKt.withTimeoutOrNull(Timeout.kt:101)
#
# -[x2 of] StandaloneCoroutine{Completed}, state: SUSPENDED [Dispatchers.Default]
# 	at com.intellij.ide.Q.U.invokeSuspend(helper.kt)
#
# 2025-01-02 23:49:17,398 [ 109092]   WARN - #c.i.d.PerformanceWatcherImpl - UI was frozen for 10900ms, details saved to /home/student/.cache/JetBrains/PhpStorm2024.2/log/threadDumps-freeze-20250102-234911-PS-242.23726.107-TransactionGuardImpl$2.run-10sec
# 2025-01-02 23:49:17,689 [ 109383]   WARN - #c.i.o.a.Application - issue detected: ide.script.launcher.used
# 2025-01-02 23:49:19,287 [ 110981]   WARN - #com.github.copilot.lang.agent.vscodeRpc.CancellableAsyncPromise - Not signed in to Copilot agent
# com.github.copilot.lang.agent.NotSignedInException: Not signed in to Copilot agent
# 	at com.github.copilot.lang.agent.vscodeRpc.DefaultJsonRpcMessageHandler.handleErrorResponse(DefaultJsonRpcMessageHandler.java:210)
# 	at com.github.copilot.lang.agent.vscodeRpc.DefaultJsonRpcMessageHandler.handleJsonMessage(DefaultJsonRpcMessageHandler.java:81)
# 	at com.github.copilot.lang.agent.vscodeRpc.VSCodeJsonRpcParser.processPendingContent(VSCodeJsonRpcParser.java:96)
# 	at com.github.copilot.lang.agent.vscodeRpc.VSCodeJsonRpcParser.appendLocked(VSCodeJsonRpcParser.java:76)
# 	at com.github.copilot.lang.agent.vscodeRpc.VSCodeJsonRpcParser.append(VSCodeJsonRpcParser.java:44)
# 	at com.github.copilot.lang.agent.vscodeRpc.AgentProcessHandler$1.onTextAvailable(AgentProcessHandler.java:37)
# 	at com.intellij.execution.process.ProcessHandler$2.onTextAvailable(ProcessHandler.java:292)
# 	at com.intellij.execution.process.ProcessHandler.notifyTextAvailable(ProcessHandler.java:223)
# 	at com.intellij.execution.process.BaseOSProcessHandler$SimpleOutputReader.onTextAvailable(BaseOSProcessHandler.java:133)
# 	at com.intellij.util.io.BaseOutputReader.processInput(BaseOutputReader.java:213)
# 	at com.intellij.util.io.BaseOutputReader.readAvailableBlocking(BaseOutputReader.java:151)
# 	at com.intellij.util.io.BaseDataReader.readAvailable(BaseDataReader.java:72)
# 	at com.intellij.util.io.BaseDataReader.doRun(BaseDataReader.java:153)
# 	at com.intellij.util.ConcurrencyUtil.runUnderThreadName(ConcurrencyUtil.java:218)
# 	at com.intellij.util.io.BaseDataReader.lambda$start$0(BaseDataReader.java:48)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:317)
# 	at com.intellij.util.concurrency.ContextRunnable.run(ContextRunnable.java:27)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:735)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:732)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:400)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1.run(Executors.java:732)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# 2025-01-02 23:49:24,425 [ 116119]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./syntaxes/asp-vb-net.tmLanguage.json` in bundle `/opt/PhpStorm-242.23726.107/plugins/textmate/lib/bundles/vb`
# 2025-01-02 23:49:25,117 [ 116811]   WARN - #c.i.u.x.Binding - No accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-02 23:49:25,579 [ 117273]   WARN - #c.i.u.x.Binding - No accessors for java.time.ZonedDateTime. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-02 23:49:25,999 [ 117693]   WARN - #o.j.p.t.TextMateService - Cannot find referenced file `./syntaxes/asp-vb-net.tmLanguage.json` in bundle `/opt/PhpStorm-242.23726.107/plugins/textmate/lib/bundles/vb`
# 2025-01-02 23:49:34,258 [ 125952]   WARN - #c.i.o.a.i.ActionUpdater - 5149 ms total to grab EDT 1 times to expand ToolWindowHeader$2#expandGroup@ToolwindowTitle (com.intellij.toolWindow.ToolWindowHeader$2). Use `ActionUpdateThread.BGT`.
# 2025-01-02 23:49:38,189 [ 129883]   WARN - #c.i.o.a.i.ActionUpdater - 2449 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#presentation@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction(id=Debug))
# 2025-01-02 23:49:38,194 [ 129888]   WARN - #c.i.o.a.i.ActionUpdater - 2447 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#presentation@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction(id=Run))
# 2025-01-02 23:49:39,608 [ 131302]   WARN - #c.i.u.x.Binding - No accessors for com.intellij.ide.util.TipsUsageManager$State. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-02 23:49:41,293 [ 132987]   WARN - #c.i.o.a.i.ActionUpdater - 1188 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#presentation@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction(id=Run))
# 2025-01-02 23:49:41,295 [ 132989]   WARN - #c.i.o.a.i.ActionUpdater - 1190 ms to call on BGT ExecutorRegistryImpl$ExecutorAction#presentation@NewUiRunToolbar (com.intellij.execution.ExecutorRegistryImpl$ExecutorAction(id=Debug))
# MESA: error: ZINK: failed to choose pdev
# glx: failed to create drisw screen
# 2025-01-02 23:49:53,438 [ 145132]   WARN - #org.intellij.plugins.markdown.ui.preview.jcef.impl.JcefBrowserPipeImpl - No subscribers for documentReady!
# Attached data:
# 2025-01-02 23:50:04,303 [ 155997]   WARN - org.eclipse.lsp4j.jsonrpc.services.GenericEndpoint - Unsupported notification method: @/tailwindCSS/projectInitialized
# 2025-01-02 23:50:37,752 [ 189446]   WARN - #c.j.p.f.g.s.SymfonyComponentUtils - Unexpected End-of-input in prolog
#  at [row,col {unknown-source}]: [1,1]
# org.jdom.JDOMException: Unexpected End-of-input in prolog
#  at [row,col {unknown-source}]: [1,1]
# 	at com.intellij.openapi.util.JDOMUtil.load(JDOMUtil.java:294)
# 	at com.intellij.openapi.util.JDOMUtil.load(JDOMUtil.java:244)
# 	at com.jetbrains.php.framework.generators.symfonycomponent.SymfonyComponentUtils.getFrameworkCommandsVersion2(SymfonyComponentUtils.java:141)
# 	at com.jetbrains.php.framework.generators.symfony.SymfonyVersion$4.getCommands(SymfonyVersion.java:233)
# 	at com.jetbrains.php.framework.generators.symfonycomponent.SymfonyComponentUtils.getFrameworkCommands(SymfonyComponentUtils.java:122)
# 	at com.jetbrains.php.framework.generators.symfonycomponent.SymfonyComponentDescriptionProvider.getFrameworkCommands(SymfonyComponentDescriptionProvider.java:36)
# 	at com.jetbrains.php.framework.generators.laravel.LaravelCommandLineComposerConfig.lambda$updateSettings$3(LaravelCommandLineComposerConfig.java:71)
# 	at com.intellij.openapi.application.impl.AnyThreadWriteThreadingSupport$executeOnPooledThread$1.run(AnyThreadWriteThreadingSupport.kt:134)
# 	at java.base/java.util.concurrent.Executors$RunnableAdapter.call(Executors.java:572)
# 	at com.intellij.util.concurrency.ContextCallable.call(ContextCallable.java:32)
# 	at com.intellij.util.concurrency.CancellationCallable$call$1.invoke(CancellationCallable.kt:22)
# 	at com.intellij.util.concurrency.Propagation$runAsCoroutine$deferred$1.invokeSuspend(propagation.kt:229)
# 	at com.intellij.util.concurrency.Propagation$runAsCoroutine$deferred$1.invoke(propagation.kt)
# 	at com.intellij.util.concurrency.Propagation$runAsCoroutine$deferred$1.invoke(propagation.kt)
# 	at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:27)
# 	at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:90)
# 	at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:123)
# 	at kotlinx.coroutines.BuildersKt__Builders_commonKt.async(Builders.common.kt:87)
# 	at kotlinx.coroutines.BuildersKt.async(Unknown Source)
# 	at com.intellij.util.concurrency.Propagation.runAsCoroutine(propagation.kt:224)
# 	at com.intellij.util.concurrency.CancellationCallable.call(CancellationCallable.kt:21)
# 	at java.base/java.util.concurrent.FutureTask.run(FutureTask.java:317)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor.runWorker(ThreadPoolExecutor.java:1144)
# 	at java.base/java.util.concurrent.ThreadPoolExecutor$Worker.run(ThreadPoolExecutor.java:642)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:735)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1$1.run(Executors.java:732)
# 	at java.base/java.security.AccessController.doPrivileged(AccessController.java:400)
# 	at java.base/java.util.concurrent.Executors$PrivilegedThreadFactory$1.run(Executors.java:732)
# 	at java.base/java.lang.Thread.run(Thread.java:1583)
# Caused by: com.fasterxml.aalto.WFCException: Unexpected End-of-input in prolog
#  at [row,col {unknown-source}]: [1,1]
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.throwWfe(StreamReaderImpl.java:1777)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.throwUnexpectedEOI(StreamReaderImpl.java:1796)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.handlePrologEoi(StreamReaderImpl.java:1756)
# 	at com.fasterxml.aalto.stax.StreamReaderImpl.next(StreamReaderImpl.java:810)
# 	at com.intellij.openapi.util.SafeStAXStreamBuilderKt.buildJdom(SafeStAXStreamBuilder.kt:124)
# 	at com.intellij.openapi.util.JDOMUtil.load(JDOMUtil.java:287)
# 	... 28 more
# 2025-01-02 23:52:12,808 [ 284502]   WARN - #c.i.o.v.i.VirtualFilePointerManagerImpl - VirtualFilePointerManagerImpl.prepareChange(1 events): 0ms.; total pointers: 5; afterElapsedMs: 4003ms.; eventList.size(): 2; toFirePointers.size(): 1; toUpdateNodes.size(): 1; eventList: [com.intellij.javascript.nodejs.library.node_modules.NodeModulesVfsEventsSession$processWhenAvailable$1@3b69fee4 -> [(disposed)], Multicaster -> [(disposed)]]
# 2025-01-02 23:52:13,903 [ 285597]   WARN - #c.i.o.v.n.RefreshSession - Long VFS change processing (5134ms, 1 events): [Compound VfsEvent[create dir 'file:///home/student/Desktop/PHP_labs/zad1/php_2024_iad_g2_bartosz_irzyk/09_laravel_tdd/project/vendor']; induced: []]
# ^C

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3

# %%
seleniumServer.kill()

# %%
# %cd ..

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
