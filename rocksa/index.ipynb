# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 44f12272c61e71ac265a8cf06d32fa92e3451e56aea0f30f3d31a973a3026dec

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update sebastian/phpcpd
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Package sebastian/phpcpd is abandoned, you should avoid using it. No replacement was suggested.
# Generating autoload files
# 5 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   andreiio/blade-remix-icon ............................................. DONE
#   blade-ui-kit/blade-icons .............................................. DONE
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/pail .......................................................... DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   livewire/livewire ..................................................... DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#
# 108 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.68.1 Persian Successor by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.6
# Running analysis on 1 core sequentially.
# You can enable parallel runner and speed up the analysis! Please see ]8;;https://cs.symfony.com/doc/usage.html\usage docs]8;;\ for more information.
# Loaded config default from "/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    0/128 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  13/128 [▓▓░░░░░░░░░░░░░░░░░░░░░░░░░░]  10%  26/128 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20%  39/128 [▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░]  30%  52/128 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  40% 103/128 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 116/128 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 128/128 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#    1) app/Models/OrderItems.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# @@ -20,7 +20,8 @@
#
#      }
#
# -    public function rocks(){
# +    public function rocks()
# +    {
#
#          return $this -> belongsTo(Rock::class);
#
#
#       ----------- end diff -----------
#
#    2) app/Models/User.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# @@ -57,4 +57,3 @@
#          return $this->hasMany(Order::class);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    3) app/Models/Rock.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# @@ -35,4 +35,3 @@
#
#
#  }
# -
#
#       ----------- end diff -----------
#
#    4) app/Http/Controllers/OrderController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# @@ -1,4 +1,5 @@
#  <?php
# +
#  namespace App\Http\Controllers;
#
#  use App\Http\Requests\StoreOrderRequest;
# @@ -64,5 +65,3 @@
#      }
#
#  }
# -
# -
#
#       ----------- end diff -----------
#
#    5) app/Http/Controllers/orderItemsController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# @@ -8,6 +8,7 @@
#  use App\Models\OrderItems;
#  use Illuminate\Http\RedirectResponse;
#  use Illuminate\View\View;
# +
#  class orderItemsController extends Controller
#  {
#      public function store(StoreOrderItemsRequest $request): RedirectResponse
#
#       ----------- end diff -----------
#
#    6) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# @@ -8,7 +8,6 @@
#  // use Database\Seeders\InsertTestSeeder;
#  use Database\Seeders\InsertTestSeeder;
#
# -
#  class DatabaseSeeder extends Seeder
#  {
#      /**
#
#       ----------- end diff -----------
#
#    7) database/seeders/InsertTestSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# @@ -5,6 +5,7 @@
#  use Illuminate\Database\Seeder;
#  use Illuminate\Support\Facades\DB;
#  use Illuminate\Support\Facades\Hash;
# +
#  // use Illuminate\Support\Facades\File;
#
#  class InsertTestSeeder extends Seeder
# @@ -73,4 +74,3 @@
#          ]);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    8) database/migrations/2025_01_11_create_orders_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# @@ -5,7 +5,6 @@
#  use Illuminate\Support\Facades\Schema;
#
#  return new class () extends Migration {
# -
#      /**
#       * Run the migrations.
#       *
# @@ -39,4 +38,3 @@
#          Schema::dropIfExists('orders');
#      }
#  };
# -
#
#       ----------- end diff -----------
#
#
# Found 8 of 128 files that can be fixed in 0.525 seconds, 20.00 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#    0/119 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  20/119 [▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░░]  16%  60/119 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░]  50%  80/119 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░]  67% 100/119 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░]  84% 119/119 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/Cart.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\Cart::$cart type has no value type specified in
#          iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   14     Property App\Livewire\Cart::$listeners has no type specified.
#          🪪  missingType.property
#   21     Method App\Livewire\Cart::mount() has no return type specified.
#          🪪  missingType.return
#   26     Method App\Livewire\Cart::toggleCart() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has no return type
#          specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $image with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $name with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $price with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   32     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   34     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   35     Binary operation "+=" between mixed and 1 results in an error.
#          🪪  assignOp.invalid
#   35     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   37     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   51     Method App\Livewire\Cart::updateQuantity() has no return type
#          specified.
#          🪪  missingType.return
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $change with
#          no type specified.
#          🪪  missingType.parameter
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   53     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   55     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   56     Binary operation "+=" between mixed and mixed results in an error.
#          🪪  assignOp.invalid
#   56     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Comparison operation "<=" between (array|float|int) and 0 results in
#          an error.
#          🪪  smallerOrEqual.invalid
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has no return type
#          specified.
#          🪪  missingType.return
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has parameter
#          $productId with no type specified.
#          🪪  missingType.parameter
#   70     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   72     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   73     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   88     Method App\Livewire\Cart::clearCart() has no return type specified.
#          🪪  missingType.return
#   100    Method App\Livewire\Cart::refreshCart() has no return type specified.
#          🪪  missingType.return
#   102    Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   105    Method App\Livewire\Cart::render() has no return type specified.
#          🪪  missingType.return
#   109    Method App\Livewire\Cart::proceedToCheckout() has no return type
#          specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/RockCard.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\RockCard::$data type has no value type
#          specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   17     Method App\Livewire\RockCard::mount() has no return type specified.
#          🪪  missingType.return
#   38     Method App\Livewire\RockCard::render() has invalid return type
#          App\Livewire\View.
#          🪪  class.notFound
#  ------ --------------------------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Models/Order.php
#  ------ ----------------------------------------------------------------
#   22     Method App\Models\Order::user() has no return type specified.
#          🪪  missingType.return
#   27     Method App\Models\Order::items() has no return type specified.
#          🪪  missingType.return
#  ------ ----------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/OrderItems.php
#  ------ ---------------------------------------------------------------------
#   16     Method App\Models\OrderItems::order() has no return type specified.
#          🪪  missingType.return
#   23     Method App\Models\OrderItems::rocks() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------
#   Line   app/Models/Rock.php
#  ------ --------------------------------------------------------------------
#   26     Method App\Models\Rock::orderItems() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Models\Rock::user() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Models/User.php
#  ------ ----------------------------------------------------------------
#   50     Method App\Models\User::rocks() has no return type specified.
#          🪪  missingType.return
#   55     Method App\Models\User::orders() has no return type specified.
#          🪪  missingType.return
#  ------ ----------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   tests/Unit/ExampleTest.php
#  ------ -----------------------------------------------------------------------
#   19     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   19     No error with identifier method.alreadyNarrowedType is reported on
#          line 19.
#   24     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   24     No error with identifier method.alreadyNarrowedType is reported on
#          line 24.
#   29     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   29     No error with identifier method.alreadyNarrowedType is reported on
#          line 29.
#   33     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   33     No error with identifier method.alreadyNarrowedType is reported on
#          line 33.
#   37     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   37     No error with identifier method.alreadyNarrowedType is reported on
#          line 37.
#   41     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   41     No error with identifier method.alreadyNarrowedType is reported on
#          line 41.
#   46     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   46     No error with identifier method.alreadyNarrowedType is reported on
#          line 46.
#   51     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   51     No error with identifier method.alreadyNarrowedType is reported on
#          line 51.
#   56     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   56     No error with identifier method.alreadyNarrowedType is reported on
#          line 56.
#   61     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   61     No error with identifier method.alreadyNarrowedType is reported on
#          line 61.
#   66     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   66     No error with identifier method.alreadyNarrowedType is reported on
#          line 66.
#  ------ -----------------------------------------------------------------------
#
#
#  [ERROR] Found 66 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# No clones found.
#
# Time: 00:00.012, Memory: 4.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done

# %%
! php artisan migrate:fresh
# Out:
#    INFO  Preparing database.
#
#   Creating migration table ...................................... 76.57ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ......................... 438.08ms DONE
#   0001_01_01_000001_create_cache_table ......................... 199.72ms DONE
#   0001_01_01_000002_create_jobs_table .......................... 524.51ms DONE
#   2024_11_29_145411_create_comments_table ...................... 160.60ms DONE
#   2024_12_07_094911_create_books_table ......................... 184.81ms DONE
#   2025_01_10_create_rocks_table ................................. 71.41ms DONE
#   2025_01_11_create_orders_table ............................... 330.07ms DONE
#   2025_01_14_151420_add_user_id_to_rocks_table ................. 267.06ms DONE
#   2025_01_14_153906_order_items_table .......................... 440.40ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 285 ms DONE
#
#   Database\Seeders\InsertTestSeeder .................................. RUNNING
#   Database\Seeders\InsertTestSeeder .............................. 700 ms DONE
#
#   2025-01-19 17:40:20 /login ..................................... ~ 503.04ms
#   2025-01-19 17:40:20 /dashboard ................................... ~ 2.30ms
#   2025-01-19 17:40:21 /build/assets/app-PwOqhazG.css ............... ~ 0.31ms
#   2025-01-19 17:40:21 /build/assets/app-D-FaURHc.js ................ ~ 2.82ms
#   2025-01-19 17:40:21 /static/logo.svg ............................. ~ 8.01ms
#   2025-01-19 17:40:21 /static/gradient.jpg ......................... ~ 1.02ms
#   2025-01-19 17:40:21 /favicon.ico ................................ ~ 20.90ms
#   2025-01-19 17:40:25 /carttestlivewire ................................ ~ 1s
#   2025-01-19 17:40:26 /build/assets/app-D-FaURHc.js ................ ~ 0.19ms
#   2025-01-19 17:40:26 /build/assets/app-PwOqhazG.css ............... ~ 5.17ms
#   2025-01-19 17:40:26 /livewire/livewire.js ........................ ~ 3.61ms
#   2025-01-19 17:40:26 /static/amethyst2.jpg ...................... ~ 506.11ms
#   2025-01-19 17:40:26 /static/amethyst1.jpg ...................... ~ 518.28ms
#   2025-01-19 17:40:26 /static/amethyst.jpg ....................... ~ 522.82ms
#   2025-01-19 17:40:26 /static/amethyst2.jpg ....................... ~ 10.87ms
#   2025-01-19 17:40:27 /favicon.ico ................................. ~ 0.07ms
#   2025-01-19 17:40:30 /livewire/update ........................... ~ 511.01ms
#   2025-01-19 17:40:35 /build/assets/app-PwOqhazG.css ............... ~ 0.42ms
#   2025-01-19 17:40:56 /carttestlivewire .......................... ~ 500.77ms
#   2025-01-19 17:40:56 /favicon.ico ................................. ~ 0.84ms

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧
# up to date, audited 172 packages in 2s
# ⠧
# ⠧40 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# found 0 vulnerabilities
# ⠧

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.4.11 building for production...
# transforming (1) resources/js/app.jstransforming (2) resources/js/bootstrap.jstransforming (3) resources/css/app.csstransforming (23) node_modules/axios/lib/helpers/validator.js✓ 53 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-PwOqhazG.css  41.12 kB │ gzip:  7.40 kB
# public/build/assets/app-D-FaURHc.js   34.85 kB │ gzip: 14.03 kB
# ✓ built in 1.85s
# ⠙

# %%
! php artisan test
# Out:
#    FAIL  Tests\Unit\ExampleTest
#   ✓ that true is true
#   ⨯ add to cart                                                          0.01s
#   ⨯ remove from cart
#   ⨯ edit name
#   ⨯ edit email
#   ⨯ edit phone number
#   ⨯ edit password
#   ⨯ calculate cost
#   ⨯ add rock
#   ⨯ remove rock
#   ⨯ add filter
#   ⨯ remove filter
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                         2.83s
#   ✓ users can authenticate using the login screen                        0.26s
#   ✓ users can not authenticate with invalid password                     0.44s
#   ✓ users can logout                                                     0.19s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.22s
#   ✓ email can be verified                                                0.26s
#   ✓ email is not verified with invalid hash                              0.26s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.25s
#   ✓ password can be confirmed                                            0.20s
#   ✓ password is not confirmed with invalid password                      0.42s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.24s
#   ✓ reset password link can be requested                                 0.24s
#   ✓ reset password screen can be rendered                                0.26s
#   ✓ password can be reset with valid token                               0.27s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.30s
#   ✓ correct password must be provided to update password                 0.26s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.24s
#   ✓ new users can register                                               0.26s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.24s
#
#    PASS  Tests\Feature\ProfileTest
#   ✓ profile page is displayed                                            0.24s
#   ✓ profile information can be updated                                   0.21s
#   ✓ email verification status is unchanged when the email address is un… 0.27s
#   ✓ user can delete their account                                        0.22s
#   ✓ correct password must be provided to delete account                  0.20s
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add to cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:19
#      15▕     }
#      16▕     // Add to cart
#      17▕     public function test_add_to_cart(): void
#      18▕     {
#   ➜  19▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#
#   1   tests/Unit/ExampleTest.php:19
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove from cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:24
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#   ➜  24▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#
#   1   tests/Unit/ExampleTest.php:24
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit name
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:29
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#   ➜  29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:29
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit email
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:33
#      29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#   ➜  33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:33
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit phone number
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:37
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#   ➜  37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#      41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:37
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit password
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:41
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#   ➜  41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#
#   1   tests/Unit/ExampleTest.php:41
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > calculate cost
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:46
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#   ➜  46▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#
#   1   tests/Unit/ExampleTest.php:46
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:51
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#   ➜  51▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#
#   1   tests/Unit/ExampleTest.php:51
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:56
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#   ➜  56▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#
#   1   tests/Unit/ExampleTest.php:56
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:61
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#   ➜  61▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#
#   1   tests/Unit/ExampleTest.php:61
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:66
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#   ➜  66▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      67▕     }
#      68▕ }
#      69▕
#
#   1   tests/Unit/ExampleTest.php:66
#
#
#   Tests:    11 failed, 25 passed (74 assertions)
#   Duration: 8.93s

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.24.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done
# Out:
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 17:31:23.107 INFO [LoggingOptions.configureLogEncoding] - Using the system default encoding
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
# 17:31:23.126 INFO [OpenTelemetryTracer.createTracer] - Using OpenTelemetry for tracing
#   Press Ctrl+C to stop the server
#
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 17:31:24.514 INFO [NodeOptions.getSessionFactories] - Detected 4 available processors
# 17:31:24.520 INFO [NodeOptions.discoverDrivers] - Looking for existing drivers on the PATH.
# 17:31:24.521 INFO [NodeOptions.discoverDrivers] - Add '--selenium-manager true' to the startup command to setup drivers automatically.
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 17:31:25.288 WARN [SeleniumManager.lambda$runCommand$1] - Exception managing chrome: Unable to discover proper chromedriver version in offline mode
# 17:31:25.324 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper msedgedriver version in offline mode
# 17:31:25.354 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper geckodriver version in offline mode
# 17:31:25.387 INFO [NodeOptions.report] - Adding Edge for {"browserName": "MicrosoftEdge","platformName": "linux"} 4 times
# 17:31:25.389 INFO [NodeOptions.report] - Adding Firefox for {"browserName": "firefox","platformName": "linux"} 4 times
# 17:31:25.391 INFO [NodeOptions.report] - Adding Chrome for {"browserName": "chrome","platformName": "linux"} 4 times
# 17:31:25.423 INFO [Node.<init>] - Binding additional locator mechanisms: relative
# 17:31:25.455 INFO [GridModel.setAvailability] - Switching Node 95ec0897-ac88-4937-9435-c0fb8f7cb7c9 (uri: http://172.17.0.1:4444) from DOWN to UP
# 17:31:25.455 INFO [LocalDistributor.add] - Added node 95ec0897-ac88-4937-9435-c0fb8f7cb7c9 at http://172.17.0.1:4444. Health check every 120s
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 17:31:25.760 INFO [Standalone.execute] - Started Selenium Standalone 4.24.0 (revision 748ffc9bc3): http://172.17.0.1:4444

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done
# Out:
#   2025-01-19 17:31:26 .............................................. ~ 0.48ms
#   2025-01-19 17:39:22 / ................................................ ~ 1s
#   2025-01-19 17:39:23 /build/assets/app-PwOqhazG.css ............... ~ 0.25ms
#   2025-01-19 17:39:23 /build/assets/app-D-FaURHc.js ................ ~ 0.99ms
#   2025-01-19 17:39:23 /static/logo.svg ............................. ~ 4.44ms
#   2025-01-19 17:39:23 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-19 17:39:23 /favicon.ico ................................. ~ 0.11ms
#   2025-01-19 17:39:27 /login ........................................... ~ 1s
#   2025-01-19 17:39:28 /build/assets/app-PwOqhazG.css ............... ~ 1.08ms
#   2025-01-19 17:39:28 /build/assets/app-D-FaURHc.js ................ ~ 3.09ms
#   2025-01-19 17:39:28 /static/logo.svg ............................. ~ 5.51ms
#   2025-01-19 17:39:28 /static/gradient.jpg ......................... ~ 0.84ms
#   2025-01-19 17:39:28 /favicon.ico ................................. ~ 0.12ms
#   2025-01-19 17:39:37 /login ........................................... ~ 1s
#   2025-01-19 17:39:38 /login ....................................... ~ 1.34ms
#   2025-01-19 17:39:38 /build/assets/app-D-FaURHc.js ................ ~ 0.45ms
#   2025-01-19 17:39:38 /build/assets/app-PwOqhazG.css ............... ~ 3.64ms
#   2025-01-19 17:39:38 /static/logo.svg ............................. ~ 4.26ms
#   2025-01-19 17:39:38 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-19 17:39:38 /favicon.ico ................................. ~ 0.11ms
#   2025-01-19 17:39:46 /login ........................................... ~ 1s
#   2025-01-19 17:39:47 /login ...................................... ~ 10.16ms
#   2025-01-19 17:39:47 /static/logo.svg ............................. ~ 0.23ms
#   2025-01-19 17:39:47 /build/assets/app-PwOqhazG.css ............... ~ 4.05ms
#   2025-01-19 17:39:47 /build/assets/app-D-FaURHc.js ................ ~ 4.91ms
#   2025-01-19 17:39:47 /static/gradient.jpg ......................... ~ 0.45ms
#   2025-01-19 17:39:47 /favicon.ico ................................. ~ 0.43ms
#   2025-01-19 17:39:51 /favicon.ico ................................. ~ 0.13ms
#   2025-01-19 17:39:57 /login ........................................... ~ 1s
#   2025-01-19 17:39:58 /login ....................................... ~ 0.13ms
#   2025-01-19 17:39:58 /static/logo.svg ............................. ~ 0.18ms
#   2025-01-19 17:39:58 /build/assets/app-PwOqhazG.css ............... ~ 2.97ms
#   2025-01-19 17:39:58 /build/assets/app-D-FaURHc.js ................ ~ 3.74ms
#   2025-01-19 17:39:58 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-19 17:39:58 /favicon.ico ................................. ~ 2.58ms
#   2025-01-19 17:40:01 /favicon.ico ............................... ~ 500.99ms

# %%
! vendor/bin/codecept run
# Out:
#   2025-01-18 19:37:47 .............................................. ~ 0.68ms
# Codeception PHP Testing Framework v5.1.2 https://stand-with-ukraine.pp.ua
#
# TestsCodeception.Acceptance Tests (4) ------------------------------------------
# - Test00_HomepageCest: See Laravel links on homepage19:37:50.146 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 19:37:54.711 INFO [LocalNode.newSession] - Session created by the Node. Id: bf97a9726017d17a5dbd4acd2eeddaea, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 19:37:54.733 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: bf97a9726017d17a5dbd4acd2eeddaea
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2025-01-18 19:37:58 / ................................................ ~ 1s
#   2025-01-18 19:37:59 /build/assets/app-PCkFcrRW.css ............... ~ 0.40ms
#   2025-01-18 19:37:59 /build/assets/app-D-FaURHc.js ................ ~ 2.49ms
#   2025-01-18 19:37:59 /static/logo.svg ............................. ~ 3.11ms
#   2025-01-18 19:37:59 /static/gradient.jpg ............................. ~ 2s
#   2025-01-18 19:38:04 /favicon.ico ................................. ~ 0.24ms
# ✖ Test00_HomepageCest: See Laravel links on homepage(6.53s)
# - Test01_CommentsCest: See comments from DB displayed on page  2025-01-18 19:38:10 /comments ........................................ ~ 1s
#   2025-01-18 19:38:11 /build/assets/app-PCkFcrRW.css ............... ~ 0.24ms
#   2025-01-18 19:38:11 /build/assets/app-D-FaURHc.js ................ ~ 4.43ms
#   2025-01-18 19:38:11 /static/logo.svg ............................. ~ 5.03ms
#   2025-01-18 19:38:11 /static/gradient.jpg ......................... ~ 0.10ms
#   2025-01-18 19:38:13 /favicon.ico ................................. ~ 0.22ms
#   2025-01-18 19:38:14 /comments/1 ...................................... ~ 1s
#   2025-01-18 19:38:15 /build/assets/app-PCkFcrRW.css ............... ~ 2.67ms
#   2025-01-18 19:38:15 /build/assets/app-D-FaURHc.js ................ ~ 3.80ms
#   2025-01-18 19:38:15 /static/logo.svg ............................. ~ 5.79ms
#   2025-01-18 19:38:15 /static/gradient.jpg ......................... ~ 4.78ms
#   2025-01-18 19:38:16 /favicon.ico ................................. ~ 0.37ms
# ✔ Test01_CommentsCest: See comments from DB displayed on page(7.87s)
# - Test02_LoginCest: Login with existing user  2025-01-18 19:38:21 /dashboard ................................. ~ 500.86ms
#   2025-01-18 19:38:21 /login ....................................... ~ 0.50ms
#   2025-01-18 19:38:21 /static/logo.svg ............................. ~ 0.31ms
#   2025-01-18 19:38:21 /build/assets/app-D-FaURHc.js .............. ~ 529.08ms
#   2025-01-18 19:38:21 /build/assets/app-PCkFcrRW.css ............. ~ 529.88ms
#   2025-01-18 19:38:21 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-18 19:38:25 /favicon.ico ................................. ~ 0.38ms
#   2025-01-18 19:38:26 /login ........................................... ~ 1s
#   2025-01-18 19:38:27 /dashboard ....................................... ~ 1s
# ✖ Test02_LoginCest: Login with existing user(9.22s)
# ✖ Test03_BooksCest: Have books page(0.64s)
#   2025-01-18 19:38:33 /books ..................................... ~ 502.05ms
#   2025-01-18 19:38:34 /favicon.ico ................................. ~ 0.20ms
# 19:38:54.678 INFO [LocalSessionMap.remove] - Deleted session from local Session Map, Id: bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.680 INFO [GridModel.release] - Releasing slot for session id bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.681 INFO [SessionSlot.stop] - Stopping session bf97a9726017d17a5dbd4acd2eeddaea
# --------------------------------------------------------------------------------
# Time: 01:07.277, Memory: 16.00 MB
#
# There were 3 failures:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:test
#  Step  See in title "Laravel"
#  Fail  Failed asserting that 'Rocksa' [ASCII](length: 6) contains "Laravel" [ASCII](length: 7).
#
# Scenario Steps:
#
#  2. $I->seeInTitle("Laravel") at tests_codeception/Acceptance/Test00_HomepageCest.php:15
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.html
# 2) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:test
#  Step  See "John Doe"
#  Fail  Failed asserting that on page /dashboard
# --> Internal Server Error
# ErrorException
# Undefined variable $rocks
# GET localhost:8888
# PHP 8.3.6 — Laravel 11.34.2
# resources/views/dashboard.blade.php :7
#     <div class="py-12">
#         <div class="max-w-7xl mx-auto sm:px-6 lg:px-8">
#             <div class="bg-white overflow-visible shadow-sm sm:rounded-
# [Content too long to display. See complete response in '/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/' directory]
# --> contains "John Doe".
#
# Scenario Steps:
#
#  9. $I->see("John Doe") at tests_codeception/Acceptance/Test02_LoginCest.php:19
#  8. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:17
#  7. $I->waitForJS("return document.oldPage !== "yes"") at tests_codeception/Support/AcceptanceTester.php:49
#  6. $I->click("Log in") at tests_codeception/Support/AcceptanceTester.php:35
#  5. $I->waitForJS("return document.oldPage = "yes"") at tests_codeception/Support/AcceptanceTester.php:42
#  4. $I->fillField("password","secret") at tests_codeception/Support/AcceptanceTester.php:34
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.html
# 3) Test03_BooksCest: Have books page
#  Test  tests_codeception/Acceptance/Test03_BooksCest.php:test
#  Step  See current url equals "/login"
#  Fail  Failed asserting that two strings are equal.
# - Expected | + Actual
# @@ @@
# -'/login'
# +'/books'
#
# Scenario Steps:
#
#  2. $I->seeCurrentUrlEquals("/login") at tests_codeception/Support/AcceptanceTester.php:32
#  1. $I->amOnPage("/books") at tests_codeception/Acceptance/Test03_BooksCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.html
#
# FAILURES!
# Tests: 4, Assertions: 12, Failures: 3.
#   2025-01-18 19:39:09 / .......................................... ~ 507.98ms
#   2025-01-18 19:39:09 /build/assets/app-PCkFcrRW.css ............... ~ 2.44ms
#   2025-01-18 19:39:09 /build/assets/app-D-FaURHc.js ................ ~ 2.94ms
#   2025-01-18 19:39:09 /static/logo.svg ............................. ~ 3.42ms
#   2025-01-18 19:39:09 /static/gradient.jpg ......................... ~ 4.13ms
#   2025-01-18 19:39:10 /favicon.ico ................................ ~ 17.70ms
#   2025-01-18 19:39:14 /login ..................................... ~ 508.37ms
#   2025-01-18 19:39:15 /static/logo.svg ............................. ~ 0.17ms
#   2025-01-18 19:39:15 /build/assets/app-PCkFcrRW.css ............... ~ 3.14ms
#   2025-01-18 19:39:15 /build/assets/app-D-FaURHc.js ............... ~ 20.43ms
#   2025-01-18 19:39:15 /static/gradient.jpg ......................... ~ 0.14ms
#   2025-01-18 19:39:15 /favicon.ico ................................. ~ 0.29ms
#   2025-01-18 19:39:31 /login ........................................... ~ 1s
#   2025-01-18 19:39:32 /dashboard ................................. ~ 503.25ms
#   2025-01-18 19:47:53 /dashboard ....................................... ~ 1s
#   2025-01-18 19:49:12 /favicon.ico ............................... ~ 504.08ms
#   2025-01-18 19:49:27 /login ..................................... ~ 500.84ms
#   2025-01-18 19:49:27 /favicon.ico ................................. ~ 0.14ms
#   2025-01-18 19:50:04 /login ........................................... ~ 1s
#   2025-01-18 19:50:08 /favicon.ico ................................. ~ 0.73ms
#   2025-01-18 19:50:13 /login ........................................... ~ 3s
#   2025-01-18 19:50:16 /dashboard ................................. ~ 528.04ms
#   2025-01-18 19:50:24 / ............................................ ~ 7.24ms
#   2025-01-18 19:50:25 /build/assets/app-PCkFcrRW.css ............... ~ 4.50ms
#   2025-01-18 19:50:25 /static/logo.svg ............................. ~ 5.58ms
#   2025-01-18 19:50:25 /build/assets/app-D-FaURHc.js ................ ~ 7.22ms
#   2025-01-18 19:50:25 /static/gradient.jpg ......................... ~ 5.73ms
#   2025-01-18 19:50:30 / ................................................ ~ 2s
#   2025-01-18 19:50:31 /login ........................................... ~ 2s
#   2025-01-18 19:50:34 /dashboard ....................................... ~ 1s
#   2025-01-18 19:51:34 /dashboard ....................................... ~ 1s

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# Warning: Not allowed as a service: java.awt.Window.CustomTitleBarPeer
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# Warning: Service not supported: com.jetbrains.WindowDecorations
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-19 17:41:23,039 [   6173]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDefault.xml
# 2025-01-19 17:41:23,111 [   6245]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDarcula.xml
# [JetBrains Runtime] Detected slow X11, switched off alpha compositing of images. Control with -Dremote.x11.workaround={true|false|auto}.
# 2025-01-19 17:41:29,980 [  13114]   WARN - #c.i.s.ComponentManagerImpl - `preload=NOT_HEADLESS` must be used only for core services (service=com.jetbrains.rdserver.toolWindow.BackendServerToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendUserManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.ports.CwmPortForwardingToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendCWMUserFocusHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeManagerService, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendProjectViewSync, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,981 [  13115]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeEditorsHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,983 [  13117]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeDebuggerHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:29,983 [  13117]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeLookupSynchronizer, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 17:41:34,502 [  17636]   WARN - #c.i.o.p.i.ProjectFrameAllocator - Cannot load project in 10 seconds:
# - BlockingCoroutine{Active} [BlockingEventLoop@5d70976d]
# 	- "showSplashIfNeeded":StandaloneCoroutine{Completing} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@12c354b4, Dispatchers.Default]
# 		- "showSplashIfNeeded":LazyStandaloneCoroutine{Active} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@12c354b4, Dispatchers.Default]
# 			- "splash initialization":DispatchedCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, splash initialization, kotlinx.coroutines.UndispatchedMarker@12c354b4, Swing]
# 				at com.intellij.platform.ide.bootstrap.SplashManagerKt$showSplashIfNeeded$newJob$1$1$5.invokeSuspend(SplashManager.kt:168)
# 				at com.intellij.platform.ide.bootstrap.SplashManagerKt$showSplashIfNeeded$newJob$1$1.invokeSuspend(SplashManager.kt:167)
# 	- "startApplication":StandaloneCoroutine{Active} [StartupAbortedExceptionHandler, startApplication, kotlinx.coroutines.UndispatchedMarker@12c354b4, Dispatchers.Default]
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@12c354b4, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@215fe2f4, Dispatchers.Default]
# 			at java.base/java.lang.Thread.getStackTrace(Thread.java:2450)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDumpImpl(DebugProbesImpl.kt:332)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDump(DebugProbesImpl.kt:317)
# 			at com.intellij.diagnostic.CoroutineDumperKt.traceToDump(coroutineDumper.kt:325)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:298)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:131)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:59)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines$default(coroutineDumper.kt:50)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2$debugTask$1.invokeSuspend(ProjectFrameAllocator.kt:161)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@12c354b4, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@215fe2f4, Dispatchers.Default]
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1.invokeSuspend(ProjectFrameAllocator.kt:357)
# 			- "tool window pane creation":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, tool window pane creation, kotlinx.coroutines.UndispatchedMarker@12c354b4, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@215fe2f4, Dispatchers.Default]
# 				at java.base/java.lang.Class.initClassName(Native Method)
# 				at java.base/java.lang.Class.getName(Class.java:948)
# 				at java.base/java.lang.Class.getPackageName(Class.java:1167)
# 				at java.base/java.lang.ClassLoader.postDefineClass(ClassLoader.java:934)
# 				at java.base/java.lang.ClassLoader.defineClass(ClassLoader.java:1119)
# 				at com.intellij.util.lang.UrlClassLoader.consumeClassData(UrlClassLoader.java:276)
# 				at com.intellij.util.lang.ZipResourceFile.findClass(ZipResourceFile.java:115)
# 				at com.intellij.util.lang.JarLoader.findClass(JarLoader.java:58)
# 				at com.intellij.util.lang.ClassPath.findClassInLoader(ClassPath.java:240)
# 				at com.intellij.util.lang.ClassPath.findClass(ClassPath.java:190)
# 				at com.intellij.util.lang.UrlClassLoader.findClass(UrlClassLoader.java:227)
# 				at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:593)
# 				at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:526)
# 				at com.intellij.toolWindow.InternalDecoratorImpl.<clinit>(InternalDecoratorImpl.kt:205)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl.createContentManager(ToolWindowImpl.kt:176)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl.access$createContentManager(ToolWindowImpl.kt:65)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl$contentManager$1.invoke(ToolWindowImpl.kt:120)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl$contentManager$1.invoke(ToolWindowImpl.kt:119)
# 				at com.intellij.util.concurrency.SynchronizedClearableLazy._get_value_$lambda$1$lambda$0(SynchronizedClearableLazy.kt:41)
# 				at java.base/java.util.concurrent.atomic.AtomicReference.updateAndGet(AtomicReference.java:210)
# 				at com.intellij.util.concurrency.SynchronizedClearableLazy.getValue(SynchronizedClearableLazy.kt:40)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl.ensureContentManagerInitialized(ToolWindowImpl.kt:640)
# 				at com.intellij.openapi.wm.impl.ToolWindowImpl.getOrCreateDecoratorComponent$intellij_platform_ide_impl(ToolWindowImpl.kt:154)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.doShowWindow(ToolWindowManagerImpl.kt:1022)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.showToolWindowImpl(ToolWindowManagerImpl.kt:970)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.showToolWindowImpl$default(ToolWindowManagerImpl.kt:953)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$registerToolWindow$postTask$1.invoke(ToolWindowManagerImpl.kt:1169)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$registerToolWindow$postTask$1.invoke(ToolWindowManagerImpl.kt:1168)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.registerToolWindow$intellij_platform_ide_impl(ToolWindowManagerImpl.kt:1182)
# 				at com.intellij.toolWindow.ToolWindowSetInitializerKt.registerToolWindows(ToolWindowSetInitializer.kt:222)
# 				at com.intellij.toolWindow.ToolWindowSetInitializerKt.access$registerToolWindows(ToolWindowSetInitializer.kt:1)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$createAndLayoutToolWindows$entries$1$1.invokeSuspend(ToolWindowSetInitializer.kt:139)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$createAndLayoutToolWindows$entries$1$1.invoke(ToolWindowSetInitializer.kt)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$createAndLayoutToolWindows$entries$1$1.invoke(ToolWindowSetInitializer.kt)
# 				at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 				at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 				at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 				at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span(tracer.kt:56)
# 				at com.intellij.platform.diagnostic.telemetry.impl.TracerKt.span$default(tracer.kt:49)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$createAndLayoutToolWindows$entries$1.invokeSuspend(ToolWindowSetInitializer.kt:136)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer.createAndLayoutToolWindows(ToolWindowSetInitializer.kt:132)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer.initUi(ToolWindowSetInitializer.kt:86)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$doInit$2.invokeSuspend(ToolWindowManagerImpl.kt:521)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.doInit(ToolWindowManagerImpl.kt:504)
# 				at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1$1$1.invokeSuspend(ProjectFrameAllocator.kt:363)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@12c354b4, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@215fe2f4, Dispatchers.Default]
# 			at com.intellij.openapi.fileEditor.impl.UiBuilder.processFiles(EditorsSplitters.kt:974)
# 			at com.intellij.openapi.fileEditor.impl.UiBuilder.process(EditorsSplitters.kt:893)
# 			at com.intellij.openapi.fileEditor.impl.UiBuilder.process(EditorsSplitters.kt:913)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2$3.invokeSuspend(ProjectFrameAllocator.kt:397)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2.invokeSuspend(ProjectFrameAllocator.kt:396)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1$1.invokeSuspend(ProjectFrameAllocator.kt:192)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1.invokeSuspend(ProjectFrameAllocator.kt:190)
# 	- "Application":supervisor:ChildScope{Active}
# 		- "ApplicationImpl@262169281 container":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.platform.ide.provisioner)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x intellij.grid.core.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			-[x7 of] "(ApplicationImpl@262169281 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.history.integration.LocalHistoryImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 					- "com.intellij.history.integration.LocalHistoryImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 						at com.intellij.history.integration.LocalHistoryImpl$init$3.invokeSuspend(LocalHistoryImpl.kt:99)
# 			- "(ApplicationImpl@262169281 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.ide.startup.importSettings.jb.JbAfterRestartSettingsApplier":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.searcheverywhere.ml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.settingsSync)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x intellij.charts)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.textmate)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.intellij.plugins.markdown)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			-[x2 of] "(ApplicationImpl@262169281 x org.jetbrains.plugins.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.completion.full.line)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x intellij.platform.ijent.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x intellij.indexing.shared.core)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x intellij.grid.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.database.loaders.DataLoaderManager$Associations":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 					- "com.intellij.database.loaders.DataLoaderManager$Associations":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "(ApplicationImpl@262169281 x XPathView)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.tasks)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.intellij.intelliLang)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			-[x4 of] "(ApplicationImpl@262169281 x Docker)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x tanvd.grazi)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x Git4Idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.github)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x JavaScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x JavaScriptDebugger)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.database)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.database.dataSource.DataSourceModelStorageImpl$App":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x NodeJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.node-remote-interpreter)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.php)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.twig)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.php.psalm)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.intellij.php.tools.quality.phpstan)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.intellij.qodana)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$2.invokeSuspend(RdSettingsStorageService.kt:61)
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.EDT]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$3.invokeSuspend(RdSettingsStorageService.kt:71)
# 						- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.EDT]
# 							at com.intellij.platform.util.coroutines.flow.FlowKt$debounceBatch$1.invokeSuspend(flow.kt:147)
# 				- "com.intellij.remoteDev.tests.impl.DistributedTestHost":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 					- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 						- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 							at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2.invokeSuspend(ActionManagerImpl.kt:1273)
# 							- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 								at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 								- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 									at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2$1.invokeSuspend(ActionManagerImpl.kt:1275)
# 			- "(ApplicationImpl@262169281 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x com.jetbrains.gateway.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x org.jetbrains.plugins.docker.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "(ApplicationImpl@262169281 x AngularJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "ApplicationImpl@262169281 container":ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "com.intellij.ide.ScreenReaderStateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.ide.ScreenReaderStateManager":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 				at com.intellij.platform.ide.bootstrap.ApplicationLoader$loadApp$2$5$3.invokeSuspend(ApplicationLoader.kt:243)
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 				at com.intellij.openapi.vfs.newvfs.persistent.VFSHealthCheckServiceStarter$execute$2.invokeSuspend(VFSHealthChecker.kt:95)
# 			- "com.intellij.openapi.vfs.newvfs.persistent.ExecuteOnCoroutine":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "PersistentFsLoader":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281), Dispatchers.IO]
# 			- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents$1.invokeSuspend(FeatureUsageSettingsEvents.kt:60)
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 				at com.intellij.ide.L.G.invokeSuspend(EvaluationSupportHelper.kt)
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 				at com.intellij.ide.AgreementUpdater$execute$2.invokeSuspend(AgreementUpdater.kt:33)
# 			- "ApplicationImpl@262169281 container":StandaloneCoroutine{Completing} [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 				- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.checkPreviousExternalUploadResult(StatisticsJobsScheduler.kt:129)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$2.invokeSuspend(StatisticsJobsScheduler.kt:44)
# 				- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler.runEventLogStatisticsService(StatisticsJobsScheduler.kt:77)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$3.invokeSuspend(StatisticsJobsScheduler.kt:47)
# 				- "ApplicationImpl@262169281 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.runValidationRulesUpdate(StatisticsJobsScheduler.kt:106)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$4.invokeSuspend(StatisticsJobsScheduler.kt:50)
# 			- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger.logApplicationStateRegularly(FUStateUsagesLogger.kt:152)
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger$1.invokeSuspend(FUStateUsagesLogger.kt:53)
# 			- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "FileTypeManager Redetect":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281), LimitedDispatcher@53c88f6a]
# 				- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.openapi.fileTypes.impl.AlarmAdapterKt$singleAlarm$1.invokeSuspend(AlarmAdapter.kt:24)
# 					- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "ApplicationImpl@262169281 container":ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.diagnostic.PerformanceWatcherImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.diagnostic.PerformanceWatcherImpl$1.invokeSuspend(PerformanceWatcherImpl.kt:96)
# 					- "com.intellij.diagnostic.PerformanceWatcherImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 			- "com.intellij.ide.ui.laf.LafManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.util.net.ssl.CertificateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.ide.IdeTooltipManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.ide.ui.customization.CustomActionsSchema":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.ide.ui.laf.LafDynamicPluginManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.ide.plugins.marketplace.MarketplaceRequests":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.openapi.editor.impl.EditorFactoryImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "refresh requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), ModalityState.NON_MODAL, Dispatchers.Default]
# 					at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 					at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 					at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$1.invokeSuspend(SaveAndSyncHandlerImpl.kt:72)
# 					- "refresh requests flow processing":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), ModalityState.NON_MODAL, Dispatchers.Default]
# 				- "save requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$2.invokeSuspend(SaveAndSyncHandlerImpl.kt:86)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl.listenIdleAndActivate(SaveAndSyncHandlerImpl.kt:171)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$3.invokeSuspend(SaveAndSyncHandlerImpl.kt:116)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.util.CoroutinesKt$awaitCancellationAndInvoke$1.invokeSuspend(coroutines.kt:28)
# 			- "com.intellij.openapi.progress.impl.PlatformTaskSupport":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.openapi.wm.impl.WindowButtonsConfiguration":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 					at com.intellij.ide.RecentProjectsManagerBase$1.invokeSuspend(RecentProjectsManagerBase.kt:118)
# 					- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@262169281), Dispatchers.Default]
# 			- "com.intellij.openapi.wm.impl.customFrameDecorations.frameButtons.LinuxIconThemeConfiguration":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "com.intellij.util.indexing.FileBasedIndexImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 				- "com.intellij.util.indexing.FileBasedIndexImpl":DeferredCoroutine{Active}, state: RUNNING [ComponentManager(ApplicationImpl@262169281), LimitedDispatcher@5d8b1cb6]
# 					at java.base/jdk.internal.misc.Unsafe.park(Native Method)
# 					at java.base/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:269)
# 					at kotlinx.coroutines.BlockingCoroutine.joinBlocking(Builders.kt:120)
# 					at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking$BuildersKt__BuildersKt(Builders.kt:84)
# 					at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking(Builders.kt:52)
# 					at kotlinx.coroutines.BuildersKt.runBlocking(Unknown Source)
# 					at com.intellij.util.indexing.IndexDataInitializer$Companion.runParallelTasks(IndexDataInitializer.kt:79)
# 					at com.intellij.util.indexing.IndexDataInitializer.call(IndexDataInitializer.kt:25)
# 					at com.intellij.util.indexing.IndexDataInitializer$Companion$submitGenesisTask$2.invokeSuspend(IndexDataInitializer.kt:70)
# 			- "com.intellij.util.indexing.diagnostic.IndexDiagnosticDumper":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "org.jetbrains.ide.BuiltInServerManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@262169281)]
# 			- "ProjectImpl@1054036647 container":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "ProjectImpl@1054036647 container":ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 					- "project service preloading (async)":StandaloneCoroutine{Completing} [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.codeHighlighting.TextEditorHighlightingPassRegistrar preloading":StandaloneCoroutine{Active}, state: RUNNING [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 							at java.base/java.lang.ClassLoader.defineClass2(Native Method)
# 							at java.base/java.lang.ClassLoader.defineClass(ClassLoader.java:1118)
# 							at com.intellij.util.lang.UrlClassLoader.consumeClassData(UrlClassLoader.java:276)
# 							at com.intellij.util.lang.ZipResourceFile.findClass(ZipResourceFile.java:115)
# 							at com.intellij.util.lang.JarLoader.findClass(JarLoader.java:58)
# 							at com.intellij.util.lang.ClassPath.findClassInLoader(ClassPath.java:240)
# 							at com.intellij.util.lang.ClassPath.findClass(ClassPath.java:190)
# 							at com.intellij.ide.plugins.cl.PluginClassLoader.loadClassInsideSelf(PluginClassLoader.kt:330)
# 							at com.intellij.ide.plugins.cl.PluginClassLoader.tryLoadingClass(PluginClassLoader.kt:179)
# 							at com.intellij.ide.plugins.cl.PluginClassLoader.loadClass(PluginClassLoader.kt:152)
# 							at java.base/java.lang.ClassLoader.loadClass(ClassLoader.java:526)
# 							at java.base/java.lang.invoke.MethodHandleNatives.resolve(Native Method)
# 							at java.base/java.lang.invoke.MemberName$Factory.resolve(MemberName.java:962)
# 							at java.base/java.lang.invoke.MemberName$Factory.resolveOrFail(MemberName.java:991)
# 							at java.base/java.lang.invoke.MethodHandles$Lookup.resolveOrFail(MethodHandles.java:3750)
# 							at java.base/java.lang.invoke.MethodHandles$Lookup.findConstructor(MethodHandles.java:2837)
# 							at com.intellij.serviceContainer.ComponentManagerImplKt.findConstructorOrNull(ComponentManagerImpl.kt:83)
# 							at com.intellij.serviceContainer.ComponentManagerImpl.findConstructorAndInstantiateClass(ComponentManagerImpl.kt:900)
# 							at com.intellij.serviceContainer.ComponentManagerImpl.doInstantiateClass(ComponentManagerImpl.kt:909)
# 							at com.intellij.serviceContainer.ComponentManagerImpl.instantiateClass(ComponentManagerImpl.kt:894)
# 							at com.intellij.openapi.extensions.impl.SimpleConstructorInjectionAdapter.instantiateClass(XmlExtensionAdapter.kt:103)
# 							at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.doCreateInstance(XmlExtensionAdapter.kt:52)
# 							at com.intellij.openapi.extensions.impl.XmlExtensionAdapter.createInstance(XmlExtensionAdapter.kt:33)
# 							at com.intellij.openapi.extensions.ExtensionPointName.forEachExtensionSafe(ExtensionPointName.kt:348)
# 							at com.intellij.codeInsight.daemon.impl.TextEditorHighlightingPassRegistrarImpl.reRegisterFactories(TextEditorHighlightingPassRegistrarImpl.java:71)
# 							at com.intellij.codeInsight.daemon.impl.TextEditorHighlightingPassRegistrarImpl.<init>(TextEditorHighlightingPassRegistrarImpl.java:47)
# 							at java.base/java.lang.invoke.MethodHandle.invokeWithArguments(MethodHandle.java:733)
# 							at com.intellij.platform.instanceContainer.instantiation.InstantiateKt$instantiate$2.invoke(instantiate.kt:49)
# 							at com.intellij.platform.instanceContainer.instantiation.InstantiateKt$instantiate$2.invoke(instantiate.kt:42)
# 							at com.intellij.platform.instanceContainer.instantiation.InstantiateKt.instantiate(instantiate.kt:313)
# 							at com.intellij.platform.instanceContainer.instantiation.InstantiateKt.instantiate(instantiate.kt:42)
# 							at com.intellij.serviceContainer.ServiceInstanceInitializer.createInstance$suspendImpl(ServiceInstanceInitializer.kt:31)
# 							at com.intellij.serviceContainer.ServiceInstanceInitializer.createInstance(ServiceInstanceInitializer.kt)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1$1.invokeSuspend(LazyInstanceHolder.kt:162)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1$1.invoke(LazyInstanceHolder.kt)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1$1.invoke(LazyInstanceHolder.kt)
# 							at kotlinx.coroutines.intrinsics.UndispatchedKt.startUndispatchedOrReturn(Undispatched.kt:62)
# 							at kotlinx.coroutines.BuildersKt__Builders_commonKt.withContext(Builders.common.kt:163)
# 							at kotlinx.coroutines.BuildersKt.withContext(Unknown Source)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1.invokeSuspend(LazyInstanceHolder.kt:160)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1.invoke(LazyInstanceHolder.kt)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder$initialize$1.invoke(LazyInstanceHolder.kt)
# 							at kotlinx.coroutines.intrinsics.UndispatchedKt.startCoroutineUndispatched(Undispatched.kt:27)
# 							at kotlinx.coroutines.CoroutineStart.invoke(CoroutineStart.kt:90)
# 							at kotlinx.coroutines.AbstractCoroutine.start(AbstractCoroutine.kt:123)
# 							at kotlinx.coroutines.BuildersKt__Builders_commonKt.launch(Builders.common.kt:52)
# 							at kotlinx.coroutines.BuildersKt.launch(Unknown Source)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.initialize(LazyInstanceHolder.kt:145)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.access$initialize(LazyInstanceHolder.kt:13)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.tryInitialize(LazyInstanceHolder.kt:135)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.getInstance(LazyInstanceHolder.kt:95)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.getInstance$suspendImpl(LazyInstanceHolder.kt:83)
# 							at com.intellij.platform.instanceContainer.internal.LazyInstanceHolder.getInstance(LazyInstanceHolder.kt)
# 							at com.intellij.serviceContainer.ComponentManagerImpl.preloadService$suspendImpl(ComponentManagerImpl.kt:1114)
# 							at com.intellij.serviceContainer.ComponentManagerImpl.preloadService(ComponentManagerImpl.kt)
# 							at com.intellij.serviceContainer.ComponentManagerImpl$preloadServices$2$1.invokeSuspend(ComponentManagerImpl.kt:1086)
# 						- "com.intellij.ide.GeneratedSourceFileChangeTracker preloading":StandaloneCoroutine{Completed}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.openapi.file.exclude.ProjectPlainTextFileTypeManager preloading":StandaloneCoroutine{Completed}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.openapi.module.impl.UnloadedModulesListStorage preloading":StandaloneCoroutine{Completed}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.xdebugger.XDebuggerManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.openapi.vcs.ProjectLevelVcsManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.profile.codeInspection.InspectionProjectProfileManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.openapi.wm.ToolWindowManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.common.users.UserManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.common.portForwarding.PortForwardingToolWindowManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.common.users.CWMUserFocusHost preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.following.FollowMeManager preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.following.BackendProjectViewSync preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.following.BackendFollowMeEditorsHost preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 						- "com.intellij.cwm.plugin.following.BackendFollowMeDebuggerHost preloading":StandaloneCoroutine{Active}, state: CREATED [ComponentManager(ProjectImpl@1054036647), Dispatchers.Default]
# 				- "(ProjectImpl@1054036647 x org.editorconfig.editorconfigjetbrains)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				-[x7 of] "(ProjectImpl@1054036647 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.jetbrains.performancePlugin)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.apacheConfig)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# 				- "(ProjectImpl@1054036647 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@1054036647)]
# ...
#   2025-01-19 18:55:38 /favicon.ico ................................. ~ 0.58ms
#   2025-01-19 18:55:59 /orders/3 .................................. ~ 510.83ms
#   2025-01-19 18:56:00 /build/assets/app-PwOqhazG.css ............... ~ 0.27ms
#   2025-01-19 18:56:00 /build/assets/app-D-FaURHc.js ................ ~ 1.80ms
#   2025-01-19 18:56:00 /static/logo.svg ............................. ~ 7.50ms
#   2025-01-19 18:56:00 /static/gradient.jpg ......................... ~ 0.31ms
#   2025-01-19 18:56:00 /favicon.ico ................................. ~ 4.87ms
# 2025-01-19 18:56:03,402 [4486536]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:03,402 [4486536]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:03,543 [4486677]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2025-01-19 18:56:25,758 [4508892]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:25,813 [4508947]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:25,884 [4509018]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:56:26,083 [4509217]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:29,198 [4512332]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:29,199 [4512333]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:29,276 [4512410]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:42,542 [4525676]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:42,562 [4525696]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:42,582 [4525716]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:43,179 [4526313]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:43,261 [4526395]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:43,383 [4526517]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:44,404 [4527538]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:45,358 [4528492]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:45,420 [4528554]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:45,566 [4528700]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:45,626 [4528760]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:56:47,004 [4530138]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:47,050 [4530184]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:47,064 [4530198]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:47,065 [4530199]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:47,161 [4530295]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:56:49,045 [4532179]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:49,062 [4532196]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:49,122 [4532256]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:49,173 [4532307]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:56:57,925 [4541059]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:57,999 [4541133]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:58,231 [4541365]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:58,467 [4541601]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:58,692 [4541826]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:58,980 [4542114]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:56:58,981 [4542115]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:59,142 [4542276]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:56:59,169 [4542303]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:57:00,530 [4543664]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:57:00,583 [4543717]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:57:00,681 [4543815]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:57:00,747 [4543881]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:57:01,839 [4544973]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:57:01,851 [4544985]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:57:01,860 [4544994]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:57:02,728 [4545862]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
#   2025-01-19 18:57:12 /orders/3 .................................. ~ 503.77ms
#   2025-01-19 18:57:12 /build/assets/app-PwOqhazG.css ............... ~ 1.79ms
#   2025-01-19 18:57:12 /static/logo.svg ............................. ~ 2.11ms
#   2025-01-19 18:57:12 /build/assets/app-D-FaURHc.js ................ ~ 3.76ms
#   2025-01-19 18:57:12 /static/gradient.jpg ......................... ~ 0.09ms
#   2025-01-19 18:57:12 /favicon.ico ................................. ~ 0.09ms
#   2025-01-19 18:57:38 /orders/3/edit ............................. ~ 502.78ms
#   2025-01-19 18:57:39 /favicon.ico ................................. ~ 0.23ms
# 2025-01-19 18:58:01,971 [4605105]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:58:01,971 [4605105]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 18:58:02,089 [4605223]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2025-01-19 18:58:14,379 [4617513]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:58:14,416 [4617550]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 18:58:14,588 [4617722]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 18:58:14,956 [4618090]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
#   2025-01-19 18:59:22 / .......................................... ~ 500.99ms
#   2025-01-19 18:59:22 /build/assets/app-D-FaURHc.js ................ ~ 0.27ms
#   2025-01-19 18:59:22 /static/logo.svg ............................. ~ 4.28ms
#   2025-01-19 18:59:22 /build/assets/app-PwOqhazG.css ............... ~ 7.28ms
#   2025-01-19 18:59:22 /static/gradient.jpg ......................... ~ 0.63ms
#   2025-01-19 18:59:22 /favicon.ico ................................. ~ 0.20ms
#   2025-01-19 18:59:32 /login ..................................... ~ 502.18ms
#   2025-01-19 18:59:33 /dashboard ................................. ~ 506.20ms
#   2025-01-19 18:59:33 /build/assets/app-PwOqhazG.css ............... ~ 0.29ms
#   2025-01-19 18:59:33 /static/logo.svg ............................. ~ 5.76ms
#   2025-01-19 18:59:33 /build/assets/app-D-FaURHc.js ................ ~ 6.94ms
#   2025-01-19 18:59:33 /static/gradient.jpg ......................... ~ 7.57ms
#   2025-01-19 18:59:34 /favicon.ico ................................. ~ 2.63ms
#   2025-01-19 18:59:37 /carttestlivewire .......................... ~ 512.13ms
#   2025-01-19 18:59:38 /build/assets/app-PwOqhazG.css ............... ~ 0.30ms
#   2025-01-19 18:59:38 /build/assets/app-D-FaURHc.js ................ ~ 0.95ms
#   2025-01-19 18:59:38 /static/amethyst.jpg ......................... ~ 1.62ms
#   2025-01-19 18:59:38 /static/amethyst1.jpg ...................... ~ 504.85ms
#   2025-01-19 18:59:38 /static/amethyst2.jpg ...................... ~ 514.10ms
#   2025-01-19 18:59:39 /favicon.ico ................................. ~ 5.99ms
#   2025-01-19 18:59:41 /livewire/update ........................... ~ 502.35ms
#   2025-01-19 18:59:43 /livewire/update ............................. ~ 0.24ms
#   2025-01-19 18:59:45 /livewire/update ............................. ~ 0.19ms
#   2025-01-19 18:59:45 /livewire/update ............................. ~ 0.39ms
#   2025-01-19 18:59:46 /livewire/update ........................... ~ 500.95ms
#   2025-01-19 18:59:46 /livewire/update ............................. ~ 0.09ms
#   2025-01-19 18:59:47 /livewire/update ........................... ~ 508.16ms
#   2025-01-19 18:59:48 /livewire/update ........................... ~ 503.79ms
#   2025-01-19 18:59:49 /livewire/update ............................. ~ 2.62ms
#   2025-01-19 18:59:49 /orders/create ............................. ~ 507.26ms
#   2025-01-19 18:59:50 /build/assets/app-PwOqhazG.css ............... ~ 0.25ms
#   2025-01-19 18:59:50 /static/amethyst.jpg ........................ ~ 29.64ms
#   2025-01-19 18:59:50 /build/assets/app-D-FaURHc.js ............... ~ 36.94ms
#   2025-01-19 18:59:50 /static/logo.svg ............................ ~ 39.49ms
#   2025-01-19 18:59:50 /static/gradient.jpg ......................... ~ 0.59ms
#   2025-01-19 18:59:50 /favicon.ico ................................. ~ 0.75ms
#   2025-01-19 19:00:22 /orders .......................................... ~ 1s
#   2025-01-19 19:00:23 /orders/create ............................. ~ 551.92ms
#   2025-01-19 19:00:23 /build/assets/app-D-FaURHc.js ................ ~ 0.63ms
#   2025-01-19 19:00:23 /build/assets/app-PwOqhazG.css ............... ~ 4.66ms
#   2025-01-19 19:00:23 /static/amethyst.jpg ......................... ~ 7.42ms
#   2025-01-19 19:00:23 /static/logo.svg ............................ ~ 10.53ms
#   2025-01-19 19:00:23 /static/gradient.jpg ......................... ~ 0.50ms
#   2025-01-19 19:00:25 /favicon.ico ................................. ~ 3.43ms
# 2025-01-19 19:01:49,388 [4832522]   WARN - JetBrains UI DSL - Unsupported labeled component com.intellij.vcs.log.VcsUserEditor, label 'Author:'
# 2025-01-19 19:01:51,148 [4834282]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 19:01:51,286 [4834420]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2025-01-19 19:01:56,133 [4839267]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 19:01:56,144 [4839278]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 19:01:56,159 [4839293]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 19:02:39,125 [4882259]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 19:02:39,127 [4882261]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 19:02:39,161 [4882295]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Support\Collection'
# 2025-01-19 19:02:43,704 [4886838]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 19:02:43,731 [4886865]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 19:02:43,761 [4886895]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 19:03:04,517 [4907651]   WARN - #c.i.o.a.e.ActionUtil - Can not find action by id CompileDirty

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3
# Out:
# php: no process found
# php8.3: no process found

# %%
seleniumServer.kill()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 seleniumServer.kill()
#
# NameError: name 'seleniumServer' is not defined

# %%
# %cd ..

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
# Out:
# mysql
