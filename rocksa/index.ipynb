# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 6ddf5b800f06f194e0bfdf08db5ae8e731959e0923e50b3fb40a5194b7234b87

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update sebastian/phpcpd
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Package sebastian/phpcpd is abandoned, you should avoid using it. No replacement was suggested.
# Generating autoload files
# 5 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   andreiio/blade-remix-icon ............................................. DONE
#   blade-ui-kit/blade-icons .............................................. DONE
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/pail .......................................................... DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   livewire/livewire ..................................................... DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#
# 108 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.68.1 Persian Successor by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.6
# Running analysis on 1 core sequentially.
# You can enable parallel runner and speed up the analysis! Please see ]8;;https://cs.symfony.com/doc/usage.html\usage docs]8;;\ for more information.
# Loaded config default from "/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    0/129 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  13/129 [▓▓░░░░░░░░░░░░░░░░░░░░░░░░░░]  10%  26/129 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20%  39/129 [▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░]  30%  52/129 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  40% 104/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 117/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 129/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#    1) app/Models/OrderItems.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# @@ -20,7 +20,8 @@
#
#      }
#
# -    public function rocks(){
# +    public function rocks()
# +    {
#
#          return $this -> belongsTo(Rock::class);
#
#
#       ----------- end diff -----------
#
#    2) app/Models/User.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# @@ -57,4 +57,3 @@
#          return $this->hasMany(Order::class);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    3) app/Models/Rock.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# @@ -40,4 +40,3 @@
#
#
#  }
# -
#
#       ----------- end diff -----------
#
#    4) app/Http/Controllers/OrderController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# @@ -1,4 +1,5 @@
#  <?php
# +
#  namespace App\Http\Controllers;
#
#  use App\Http\Requests\StoreOrderRequest;
# @@ -64,5 +65,3 @@
#      }
#
#  }
# -
# -
#
#       ----------- end diff -----------
#
#    5) app/Http/Controllers/orderItemsController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# @@ -8,6 +8,7 @@
#  use App\Models\OrderItems;
#  use Illuminate\Http\RedirectResponse;
#  use Illuminate\View\View;
# +
#  class orderItemsController extends Controller
#  {
#      public function store(StoreOrderItemsRequest $request): RedirectResponse
#
#       ----------- end diff -----------
#
#    6) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# @@ -8,7 +8,6 @@
#  // use Database\Seeders\InsertTestSeeder;
#  use Database\Seeders\InsertTestSeeder;
#
# -
#  class DatabaseSeeder extends Seeder
#  {
#      /**
#
#       ----------- end diff -----------
#
#    7) database/seeders/InsertTestSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# @@ -5,6 +5,7 @@
#  use Illuminate\Database\Seeder;
#  use Illuminate\Support\Facades\DB;
#  use Illuminate\Support\Facades\Hash;
# +
#  // use Illuminate\Support\Facades\File;
#
#  class InsertTestSeeder extends Seeder
# @@ -73,4 +74,3 @@
#          ]);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#    8) database/migrations/2025_01_11_create_orders_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# @@ -5,7 +5,6 @@
#  use Illuminate\Support\Facades\Schema;
#
#  return new class () extends Migration {
# -
#      /**
#       * Run the migrations.
#       *
# @@ -39,4 +38,3 @@
#          Schema::dropIfExists('orders');
#      }
#  };
# -
#
#       ----------- end diff -----------
#
#
# Found 8 of 129 files that can be fixed in 0.489 seconds, 20.00 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#    0/120 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  20/120 [▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░░]  16%  60/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░]  50%  80/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░]  66% 100/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░]  83% 120/120 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/Cart.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\Cart::$cart type has no value type specified in
#          iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   14     Property App\Livewire\Cart::$listeners has no type specified.
#          🪪  missingType.property
#   21     Method App\Livewire\Cart::mount() has no return type specified.
#          🪪  missingType.return
#   26     Method App\Livewire\Cart::toggleCart() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has no return type
#          specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $image with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $name with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $price with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   32     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   34     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   35     Binary operation "+=" between mixed and 1 results in an error.
#          🪪  assignOp.invalid
#   35     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   37     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   51     Method App\Livewire\Cart::updateQuantity() has no return type
#          specified.
#          🪪  missingType.return
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $change with
#          no type specified.
#          🪪  missingType.parameter
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   53     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   55     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   56     Binary operation "+=" between mixed and mixed results in an error.
#          🪪  assignOp.invalid
#   56     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Comparison operation "<=" between (array|float|int) and 0 results in
#          an error.
#          🪪  smallerOrEqual.invalid
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has no return type
#          specified.
#          🪪  missingType.return
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has parameter
#          $productId with no type specified.
#          🪪  missingType.parameter
#   70     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   72     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   73     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   88     Method App\Livewire\Cart::clearCart() has no return type specified.
#          🪪  missingType.return
#   100    Method App\Livewire\Cart::refreshCart() has no return type specified.
#          🪪  missingType.return
#   102    Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   105    Method App\Livewire\Cart::render() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/RockCard.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\RockCard::$data type has no value type
#          specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   17     Method App\Livewire\RockCard::mount() has no return type specified.
#          🪪  missingType.return
#   38     Method App\Livewire\RockCard::render() has invalid return type
#          App\Livewire\View.
#          🪪  class.notFound
#  ------ --------------------------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Models/Order.php
#  ------ ----------------------------------------------------------------
#   22     Method App\Models\Order::user() has no return type specified.
#          🪪  missingType.return
#   27     Method App\Models\Order::items() has no return type specified.
#          🪪  missingType.return
#  ------ ----------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/OrderItems.php
#  ------ ---------------------------------------------------------------------
#   16     Method App\Models\OrderItems::order() has no return type specified.
#          🪪  missingType.return
#   23     Method App\Models\OrderItems::rocks() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------
#   Line   app/Models/Rock.php
#  ------ --------------------------------------------------------------------
#   31     Method App\Models\Rock::orderItems() has no return type specified.
#          🪪  missingType.return
#   35     Method App\Models\Rock::user() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Models/User.php
#  ------ ----------------------------------------------------------------
#   50     Method App\Models\User::rocks() has no return type specified.
#          🪪  missingType.return
#   55     Method App\Models\User::orders() has no return type specified.
#          🪪  missingType.return
#  ------ ----------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   tests/Unit/ExampleTest.php
#  ------ -----------------------------------------------------------------------
#   19     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   19     No error with identifier method.alreadyNarrowedType is reported on
#          line 19.
#   24     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   24     No error with identifier method.alreadyNarrowedType is reported on
#          line 24.
#   29     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   29     No error with identifier method.alreadyNarrowedType is reported on
#          line 29.
#   33     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   33     No error with identifier method.alreadyNarrowedType is reported on
#          line 33.
#   37     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   37     No error with identifier method.alreadyNarrowedType is reported on
#          line 37.
#   41     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   41     No error with identifier method.alreadyNarrowedType is reported on
#          line 41.
#   46     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   46     No error with identifier method.alreadyNarrowedType is reported on
#          line 46.
#   51     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   51     No error with identifier method.alreadyNarrowedType is reported on
#          line 51.
#   56     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   56     No error with identifier method.alreadyNarrowedType is reported on
#          line 56.
#   61     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   61     No error with identifier method.alreadyNarrowedType is reported on
#          line 61.
#   66     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   66     No error with identifier method.alreadyNarrowedType is reported on
#          line 66.
#  ------ -----------------------------------------------------------------------
#
#
#  [ERROR] Found 65 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# No clones found.
#
# Time: 00:00.028, Memory: 4.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done

# %%
! php artisan migrate:fresh
# Out:
#    INFO  Preparing database.
#
#   Creating migration table ...................................... 77.50ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ......................... 401.15ms DONE
#   0001_01_01_000001_create_cache_table ......................... 116.72ms DONE
#   0001_01_01_000002_create_jobs_table .......................... 275.04ms DONE
#   2024_11_29_145411_create_comments_table ...................... 168.98ms DONE
#   2024_12_07_094911_create_books_table ......................... 113.33ms DONE
#   2025_01_10_create_rocks_table ................................ 143.17ms DONE
#   2025_01_11_create_orders_table ............................... 295.22ms DONE
#   2025_01_14_151420_add_user_id_to_rocks_table ................. 232.64ms DONE
#   2025_01_14_153906_order_items_table .......................... 349.74ms DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 262 ms DONE
#
#   Database\Seeders\InsertTestSeeder .................................. RUNNING
#   Database\Seeders\InsertTestSeeder .............................. 246 ms DONE

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧
# up to date, audited 172 packages in 2s
# ⠧
# ⠧40 packages are looking for funding
# ⠧  run `npm fund` for details
# ⠧
# found 0 vulnerabilities
# ⠧

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.4.11 building for production...
# transforming (1) resources/js/app.jstransforming (2) resources/js/bootstrap.jstransforming (4) node_modules/axios/index.jstransforming (35) node_modules/axios/lib/core/transformData.js✓ 53 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-BaCk4Yae.css  41.15 kB │ gzip:  7.42 kB
# public/build/assets/app-D-FaURHc.js   34.85 kB │ gzip: 14.03 kB
# ✓ built in 1.86s
# ⠙

# %%
! php artisan test
# Out:
#    FAIL  Tests\Unit\ExampleTest
#   ✓ that true is true
#   ⨯ add to cart                                                          0.01s
#   ⨯ remove from cart
#   ⨯ edit name
#   ⨯ edit email
#   ⨯ edit phone number
#   ⨯ edit password
#   ⨯ calculate cost
#   ⨯ add rock
#   ⨯ remove rock
#   ⨯ add filter
#   ⨯ remove filter
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                         2.75s
#   ✓ users can authenticate using the login screen                        0.24s
#   ✓ users can not authenticate with invalid password                     0.42s
#   ✓ users can logout                                                     0.21s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.22s
#   ✓ email can be verified                                                0.21s
#   ✓ email is not verified with invalid hash                              0.22s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.22s
#   ✓ password can be confirmed                                            0.21s
#   ✓ password is not confirmed with invalid password                      0.41s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.20s
#   ✓ reset password link can be requested                                 0.23s
#   ✓ reset password screen can be rendered                                0.24s
#   ✓ password can be reset with valid token                               0.24s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.23s
#   ✓ correct password must be provided to update password                 0.22s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.20s
#   ✓ new users can register                                               0.20s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.20s
#
#    FAIL  Tests\Feature\ProfileTest
#   ⨯ profile page is displayed                                            0.89s
#   ✓ profile information can be updated                                   0.25s
#   ✓ email verification status is unchanged when the email address is un… 0.23s
#   ✓ user can delete their account                                        0.23s
#   ✓ correct password must be provided to delete account                  0.22s
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add to cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:19
#      15▕     }
#      16▕     // Add to cart
#      17▕     public function test_add_to_cart(): void
#      18▕     {
#   ➜  19▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#
#   1   tests/Unit/ExampleTest.php:19
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove from cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:24
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#   ➜  24▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#
#   1   tests/Unit/ExampleTest.php:24
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit name
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:29
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#   ➜  29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:29
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit email
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:33
#      29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#   ➜  33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:33
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit phone number
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:37
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#   ➜  37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#      41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:37
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit password
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:41
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#   ➜  41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#
#   1   tests/Unit/ExampleTest.php:41
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > calculate cost
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:46
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#   ➜  46▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#
#   1   tests/Unit/ExampleTest.php:46
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:51
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#   ➜  51▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#
#   1   tests/Unit/ExampleTest.php:51
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:56
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#   ➜  56▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#
#   1   tests/Unit/ExampleTest.php:56
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:61
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#   ➜  61▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#
#   1   tests/Unit/ExampleTest.php:61
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:66
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#   ➜  66▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      67▕     }
#      68▕ }
#      69▕
#
#   1   tests/Unit/ExampleTest.php:66
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Feature\ProfileTest > profile page is displayed
#   Expected response status code [200] but received 500.
# Failed asserting that 500 is identical to 200.
#
# The following exception occurred during the last request:
#
# Symfony\Component\Routing\Exception\RouteNotFoundException: Route [orders.index] not defined. in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:517
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/helpers.php(853): Illuminate\Routing\UrlGenerator->route()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/bc83c7878475f73afdc76d25b8e2e476.php(132): route()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/44ed49034fa6e57427d55e11fb4e7f3d.php(21): Illuminate\View\View->render()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(79): Illuminate\View\View->render()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Auth\Middleware\Authenticate->handle()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Session\Middleware\StartSession->handle()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Features/SupportDisablingBackButtonCache/DisableBackButtonCacheMiddleware.php(19): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Livewire\Features\SupportDisablingBackButtonCache\DisableBackButtonCacheMiddleware->handle()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #65 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #66 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #67 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #68 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #69 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #70 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #71 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #72 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #73 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\HandleCors->handle()
# #74 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #75 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\TrustProxies->handle()
# #76 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #77 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #78 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #79 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #80 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #81 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(607): Illuminate\Foundation\Http\Kernel->handle()
# #82 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(368): Illuminate\Foundation\Testing\TestCase->call()
# #83 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #84 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1235): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #85 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(514): PHPUnit\Framework\TestCase->runTest()
# #86 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #87 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(361): PHPUnit\Framework\TestRunner->run()
# #88 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #89 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #90 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #91 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #92 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #93 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #94 {main}
#
# Next Illuminate\View\ViewException: Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:517
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(58): Illuminate\View\Engines\CompilerEngine->handleViewException()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(60): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->handleViewException()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/44ed49034fa6e57427d55e11fb4e7f3d.php(21): Illuminate\View\View->render()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(79): Illuminate\View\View->render()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Auth\Middleware\Authenticate->handle()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Session\Middleware\StartSession->handle()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Features/SupportDisablingBackButtonCache/DisableBackButtonCacheMiddleware.php(19): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Livewire\Features\SupportDisablingBackButtonCache\DisableBackButtonCacheMiddleware->handle()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #65 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #66 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #67 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #68 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #69 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #70 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\HandleCors->handle()
# #71 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #72 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\TrustProxies->handle()
# #73 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #74 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #75 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #76 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #77 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #78 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(607): Illuminate\Foundation\Http\Kernel->handle()
# #79 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(368): Illuminate\Foundation\Testing\TestCase->call()
# #80 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #81 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1235): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #82 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(514): PHPUnit\Framework\TestCase->runTest()
# #83 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #84 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(361): PHPUnit\Framework\TestRunner->run()
# #85 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #86 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #87 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #88 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #89 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #90 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #91 {main}
#
# Next Illuminate\View\ViewException: Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:517
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(58): Illuminate\View\Engines\CompilerEngine->handleViewException()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(60): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->handleViewException()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Concerns/ManagesComponents.php(99): Illuminate\View\View->render()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/storage/framework/views/f3efd6f54390eda471f2c0932d8a1eeb.php(32): Illuminate\View\Factory->renderComponent()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(123): require('...')
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Filesystem/Filesystem.php(124): Illuminate\Filesystem\Filesystem::Illuminate\Filesystem\{closure}()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(58): Illuminate\Filesystem\Filesystem->getRequire()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# ...
# #72 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(514): PHPUnit\Framework\TestCase->runTest()
# #73 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #74 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(361): PHPUnit\Framework\TestRunner->run()
# #75 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #76 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #77 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #78 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #79 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #80 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #81 {main}
#
# Next Illuminate\View\ViewException: Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) in /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/UrlGenerator.php:517
# Stack trace:
# #0 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(58): Illuminate\View\Engines\CompilerEngine->handleViewException()
# #1 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/PhpEngine.php(60): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->handleViewException()
# #2 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(22): Illuminate\View\Engines\PhpEngine->evaluatePath()
# #3 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Engines/CompilerEngine.php(75): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->evaluatePath()
# #4 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Mechanisms/ExtendBlade/ExtendedCompilerEngine.php(10): Illuminate\View\Engines\CompilerEngine->get()
# #5 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(209): Livewire\Mechanisms\ExtendBlade\ExtendedCompilerEngine->get()
# #6 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(192): Illuminate\View\View->getContents()
# #7 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/View.php(161): Illuminate\View\View->renderContents()
# #8 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(79): Illuminate\View\View->render()
# #9 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Response.php(35): Illuminate\Http\Response->setContent()
# #10 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(920): Illuminate\Http\Response->__construct()
# #11 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(887): Illuminate\Routing\Router::toResponse()
# #12 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Routing\Router->prepareResponse()
# #13 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Routing\Router->Illuminate\Routing\{closure}()
# #14 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Middleware/SubstituteBindings.php(51): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #15 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Routing\Middleware\SubstituteBindings->handle()
# #16 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Auth/Middleware/Authenticate.php(64): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #17 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Auth\Middleware\Authenticate->handle()
# #18 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/VerifyCsrfToken.php(88): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #19 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\VerifyCsrfToken->handle()
# #20 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/View/Middleware/ShareErrorsFromSession.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #21 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\View\Middleware\ShareErrorsFromSession->handle()
# #22 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(121): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #23 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Session/Middleware/StartSession.php(64): Illuminate\Session\Middleware\StartSession->handleStatefulRequest()
# #24 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Session\Middleware\StartSession->handle()
# #25 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/AddQueuedCookiesToResponse.php(37): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #26 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\AddQueuedCookiesToResponse->handle()
# #27 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Cookie/Middleware/EncryptCookies.php(75): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #28 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Cookie\Middleware\EncryptCookies->handle()
# #29 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #30 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(807): Illuminate\Pipeline\Pipeline->then()
# #31 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(786): Illuminate\Routing\Router->runRouteWithinStack()
# #32 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(750): Illuminate\Routing\Router->runRoute()
# #33 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Routing/Router.php(739): Illuminate\Routing\Router->dispatchToRoute()
# #34 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(201): Illuminate\Routing\Router->dispatch()
# #35 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(170): Illuminate\Foundation\Http\Kernel->Illuminate\Foundation\Http\{closure}()
# #36 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/livewire/livewire/src/Features/SupportDisablingBackButtonCache/DisableBackButtonCacheMiddleware.php(19): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #37 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Livewire\Features\SupportDisablingBackButtonCache\DisableBackButtonCacheMiddleware->handle()
# #38 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #39 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/ConvertEmptyStringsToNull.php(31): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #40 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\ConvertEmptyStringsToNull->handle()
# #41 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TransformsRequest.php(21): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #42 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/TrimStrings.php(51): Illuminate\Foundation\Http\Middleware\TransformsRequest->handle()
# #43 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\TrimStrings->handle()
# #44 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/ValidatePostSize.php(27): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #45 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\ValidatePostSize->handle()
# #46 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/PreventRequestsDuringMaintenance.php(110): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #47 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\PreventRequestsDuringMaintenance->handle()
# #48 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/HandleCors.php(49): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #49 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\HandleCors->handle()
# #50 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Http/Middleware/TrustProxies.php(58): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #51 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Http\Middleware\TrustProxies->handle()
# #52 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Middleware/InvokeDeferredCallbacks.php(22): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #53 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(209): Illuminate\Foundation\Http\Middleware\InvokeDeferredCallbacks->handle()
# #54 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Pipeline/Pipeline.php(127): Illuminate\Pipeline\Pipeline->Illuminate\Pipeline\{closure}()
# #55 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(176): Illuminate\Pipeline\Pipeline->then()
# #56 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Http/Kernel.php(145): Illuminate\Foundation\Http\Kernel->sendRequestThroughRouter()
# #57 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(607): Illuminate\Foundation\Http\Kernel->handle()
# #58 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/laravel/framework/src/Illuminate/Foundation/Testing/Concerns/MakesHttpRequests.php(368): Illuminate\Foundation\Testing\TestCase->call()
# #59 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests/Feature/ProfileTest.php(19): Illuminate\Foundation\Testing\TestCase->get()
# #60 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(1235): Tests\Feature\ProfileTest->test_profile_page_is_displayed()
# #61 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(514): PHPUnit\Framework\TestCase->runTest()
# #62 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestRunner/TestRunner.php(87): PHPUnit\Framework\TestCase->runBare()
# #63 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestCase.php(361): PHPUnit\Framework\TestRunner->run()
# #64 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestCase->run()
# #65 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #66 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/Framework/TestSuite.php(369): PHPUnit\Framework\TestSuite->run()
# #67 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/TestRunner.php(64): PHPUnit\Framework\TestSuite->run()
# #68 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/src/TextUI/Application.php(210): PHPUnit\TextUI\TestRunner->run()
# #69 /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/vendor/phpunit/phpunit/phpunit(104): PHPUnit\TextUI\Application->run()
# #70 {main}
#
# ----------------------------------------------------------------------------------
#
# Route [orders.index] not defined. (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php) (View: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/resources/views/layouts/navigation.blade.php)
#
#   at tests/Feature/ProfileTest.php:21
#      17▕         $response = $this
#      18▕             ->actingAs($user)
#      19▕             ->get('/profile');
#      20▕
#   ➜  21▕         $response->assertOk();
#      22▕     }
#      23▕
#      24▕     public function test_profile_information_can_be_updated(): void
#      25▕     {
#
#
#   Tests:    12 failed, 24 passed (74 assertions)
#   Duration: 9.10s

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.24.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done
# Out:
#   2025-01-19 00:12:32 .............................................. ~ 0.30ms

# %%
! vendor/bin/codecept run
# Out:
#   2025-01-18 19:37:47 .............................................. ~ 0.68ms
# Codeception PHP Testing Framework v5.1.2 https://stand-with-ukraine.pp.ua
#
# TestsCodeception.Acceptance Tests (4) ------------------------------------------
# - Test00_HomepageCest: See Laravel links on homepage19:37:50.146 INFO [LocalDistributor.newSession] - Session request received by the Distributor:
#  [Capabilities {browserName: chrome}]
# 19:37:54.711 INFO [LocalNode.newSession] - Session created by the Node. Id: bf97a9726017d17a5dbd4acd2eeddaea, Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
# 19:37:54.733 INFO [LocalDistributor.newSession] - Session created by the Distributor. Id: bf97a9726017d17a5dbd4acd2eeddaea
#  Caps: Capabilities {acceptInsecureCerts: false, browserName: chrome, browserVersion: 130.0.6723.69, chrome: {chromedriverVersion: 130.0.6723.69 (3ec172b971b9..., userDataDir: /tmp/.org.chromium.Chromium...}, fedcm:accounts: true, goog:chromeOptions: {debuggerAddress: localhost:33091}, networkConnectionEnabled: false, pageLoadStrategy: normal, platformName: linux, proxy: Proxy(), se:bidiEnabled: false, se:cdp: ws://172.17.0.1:4444/sessio..., se:cdpVersion: 130.0.6723.69, setWindowRect: true, strictFileInteractability: false, timeouts: {implicit: 0, pageLoad: 300000, script: 30000}, unhandledPromptBehavior: dismiss and notify, webauthn:extension:credBlob: true, webauthn:extension:largeBlob: true, webauthn:extension:minPinLength: true, webauthn:extension:prf: true, webauthn:virtualAuthenticators: true}
#   2025-01-18 19:37:58 / ................................................ ~ 1s
#   2025-01-18 19:37:59 /build/assets/app-PCkFcrRW.css ............... ~ 0.40ms
#   2025-01-18 19:37:59 /build/assets/app-D-FaURHc.js ................ ~ 2.49ms
#   2025-01-18 19:37:59 /static/logo.svg ............................. ~ 3.11ms
#   2025-01-18 19:37:59 /static/gradient.jpg ............................. ~ 2s
#   2025-01-18 19:38:04 /favicon.ico ................................. ~ 0.24ms
# ✖ Test00_HomepageCest: See Laravel links on homepage(6.53s)
# - Test01_CommentsCest: See comments from DB displayed on page  2025-01-18 19:38:10 /comments ........................................ ~ 1s
#   2025-01-18 19:38:11 /build/assets/app-PCkFcrRW.css ............... ~ 0.24ms
#   2025-01-18 19:38:11 /build/assets/app-D-FaURHc.js ................ ~ 4.43ms
#   2025-01-18 19:38:11 /static/logo.svg ............................. ~ 5.03ms
#   2025-01-18 19:38:11 /static/gradient.jpg ......................... ~ 0.10ms
#   2025-01-18 19:38:13 /favicon.ico ................................. ~ 0.22ms
#   2025-01-18 19:38:14 /comments/1 ...................................... ~ 1s
#   2025-01-18 19:38:15 /build/assets/app-PCkFcrRW.css ............... ~ 2.67ms
#   2025-01-18 19:38:15 /build/assets/app-D-FaURHc.js ................ ~ 3.80ms
#   2025-01-18 19:38:15 /static/logo.svg ............................. ~ 5.79ms
#   2025-01-18 19:38:15 /static/gradient.jpg ......................... ~ 4.78ms
#   2025-01-18 19:38:16 /favicon.ico ................................. ~ 0.37ms
# ✔ Test01_CommentsCest: See comments from DB displayed on page(7.87s)
# - Test02_LoginCest: Login with existing user  2025-01-18 19:38:21 /dashboard ................................. ~ 500.86ms
#   2025-01-18 19:38:21 /login ....................................... ~ 0.50ms
#   2025-01-18 19:38:21 /static/logo.svg ............................. ~ 0.31ms
#   2025-01-18 19:38:21 /build/assets/app-D-FaURHc.js .............. ~ 529.08ms
#   2025-01-18 19:38:21 /build/assets/app-PCkFcrRW.css ............. ~ 529.88ms
#   2025-01-18 19:38:21 /static/gradient.jpg ......................... ~ 0.12ms
#   2025-01-18 19:38:25 /favicon.ico ................................. ~ 0.38ms
#   2025-01-18 19:38:26 /login ........................................... ~ 1s
#   2025-01-18 19:38:27 /dashboard ....................................... ~ 1s
# ✖ Test02_LoginCest: Login with existing user(9.22s)
# ✖ Test03_BooksCest: Have books page(0.64s)
#   2025-01-18 19:38:33 /books ..................................... ~ 502.05ms
#   2025-01-18 19:38:34 /favicon.ico ................................. ~ 0.20ms
# 19:38:54.678 INFO [LocalSessionMap.remove] - Deleted session from local Session Map, Id: bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.680 INFO [GridModel.release] - Releasing slot for session id bf97a9726017d17a5dbd4acd2eeddaea
# 19:38:54.681 INFO [SessionSlot.stop] - Stopping session bf97a9726017d17a5dbd4acd2eeddaea
# --------------------------------------------------------------------------------
# Time: 01:07.277, Memory: 16.00 MB
#
# There were 3 failures:
# 1) Test00_HomepageCest: See Laravel links on homepage
#  Test  tests_codeception/Acceptance/Test00_HomepageCest.php:test
#  Step  See in title "Laravel"
#  Fail  Failed asserting that 'Rocksa' [ASCII](length: 6) contains "Laravel" [ASCII](length: 7).
#
# Scenario Steps:
#
#  2. $I->seeInTitle("Laravel") at tests_codeception/Acceptance/Test00_HomepageCest.php:15
#  1. $I->amOnPage("/") at tests_codeception/Acceptance/Test00_HomepageCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test00.HomepageCest.test.fail.html
# 2) Test02_LoginCest: Login with existing user
#  Test  tests_codeception/Acceptance/Test02_LoginCest.php:test
#  Step  See "John Doe"
#  Fail  Failed asserting that on page /dashboard
# --> Internal Server Error
# ErrorException
# Undefined variable $rocks
# GET localhost:8888
# PHP 8.3.6 — Laravel 11.34.2
# resources/views/dashboard.blade.php :7
#     <div class="py-12">
#         <div class="max-w-7xl mx-auto sm:px-6 lg:px-8">
#             <div class="bg-white overflow-visible shadow-sm sm:rounded-
# [Content too long to display. See complete response in '/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/' directory]
# --> contains "John Doe".
#
# Scenario Steps:
#
#  9. $I->see("John Doe") at tests_codeception/Acceptance/Test02_LoginCest.php:19
#  8. $I->seeCurrentUrlEquals("/dashboard") at tests_codeception/Acceptance/Test02_LoginCest.php:17
#  7. $I->waitForJS("return document.oldPage !== "yes"") at tests_codeception/Support/AcceptanceTester.php:49
#  6. $I->click("Log in") at tests_codeception/Support/AcceptanceTester.php:35
#  5. $I->waitForJS("return document.oldPage = "yes"") at tests_codeception/Support/AcceptanceTester.php:42
#  4. $I->fillField("password","secret") at tests_codeception/Support/AcceptanceTester.php:34
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test02.LoginCest.test.fail.html
# 3) Test03_BooksCest: Have books page
#  Test  tests_codeception/Acceptance/Test03_BooksCest.php:test
#  Step  See current url equals "/login"
#  Fail  Failed asserting that two strings are equal.
# - Expected | + Actual
# @@ @@
# -'/login'
# +'/books'
#
# Scenario Steps:
#
#  2. $I->seeCurrentUrlEquals("/login") at tests_codeception/Support/AcceptanceTester.php:32
#  1. $I->amOnPage("/books") at tests_codeception/Acceptance/Test03_BooksCest.php:13
#
# Artifacts:
#
# Png: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.png
# Html: /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/_output/TestsCodeception.Acceptance.Test03.BooksCest.test.fail.html
#
# FAILURES!
# Tests: 4, Assertions: 12, Failures: 3.
#   2025-01-18 19:39:09 / .......................................... ~ 507.98ms
#   2025-01-18 19:39:09 /build/assets/app-PCkFcrRW.css ............... ~ 2.44ms
#   2025-01-18 19:39:09 /build/assets/app-D-FaURHc.js ................ ~ 2.94ms
#   2025-01-18 19:39:09 /static/logo.svg ............................. ~ 3.42ms
#   2025-01-18 19:39:09 /static/gradient.jpg ......................... ~ 4.13ms
#   2025-01-18 19:39:10 /favicon.ico ................................ ~ 17.70ms
#   2025-01-18 19:39:14 /login ..................................... ~ 508.37ms
#   2025-01-18 19:39:15 /static/logo.svg ............................. ~ 0.17ms
#   2025-01-18 19:39:15 /build/assets/app-PCkFcrRW.css ............... ~ 3.14ms
#   2025-01-18 19:39:15 /build/assets/app-D-FaURHc.js ............... ~ 20.43ms
#   2025-01-18 19:39:15 /static/gradient.jpg ......................... ~ 0.14ms
#   2025-01-18 19:39:15 /favicon.ico ................................. ~ 0.29ms
#   2025-01-18 19:39:31 /login ........................................... ~ 1s
#   2025-01-18 19:39:32 /dashboard ................................. ~ 503.25ms
#   2025-01-18 19:47:53 /dashboard ....................................... ~ 1s
#   2025-01-18 19:49:12 /favicon.ico ............................... ~ 504.08ms
#   2025-01-18 19:49:27 /login ..................................... ~ 500.84ms
#   2025-01-18 19:49:27 /favicon.ico ................................. ~ 0.14ms
#   2025-01-18 19:50:04 /login ........................................... ~ 1s
#   2025-01-18 19:50:08 /favicon.ico ................................. ~ 0.73ms
#   2025-01-18 19:50:13 /login ........................................... ~ 3s
#   2025-01-18 19:50:16 /dashboard ................................. ~ 528.04ms
#   2025-01-18 19:50:24 / ............................................ ~ 7.24ms
#   2025-01-18 19:50:25 /build/assets/app-PCkFcrRW.css ............... ~ 4.50ms
#   2025-01-18 19:50:25 /static/logo.svg ............................. ~ 5.58ms
#   2025-01-18 19:50:25 /build/assets/app-D-FaURHc.js ................ ~ 7.22ms
#   2025-01-18 19:50:25 /static/gradient.jpg ......................... ~ 5.73ms
#   2025-01-18 19:50:30 / ................................................ ~ 2s
#   2025-01-18 19:50:31 /login ........................................... ~ 2s
#   2025-01-18 19:50:34 /dashboard ....................................... ~ 1s
#   2025-01-18 19:51:34 /dashboard ....................................... ~ 1s

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# Warning: Not allowed as a service: java.awt.Window.CustomTitleBarPeer
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# Warning: Service not supported: com.jetbrains.WindowDecorations
# 	at com.jetbrains.JBR$WindowDecorations__Holder.<clinit>(JBR.java:642)
# 	at com.jetbrains.JBR.getWindowDecorations(JBR.java:662)
# 	at com.intellij.platform.ide.bootstrap.StartupUtil$startApplication$3.invokeSuspend(startup.kt:171)
# 	at kotlin.coroutines.jvm.internal.BaseContinuationImpl.resumeWith(ContinuationImpl.kt:33)
# 	at kotlinx.coroutines.DispatchedTask.run(DispatchedTask.kt:104)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler.runSafely(CoroutineScheduler.kt:608)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.executeTask(CoroutineScheduler.kt:873)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.runWorker(CoroutineScheduler.kt:763)
# 	at kotlinx.coroutines.scheduling.CoroutineScheduler$Worker.run(CoroutineScheduler.kt:750)
# 2025-01-19 00:12:42,363 [   3756]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDefault.xml
# 2025-01-19 00:12:42,441 [   3834]   WARN - #c.i.o.e.c.i.EditorColorsManagerImpl - resource not found: colorSchemes/DqlAddonsDarcula.xml
# 2025-01-19 00:12:50,030 [  11423]   WARN - #c.i.s.ComponentManagerImpl - `preload=NOT_HEADLESS` must be used only for core services (service=com.jetbrains.rdserver.toolWindow.BackendServerToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,030 [  11423]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendUserManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,030 [  11423]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.ports.CwmPortForwardingToolWindowManager, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.users.BackendCWMUserFocusHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeManagerService, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendProjectViewSync, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeEditorsHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.BackendFollowMeDebuggerHost, plugin=com.jetbrains.codeWithMe)
# 2025-01-19 00:12:50,031 [  11424]   WARN - #c.i.s.ComponentManagerImpl - `preload=TRUE` must be used only for core services (service=com.intellij.cwm.plugin.following.FollowMeLookupSynchronizer, plugin=com.jetbrains.codeWithMe)
# [JetBrains Runtime] Detected slow X11, switched off alpha compositing of images. Control with -Dremote.x11.workaround={true|false|auto}.
# 2025-01-19 00:12:53,385 [  14778]   WARN - #c.i.u.x.Binding - No accessors for com.jetbrains.php.testFramework.PhpTestFrameworkType. This means that state class cannot be serialized properly. Please see https://jb.gg/ij-psoc
# 2025-01-19 00:12:55,999 [  17392]   WARN - #c.i.o.p.i.ProjectFrameAllocator - Cannot load project in 10 seconds:
# - BlockingCoroutine{Active} [BlockingEventLoop@140706b3]
# 	- "showSplashIfNeeded":StandaloneCoroutine{Completing} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, Dispatchers.Default]
# 		- "showSplashIfNeeded":LazyStandaloneCoroutine{Active} [StartupAbortedExceptionHandler, showSplashIfNeeded, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, Dispatchers.Default]
# 			- "splash initialization":DispatchedCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, splash initialization, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, Swing]
# 				at com.intellij.platform.ide.bootstrap.SplashManagerKt$showSplashIfNeeded$newJob$1$1$5.invokeSuspend(SplashManager.kt:168)
# 				at com.intellij.platform.ide.bootstrap.SplashManagerKt$showSplashIfNeeded$newJob$1$1.invokeSuspend(SplashManager.kt:167)
# 	- "startApplication":StandaloneCoroutine{Active} [StartupAbortedExceptionHandler, startApplication, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, Dispatchers.Default]
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@41829554, Dispatchers.Default]
# 			at java.base/java.lang.Thread.getStackTrace(Thread.java:2450)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDumpImpl(DebugProbesImpl.kt:332)
# 			at kotlinx.coroutines.debug.internal.DebugProbesImpl.enhanceStackTraceWithThreadDump(DebugProbesImpl.kt:317)
# 			at com.intellij.diagnostic.CoroutineDumperKt.traceToDump(coroutineDumper.kt:325)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:298)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.toRepresentation(coroutineDumper.kt:300)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:131)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines(coroutineDumper.kt:59)
# 			at com.intellij.diagnostic.CoroutineDumperKt.dumpCoroutines$default(coroutineDumper.kt:50)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$run$2$debugTask$1.invokeSuspend(ProjectFrameAllocator.kt:161)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@41829554, Dispatchers.Default]
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1.invokeSuspend(ProjectFrameAllocator.kt:357)
# 			- "tool window pane creation":StandaloneCoroutine{Active}, state: RUNNING [StartupAbortedExceptionHandler, tool window pane creation, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@41829554, Dispatchers.Default]
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$initUi$3$1.invokeSuspend(ToolWindowSetInitializer.kt:92)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer$initUi$3.invokeSuspend(ToolWindowSetInitializer.kt:91)
# 				at com.intellij.toolWindow.ToolWindowSetInitializer.initUi(ToolWindowSetInitializer.kt:88)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl$doInit$2.invokeSuspend(ToolWindowManagerImpl.kt:521)
# 				at com.intellij.openapi.wm.impl.ToolWindowManagerImpl.doInit(ToolWindowManagerImpl.kt:504)
# 				at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$scheduleInitFrame$1$1$1.invokeSuspend(ProjectFrameAllocator.kt:363)
# 		- "ProjectManager.openAsync":StandaloneCoroutine{Active}, state: SUSPENDED [StartupAbortedExceptionHandler, ProjectManager.openAsync, kotlinx.coroutines.UndispatchedMarker@4aa2c75e, com.intellij.platform.ide.diagnostic.startUpPerformanceReporter.FUSProjectHotStartUpMeasurer$MyMarker@41829554, Dispatchers.Default]
# 			at kotlinx.coroutines.flow.FlowKt__ReduceKt.firstOrNull(Reduce.kt:179)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt.focusSelectedEditor(ProjectFrameAllocator.kt:449)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2$4.invokeSuspend(ProjectFrameAllocator.kt:409)
# 			at com.intellij.openapi.project.impl.ProjectFrameAllocatorKt$restoreEditors$2.invokeSuspend(ProjectFrameAllocator.kt:400)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1$1.invokeSuspend(ProjectFrameAllocator.kt:192)
# 			at com.intellij.openapi.project.impl.ProjectUiFrameAllocator$doRun$2$reopeningEditorJob$1.invokeSuspend(ProjectFrameAllocator.kt:190)
# 	- "Application":supervisor:ChildScope{Active}
# 		- "ApplicationImpl@455813375 container":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.platform.ide.provisioner)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x intellij.grid.core.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			-[x7 of] "(ApplicationImpl@455813375 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.history.integration.LocalHistoryImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 					- "com.intellij.history.integration.LocalHistoryImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at com.intellij.history.integration.LocalHistoryImpl$init$3.invokeSuspend(LocalHistoryImpl.kt:99)
# 			- "(ApplicationImpl@455813375 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.ide.startup.importSettings.jb.JbAfterRestartSettingsApplier":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.searcheverywhere.ml)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.settingsSync)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x intellij.charts)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.textmate)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.intellij.plugins.markdown)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			-[x2 of] "(ApplicationImpl@455813375 x org.jetbrains.plugins.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.completion.full.line)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x intellij.platform.ijent.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x intellij.indexing.shared.core)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x intellij.grid.impl)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.database.loaders.DataLoaderManager$Associations":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 					- "com.intellij.database.loaders.DataLoaderManager$Associations":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at com.intellij.database.loaders.DataLoaderManager$Associations$1.invokeSuspend(DataLoaderManager.kt:217)
# 						- "com.intellij.database.loaders.DataLoaderManager$Associations":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 							at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 							at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 							at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 							at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 							- "com.intellij.database.loaders.DataLoaderManager$Associations":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "(ApplicationImpl@455813375 x XPathView)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.tasks)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.intellij.intelliLang)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			-[x4 of] "(ApplicationImpl@455813375 x Docker)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x tanvd.grazi)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x Git4Idea)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.github)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x JavaScript)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x JavaScriptDebugger)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.database)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.database.dataSource.DataSourceModelStorageImpl$App":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x NodeJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.node-remote-interpreter)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.php)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.twig)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.php.psalm)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.intellij.php.tools.quality.phpstan)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.intellij.qodana)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$2.invokeSuspend(RdSettingsStorageService.kt:61)
# 					- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.EDT]
# 						at com.jetbrains.rd.platform.codeWithMe.settings.RdSettingsStorageService$3.invokeSuspend(RdSettingsStorageService.kt:71)
# 						- "com.jetbrains.rdserver.settings.BackendBroadcastSettingsStorageService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.EDT]
# 							at com.intellij.platform.util.coroutines.flow.FlowKt$debounceBatch$1.invokeSuspend(flow.kt:147)
# 				- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 					- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 						- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 							at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2.invokeSuspend(ActionManagerImpl.kt:1273)
# 							- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 								at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 								- "com.jetbrains.rdserver.ui.actionPopupMenu.BackendActionManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 									at com.intellij.openapi.actionSystem.impl.ActionManagerImpl$MyTimer$2$1.invokeSuspend(ActionManagerImpl.kt:1275)
# 				- "com.intellij.remoteDev.tests.impl.DistributedTestHost":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.codeWithMe)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x com.jetbrains.gateway.terminal)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x org.jetbrains.plugins.docker.gateway)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "(ApplicationImpl@455813375 x AngularJS)":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "ApplicationImpl@455813375 container":ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "com.intellij.ide.ScreenReaderStateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.ide.ScreenReaderStateManager":StandaloneCoroutine{Active} [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 				at com.intellij.platform.ide.bootstrap.ApplicationLoader$loadApp$2$5$3.invokeSuspend(ApplicationLoader.kt:243)
# 			- "com.intellij.ide.ui.laf.LafManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 				at com.intellij.openapi.vfs.newvfs.persistent.VFSHealthCheckServiceStarter$execute$2.invokeSuspend(VFSHealthChecker.kt:95)
# 			- "com.intellij.openapi.vfs.newvfs.persistent.ExecuteOnCoroutine":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "PersistentFsLoader":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375), Dispatchers.IO]
# 			- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.configurationStore.statistic.eventLog.FeatureUsageSettingsEvents$1.invokeSuspend(FeatureUsageSettingsEvents.kt:60)
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 				at com.intellij.ide.L.G.invokeSuspend(EvaluationSupportHelper.kt)
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 				at com.intellij.ide.AgreementUpdater$execute$2.invokeSuspend(AgreementUpdater.kt:33)
# 			- "ApplicationImpl@455813375 container":StandaloneCoroutine{Completing} [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 				- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.checkPreviousExternalUploadResult(StatisticsJobsScheduler.kt:129)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$2.invokeSuspend(StatisticsJobsScheduler.kt:44)
# 				- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler.runEventLogStatisticsService(StatisticsJobsScheduler.kt:77)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$3.invokeSuspend(StatisticsJobsScheduler.kt:47)
# 				- "ApplicationImpl@455813375 container":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.internal.statistic.updater.StatisticsJobsSchedulerKt.runValidationRulesUpdate(StatisticsJobsScheduler.kt:106)
# 					at com.intellij.internal.statistic.updater.StatisticsJobsScheduler$execute$2$4.invokeSuspend(StatisticsJobsScheduler.kt:50)
# 			- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger.logApplicationStateRegularly(FUStateUsagesLogger.kt:152)
# 					at com.intellij.internal.statistic.service.fus.collectors.FUStateUsagesLogger$1.invokeSuspend(FUStateUsagesLogger.kt:53)
# 			- "com.intellij.ide.ui.customization.CustomActionsSchema":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "ApplicationImpl@455813375 container":ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "com.intellij.diagnostic.PerformanceWatcherImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.diagnostic.PerformanceWatcherImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.diagnostic.PerformanceWatcherImpl$1.invokeSuspend(PerformanceWatcherImpl.kt:96)
# 					- "com.intellij.diagnostic.PerformanceWatcherImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 			- "com.intellij.ide.ui.laf.LafDynamicPluginManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "FileTypeManager Redetect":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375), LimitedDispatcher@7a928fee]
# 				- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.openapi.fileTypes.impl.AlarmAdapterKt$singleAlarm$1.invokeSuspend(AlarmAdapter.kt:24)
# 					- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.openapi.fileTypes.impl.FileTypeManagerImpl":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "com.intellij.util.net.ssl.CertificateManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.ide.RecentProjectsManagerBase$1.invokeSuspend(RecentProjectsManagerBase.kt:118)
# 					- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.ide.AttachedModuleAwareRecentProjectsManager":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.ide.ui.html.GlobalStyleSheetUpdateService$init$2.invokeSuspend(GlobalStyleSheetHolder.kt:102)
# 					- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 						at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 						at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 						at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 						at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 						- "com.intellij.ide.ui.html.GlobalStyleSheetUpdateService":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 			- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "refresh requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), ModalityState.NON_MODAL, Dispatchers.Default]
# 					at kotlinx.coroutines.selects.SelectImplementation.doSelectSuspend(Select.kt:438)
# 					at kotlinx.coroutines.flow.FlowKt__DelayKt$debounceInternal$1.invokeSuspend(Delay.kt:417)
# 					at kotlinx.coroutines.flow.internal.FlowCoroutineKt$scopedFlow$1$1.invokeSuspend(FlowCoroutine.kt:47)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$1.invokeSuspend(SaveAndSyncHandlerImpl.kt:72)
# 					- "refresh requests flow processing":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), ModalityState.NON_MODAL, Dispatchers.Default]
# 				- "save requests flow processing":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$2.invokeSuspend(SaveAndSyncHandlerImpl.kt:86)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl.listenIdleAndActivate(SaveAndSyncHandlerImpl.kt:171)
# 					at com.intellij.configurationStore.SaveAndSyncHandlerImpl$3.invokeSuspend(SaveAndSyncHandlerImpl.kt:116)
# 				- "com.intellij.configurationStore.SaveAndSyncHandlerImpl":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ApplicationImpl@455813375), Dispatchers.Default]
# 					at com.intellij.util.CoroutinesKt$awaitCancellationAndInvoke$1.invokeSuspend(coroutines.kt:28)
# 			- "com.intellij.util.indexing.FileBasedIndexImpl":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 				- "com.intellij.util.indexing.FileBasedIndexImpl":DeferredCoroutine{Active}, state: RUNNING [ComponentManager(ApplicationImpl@455813375), LimitedDispatcher@384ee14d]
# 					at java.base/jdk.internal.misc.Unsafe.park(Native Method)
# 					at java.base/java.util.concurrent.locks.LockSupport.parkNanos(LockSupport.java:269)
# 					at kotlinx.coroutines.BlockingCoroutine.joinBlocking(Builders.kt:120)
# 					at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking$BuildersKt__BuildersKt(Builders.kt:84)
# 					at kotlinx.coroutines.BuildersKt__BuildersKt.runBlocking(Builders.kt:52)
# 					at kotlinx.coroutines.BuildersKt.runBlocking(Unknown Source)
# 					at com.intellij.util.indexing.IndexDataInitializer$Companion.runParallelTasks(IndexDataInitializer.kt:79)
# 					at com.intellij.util.indexing.IndexDataInitializer.call(IndexDataInitializer.kt:25)
# 					at com.intellij.util.indexing.IndexDataInitializer$Companion$submitGenesisTask$2.invokeSuspend(IndexDataInitializer.kt:70)
# 			- "com.intellij.ide.IdeTooltipManager":supervisor:ChildScope{Active} [ComponentManager(ApplicationImpl@455813375)]
# 			- "ProjectImpl@2029473012 container":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "ProjectImpl@2029473012 container":ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.editorconfig.editorconfigjetbrains)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.jetbrains.plugins.yaml)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 					- "com.intellij.openapi.vcs.changes.ChangeListManagerImpl":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				-[x6 of] "(ProjectImpl@2029473012 x com.intellij)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x hg4idea)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.jetbrains.plugins.webDeployment)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.diagram)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.jetbrains.performancePlugin)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.apacheConfig)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.configurationScript)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x Subversion)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.plugins.watcher)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.platform.images)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.copyright)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.css)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.ideolog)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.jetbrains.plugins.remote-run)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.jetbrains.plugins.vagrant)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.jetbrains.sh)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.completion.ml.ranking)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.jetbrains.restClient)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 					- "com.intellij.httpClient.http.request.run.v2.HttpRequestRunLineMarkerV2EnablingListener":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.swagger)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x intellij.indexing.shared)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x intellij.grid.impl)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x XPathView)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.tasks)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x com.intellij.tasks.timeTracking)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.intellij.intelliLang)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x PerforceDirectPlugin)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x Git4Idea)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 				- "(ProjectImpl@2029473012 x org.jetbrains.plugins.gitlab)":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 					- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.GitLabMergeRequestsToolWindowController":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 						- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.GitLabMergeRequestsToolWindowController":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 					- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012)]
# 						- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 								at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 								at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1.invokeSuspend(CoroutineUtil.kt:224)
# 								at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1.invokeSuspend(CoroutineUtil.kt:203)
# 								- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 									at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1$1.invokeSuspend(CoroutineUtil.kt:209)
# 							- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 								at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1.invokeSuspend(CoroutineUtil.kt:224)
# 								at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1.invokeSuspend(CoroutineUtil.kt:203)
# 								- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 									at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1$1.invokeSuspend(CoroutineUtil.kt:209)
# 									- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: RUNNING [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1$1$1$1$scopeBody$1.invokeSuspend(CoroutineUtil.kt:214)
# 										at com.intellij.collaboration.async.CoroutineUtilKt$mapScoped2$1$1$1$1$1.invokeSuspend(CoroutineUtil.kt:216)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":supervisor:ChildScope{Active} [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 											-[x3 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3064)
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:51)
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 												-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 													at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:28)
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 												- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 													at com.intellij.collaboration.auth.PasswordSafeCredentialsRepository$canPersistCredentials$1.invokeSuspend(PasswordSafeCredentialsRepository.kt:39)
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 												- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":ProducerCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 													at kotlinx.coroutines.flow.internal.ChannelFlowTransformLatest$flowCollect$3.invokeSuspend(Merge.kt:23)
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3064)
# 												at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:51)
# 												at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 												-[x3 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.EDT]
# 													at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:28)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3064)
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 											at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:51)
# 											at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 											-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:28)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatchingOnNoWaiterSuspend-GKJJFZk(BufferedChannel.kt:3064)
# 											at kotlinx.coroutines.channels.BufferedChannel.receiveCatching-JP2dKIU$suspendImpl(BufferedChannel.kt:739)
# 											at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2.invokeSuspend(Combine.kt:51)
# 											at kotlinx.coroutines.flow.FlowKt__ShareKt$launchSharing$1.invokeSuspend(Share.kt:210)
# 											-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1$1.emit(Combine.kt:30)
# 												at kotlinx.coroutines.flow.StateFlowImpl.collect(StateFlow.kt:392)
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:28)
# 											- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 												at kotlinx.coroutines.flow.internal.CombineKt$combineInternal$2$1.invokeSuspend(Combine.kt:28)
# 										- "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# 											at org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabRepositoryAndAccountSelectorViewModel$1.invokeSuspend(GitLabRepositoryAndAccountSelectorViewModel.kt:43)
# 							-[x2 of] "org.jetbrains.plugins.gitlab.mergerequest.ui.toolwindow.model.GitLabToolWindowViewModel":StandaloneCoroutine{Active}, state: SUSPENDED [ComponentManager(ProjectImpl@2029473012), Dispatchers.Default]
# ...
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt$performActivity$runnableWithWIL$1.invoke(IdeEventQueue.kt:1035)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity$lambda$1(IdeEventQueue.kt:1036)
# 	at com.intellij.openapi.application.TransactionGuardImpl.performActivity(TransactionGuardImpl.java:106)
# 	at com.intellij.ide.IdeEventQueueKt.performActivity(IdeEventQueue.kt:1036)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent$lambda$10(IdeEventQueue.kt:351)
# 	at com.intellij.ide.IdeEventQueue.dispatchEvent(IdeEventQueue.kt:397)
# 	at java.desktop/java.awt.EventDispatchThread.pumpOneEventForFilters(EventDispatchThread.java:207)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForFilter(EventDispatchThread.java:128)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEventsForHierarchy(EventDispatchThread.java:117)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:113)
# 	at java.desktop/java.awt.EventDispatchThread.pumpEvents(EventDispatchThread.java:105)
# 	at java.desktop/java.awt.EventDispatchThread.run(EventDispatchThread.java:92)
# 2025-01-19 00:52:46,778 [2408171]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:53:22,395 [2443788]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:53:22,415 [2443808]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:53:22,429 [2443822]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:53:22,439 [2443832]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:53:53,267 [2474660]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:53:54,165 [2475558]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:53:54,315 [2475708]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:53:54,341 [2475734]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:53:54,355 [2475748]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:54:20,609 [2502002]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:54:21,540 [2502933]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:21,541 [2502934]   WARN - #c.j.p.PhpIndex - Completing type '#M#C\App\Models\Rock.hasMany' took 565ms, visited:[#M#C\App\Models\Rock.hasMany]
# 2025-01-19 00:54:21,544 [2502937]   WARN - #c.j.p.PhpIndex - Completing type '#M#C\App\Models\Rock.hasMany' took 575ms, visited:[#M#C\App\Models\Rock.hasMany]
# 2025-01-19 00:54:21,573 [2502966]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:21,649 [2503042]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:54:39,211 [2520604]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:54:53,012 [2534405]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:53,043 [2534436]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:53,047 [2534440]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:54:53,053 [2534446]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:54:53,073 [2534466]   WARN - #c.j.p.PhpIndex - Invalid Signature ' ); ?")'
# 2025-01-19 00:54:54,542 [2535935]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:54:54,659 [2536052]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:54,691 [2536084]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:54,699 [2536092]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:54:54,768 [2536161]   WARN - #c.j.p.PhpIndex - Invalid Signature ' ); ?")'
# 2025-01-19 00:54:59,421 [2540814]   WARN - #c.j.p.PhpIndex - Invalid Signature ' ); ?")'
# 2025-01-19 00:54:59,447 [2540840]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:54:59,466 [2540859]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:59,534 [2540927]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:54:59,539 [2540932]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:55:02,492 [2543885]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:55:02,509 [2543902]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:02,544 [2543937]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:02,577 [2543970]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:55:02,607 [2544000]   WARN - #c.j.p.PhpIndex - Invalid Signature ' ); ?")'
# 2025-01-19 00:55:02,956 [2544349]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:55:03,344 [2544737]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:03,790 [2545183]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:03,811 [2545204]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:55:09,536 [2550929]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:55:10,165 [2551558]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:10,204 [2551597]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:10,206 [2551599]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:55:10,209 [2551602]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:56:14,371 [2615764]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:14,393 [2615786]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:14,464 [2615857]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:56:14,554 [2615947]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:56:32,133 [2633526]   WARN - #c.j.p.PhpIndex - Completing type '#M#C\App\Models\Rock.hasMany' took 581ms, visited:[#M#C\App\Models\Rock.hasMany]
# 2025-01-19 00:56:32,141 [2633534]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:32,185 [2633578]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:56:32,201 [2633594]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:32,213 [2633606]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:56:34,222 [2635615]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:56:34,333 [2635726]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:34,365 [2635758]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:34,404 [2635797]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:56:41,614 [2643007]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:41,694 [2643087]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:56:41,710 [2643103]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:56:41,728 [2643121]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:57:14,799 [2676192]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:01,849 [2723242]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:13,582 [2734975]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:13,820 [2735213]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:13,827 [2735220]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:13,914 [2735307]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:13,953 [2735346]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:58:25,259 [2746652]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:25,276 [2746669]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:25,281 [2746674]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:25,276 [2746669]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:25,276 [2746669]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:25,290 [2746683]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:58:25,321 [2746714]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:25,964 [2747357]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:26,099 [2747492]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:26,191 [2747584]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:26,196 [2747589]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:58:29,991 [2751384]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:48,589 [2769982]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'
# 2025-01-19 00:58:48,714 [2770107]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\HasMany<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:48,750 [2770143]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Relations\BelongsTo<#ᢐ\TRelatedModel.,\Illuminate\Database\Eloquent\Concerns\HasRelationships>'
# 2025-01-19 00:58:48,787 [2770180]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Database\Eloquent\Concerns\class-string<#ᢐ\TRelatedModel.>'
# 2025-01-19 00:58:52,547 [2773940]   WARN - #c.j.p.PhpIndex - Invalid Signature '\Illuminate\Contracts\Support\Arrayable<#ᢐ\TKey.,#ᢐ\TValue.>'

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3

# %%
seleniumServer.kill()

# %%
# %cd ..

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
