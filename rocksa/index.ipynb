# %% [markdown]
# # PHP

# %% [markdown]
# ## 9. Laravel TDD

# %% [markdown]
# This project was started from the solution of the previous exercise.
#
# #### Laravel Breeze
#
# The [Laravel Breeze](https://laravel.com/docs/11.x/starter-kits#laravel-breeze) package was installed using the ```composer require laravel/breeze --dev``` and ```php artisan breeze:install``` commands. This package enables user registration and logging into the application.
#
# An example user is added through the [database/seeders/UsersSeeder.php](/edit/09_laravel_tdd/project/database/seeders/UsersSeeder.php) class generated using the ```php artisan make:seeder UsersSeeder``` command. The database seeding is done during the execution of the ```php artisan db:seed``` command before the database dump.
#
# The logging-in is tested in the [tests_codeception/Acceptance/Test02_LoginCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test02_LoginCest.php) test.
#
# Extensive testing is also done when executing the ```php artisan test``` command because the ```php artisan breeze:install``` command added many additional tests.
#
# Because there are many tests, it was possible to safely clean up PHPStan issues in the code added by ```php artisan breeze:install``` command.
#
# #### Laravel Markdown
#
# The next change done in the project was the use of the [graham-campbell/markdown](https://packagist.org/packages/graham-campbell/markdown) package, which adds support for Markdown in Laravel.
#
# The package was installed using the ```composer require graham-campbell/markdown``` command.
# The [tests_codeception/Acceptance/Test01_CommentsCest.php](/edit/09_laravel_tdd/project/tests_codeception/Acceptance/Test01_CommentsCest.php) test was extended to test for adding some **bold** text. The [resources/views/comment/show.blade.php](/edit/09_laravel_tdd/project/resources/views/comment/show.blade.php) view was updated to render the Markdown.
#
# #### Tailwind CSS
#
# The [tailwindcss](https://tailwindcss.com/) is used to style the front end. Some examples of how to build components in HTML with CSS can be found on, e.g., [flowbite](https://flowbite.com/) site.
#
# However, I am not an expert here, so there might be much better resources ;)

# %% [markdown]
# Start database:

# %%
! docker run --name=mysql --net=host --rm --env MYSQL_ROOT_PASSWORD=root123 --env MYSQL_ROOT_HOST=% --env MYSQL_DATABASE=test --env MYSQL_USER=test --env MYSQL_PASSWORD=test123 -d mysql/mysql-server:8.0
# Out:
# 2082e9181cc7aa38d40337dbdeb2eccd9b5d04db18526a94be42b1a1fa3ebb5d

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306" 2> /dev/null; do sleep 1; done; echo "Done.";
# Out:
# Done.

# %% [markdown]
# Install the CPD checker globally:

# %%
! composer global require sebastian/phpcpd 6.0.3 --dev
# Out:
# Changed current directory to /home/student/.composer
# ./composer.json has been updated
# Running composer update sebastian/phpcpd
# Loading composer repositories with package information
# Updating dependencies
# Nothing to modify in lock file
# Writing lock file
# Installing dependencies from lock file (including require-dev)
# Nothing to install, update or remove
# Package sebastian/phpcpd is abandoned, you should avoid using it. No replacement was suggested.
# Generating autoload files
# 5 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!
# No security vulnerability advisories found.

# %% [markdown]
# You can test your solution using included tests:

# %%
# %cd project
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa/project

# %%
! composer install
# Out:
# Installing dependencies from lock file (including require-dev)
# Verifying lock file contents can be installed on current platform.
# Warning: The lock file is not up to date with the latest changes in composer.json. You may be getting outdated dependencies. It is recommended that you run `composer update` or `composer update <package name>`.
# Nothing to install, update or remove
# Generating optimized autoload files
# > Illuminate\Foundation\ComposerScripts::postAutoloadDump
# > @php artisan package:discover --ansi
#
#    INFO  Discovering packages.
#
#   andreiio/blade-remix-icon ............................................. DONE
#   blade-ui-kit/blade-icons .............................................. DONE
#   graham-campbell/markdown .............................................. DONE
#   laravel/breeze ........................................................ DONE
#   laravel/pail .......................................................... DONE
#   laravel/sail .......................................................... DONE
#   laravel/tinker ........................................................ DONE
#   livewire/livewire ..................................................... DONE
#   nesbot/carbon ......................................................... DONE
#   nunomaduro/collision .................................................. DONE
#   nunomaduro/termwind ................................................... DONE
#
# 108 packages you are using are looking for funding.
# Use the `composer fund` command to find out more!

# %%
! vendor/bin/codecept build
# Out:
# Building Actor classes for suites: Acceptance
#  -> AcceptanceTesterActions.php generated successfully. 111 methods added
# TestsCodeception\AcceptanceTester includes modules: WebDriver, Db

# %%
! vendor/bin/php-cs-fixer fix --diff --dry-run .
# Out:
# PHP CS Fixer 3.68.1 Persian Successor by Fabien Potencier, Dariusz Ruminski and contributors.
# PHP runtime: 8.3.6
# Running analysis on 1 core sequentially.
# You can enable parallel runner and speed up the analysis! Please see ]8;;https://cs.symfony.com/doc/usage.html\usage docs]8;;\ for more information.
# Loaded config default from "/home/student/Desktop/php_2024_iad_rocksa/rocksa/project/./.php-cs-fixer.dist.php".
# Using cache file ".php-cs-fixer.cache".
#    0/138 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  14/138 [▓▓░░░░░░░░░░░░░░░░░░░░░░░░░░]  10%  28/138 [▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░]  20%  42/138 [▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░░░░]  30%  56/138 [▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░░░░]  40%  69/138 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░░░░]  50%  97/138 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░]  70% 111/138 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░]  80% 125/138 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░]  90% 138/138 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#    1) app/Models/OrderItems.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/OrderItems.php
# @@ -20,7 +20,8 @@
#
#      }
#
# -    public function rocks(){
# +    public function rocks()
# +    {
#
#          return $this -> belongsTo(Rock::class);
#
#
#       ----------- end diff -----------
#
#    2) app/Models/User.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/User.php
# @@ -62,4 +62,3 @@
#      }
#
#  }
# -
#
#       ----------- end diff -----------
#
#    3) app/Models/Rock.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Rock.php
# @@ -35,4 +35,3 @@
#
#
#  }
# -
#
#       ----------- end diff -----------
#
#    4) app/Models/Comment.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Comment.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Models/Comment.php
# @@ -14,7 +14,8 @@
#
#      }
#
# -    public function rock(){
# +    public function rock()
# +    {
#
#          return $this -> belongsTo(Rock::class);
#
#
#       ----------- end diff -----------
#
#    5) app/Http/Controllers/CommentController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/CommentController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/CommentController.php
# @@ -7,7 +7,6 @@
#  use Illuminate\Http\Request;
#  use Illuminate\Http\RedirectResponse;
#
# -
#  class CommentController extends Controller
#  {
#      public function show(Comment $comment)
#
#       ----------- end diff -----------
#
#    6) app/Http/Controllers/OrderController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/OrderController.php
# @@ -1,4 +1,5 @@
#  <?php
# +
#  namespace App\Http\Controllers;
#
#  use App\Http\Requests\StoreOrderRequest;
# @@ -33,7 +34,7 @@
#
#          $data = $request->validated();
#          $data['user_id'] = auth()->id();
# -        $data['total'] = collect($cart)->sum(fn($item) => $item['price'] * $item['quantity']);
# +        $data['total'] = collect($cart)->sum(fn ($item) => $item['price'] * $item['quantity']);
#          $order = Order::create($data);
#
#          foreach ($cart as $rockId => $item) {
# @@ -90,5 +91,3 @@
#      }
#
#  }
# -
# -
#
#       ----------- end diff -----------
#
#    7) app/Http/Controllers/orderItemsController.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Http/Controllers/orderItemsController.php
# @@ -8,6 +8,7 @@
#  use App\Models\OrderItems;
#  use Illuminate\Http\RedirectResponse;
#  use Illuminate\View\View;
# +
#  class orderItemsController extends Controller
#  {
#      public function store(StoreOrderItemsRequest $request): RedirectResponse
#
#       ----------- end diff -----------
#
#    8) app/Providers/AppServiceProvider.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Providers/AppServiceProvider.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/app/Providers/AppServiceProvider.php
# @@ -7,7 +7,6 @@
#  use Illuminate\Support\ServiceProvider;
#  use Illuminate\Support\Facades\View;
#
# -
#  class AppServiceProvider extends ServiceProvider
#  {
#      /**
#
#       ----------- end diff -----------
#
#    9) database/seeders/DatabaseSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/DatabaseSeeder.php
# @@ -8,7 +8,6 @@
#  // use Database\Seeders\InsertTestSeeder;
#  use Database\Seeders\InsertTestSeeder;
#
# -
#  class DatabaseSeeder extends Seeder
#  {
#      /**
#
#       ----------- end diff -----------
#
#   10) database/seeders/InsertTestSeeder.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/seeders/InsertTestSeeder.php
# @@ -5,6 +5,7 @@
#  use Illuminate\Database\Seeder;
#  use Illuminate\Support\Facades\DB;
#  use Illuminate\Support\Facades\Hash;
# +
#  // use Illuminate\Support\Facades\File;
#
#  class InsertTestSeeder extends Seeder
# @@ -25,11 +26,11 @@
#          ]);
#
#
# -         // $quartzImagePath = public_path('/static/rock1.jpg');
# -         // $diamondImagePath = public_path('/static/rock2.jpg');
# +        // $quartzImagePath = public_path('/static/rock1.jpg');
# +        // $diamondImagePath = public_path('/static/rock2.jpg');
#
# -         // $quartzImage = file_get_contents($quartzImagePath);
# -         // $diamondImage = file_get_contents($diamondImagePath);
# +        // $quartzImage = file_get_contents($quartzImagePath);
# +        // $diamondImage = file_get_contents($diamondImagePath);
#
#
#          // Dodanie kamieni przypisanych do użytkownika
# @@ -73,4 +74,3 @@
#          ]);
#      }
#  }
# -
#
#       ----------- end diff -----------
#
#   11) database/migrations/2025_01_11_create_orders_table.php
#       ---------- begin diff ----------
# --- /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# +++ /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/database/migrations/2025_01_11_create_orders_table.php
# @@ -5,7 +5,6 @@
#  use Illuminate\Support\Facades\Schema;
#
#  return new class () extends Migration {
# -
#      /**
#       * Run the migrations.
#       *
# @@ -39,4 +38,3 @@
#          Schema::dropIfExists('orders');
#      }
#  };
# -
#
#       ----------- end diff -----------
#
#
# Found 11 of 138 files that can be fixed in 1.922 seconds, 20.00 MB memory used

# %%
! vendor/bin/phpstan analyze -c phpstan.neon
# Out:
#    0/129 [░░░░░░░░░░░░░░░░░░░░░░░░░░░░]   0%  20/129 [▓▓▓▓░░░░░░░░░░░░░░░░░░░░░░░░]  15%  80/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░░░░░]  62% 100/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░░░]  77% 109/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓░░░░░]  84% 129/129 [▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓▓] 100%
#
#  ------ --------------------------------------------------------------------------
#   Line   app/Http/Controllers/CategoryController.php
#  ------ --------------------------------------------------------------------------
#   11     Method App\Http\Controllers\CategoryController::show() has no return
#          type specified.
#          🪪  missingType.return
#   11     Method App\Http\Controllers\CategoryController::show() has parameter
#          $slug with no type specified.
#          🪪  missingType.parameter
#   13     Relation 'children' is not found in App\Models\Category model.
#          🪪  larastan.relationExistence
#   19     Access to an undefined property App\Models\Category::$children.
#          🪪  property.notFound
#          💡 Learn more:
#             https://phpstan.org/blog/solving-phpstan-access-to-undefined-property
#   30     Method App\Http\Controllers\CategoryController::getAllRocks() return
#          type with generic class Illuminate\Support\Collection does not
#          specify its types: TKey, TValue
#          🪪  missingType.generics
#   32     Access to an undefined property App\Models\Category::$rocks.
#          🪪  property.notFound
#          💡 Learn more:
#             https://phpstan.org/blog/solving-phpstan-access-to-undefined-property
#   34     Access to an undefined property App\Models\Category::$children.
#          🪪  property.notFound
#          💡 Learn more:
#             https://phpstan.org/blog/solving-phpstan-access-to-undefined-property
#   34     Cannot call method flatMap() on mixed.
#          🪪  method.nonObject
#   35     Parameter #1 $category of method
#          App\Http\Controllers\CategoryController::getAllRocks() expects
#          App\Models\Category, mixed given.
#          🪪  argument.type
#   38     Cannot call method merge() on mixed.
#          🪪  method.nonObject
#   38     Method App\Http\Controllers\CategoryController::getAllRocks() should
#          return Illuminate\Support\Collection but returns mixed.
#          🪪  return.type
#  ------ --------------------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   app/Http/Controllers/CommentController.php
#  ------ -----------------------------------------------------------------------
#   13     Method App\Http\Controllers\CommentController::show() has no return
#          type specified.
#          🪪  missingType.return
#   25     Cannot access offset 'content' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   25     Property App\Models\Comment::$content (string) does not accept mixed.
#          🪪  assign.propertyType
#   26     Property App\Models\Comment::$user_id (int) does not accept
#          int|string|null.
#          🪪  assign.propertyType
#  ------ -----------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------
#   Line   app/Http/Controllers/DashboardController.php
#  ------ ----------------------------------------------------------------
#   14     Relation 'children' is not found in App\Models\Category model.
#          🪪  larastan.relationExistence
#  ------ ----------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------------------
#   Line   app/Http/Controllers/OrderController.php
#  ------ -----------------------------------------------------------------------------------
#   36     Binary operation "*" between mixed and mixed results in an error.
#          🪪  binaryOp.invalid
#   36     Cannot access offset 'price' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   36     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   36     Parameter #1 $value of function collect expects
#          Illuminate\Contracts\Support\Arrayable<(int|string),
#          mixed>|iterable<(int|string), mixed>|null, mixed given.
#          🪪  argument.type
#   36     Unable to resolve the template type TKey in call to function collect
#          🪪  argument.templateType
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-error-unable-to-resolve-template-type
#   36     Unable to resolve the template type TValue in call to function
#          collect
#          🪪  argument.templateType
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-error-unable-to-resolve-template-type
#   39     Argument of an invalid type mixed supplied for foreach, only
#          iterables are supported.
#          🪪  foreach.nonIterable
#   43     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   44     Cannot access offset 'price' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#  ------ -----------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/Cart.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\Cart::$cart type has no value type specified in
#          iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   14     Property App\Livewire\Cart::$listeners has no type specified.
#          🪪  missingType.property
#   21     Method App\Livewire\Cart::mount() has no return type specified.
#          🪪  missingType.return
#   26     Method App\Livewire\Cart::toggleCart() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has no return type
#          specified.
#          🪪  missingType.return
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $image with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $name with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $price with
#          no type specified.
#          🪪  missingType.parameter
#   30     Method App\Livewire\Cart::handleAddToCart() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   32     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   34     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   35     Binary operation "+=" between mixed and 1 results in an error.
#          🪪  assignOp.invalid
#   35     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   37     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   51     Method App\Livewire\Cart::updateQuantity() has no return type
#          specified.
#          🪪  missingType.return
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $change with
#          no type specified.
#          🪪  missingType.parameter
#   51     Method App\Livewire\Cart::updateQuantity() has parameter $productId
#          with no type specified.
#          🪪  missingType.parameter
#   53     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   55     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   56     Binary operation "+=" between mixed and mixed results in an error.
#          🪪  assignOp.invalid
#   56     Cannot access offset 'quantity' on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   57     Comparison operation "<=" between (array|float|int) and 0 results in
#          an error.
#          🪪  smallerOrEqual.invalid
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has no return type
#          specified.
#          🪪  missingType.return
#   68     Method App\Livewire\Cart::handleRemoveFromCart() has parameter
#          $productId with no type specified.
#          🪪  missingType.parameter
#   70     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   72     Cannot access offset mixed on mixed.
#          🪪  offsetAccess.nonOffsetAccessible
#   73     Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   88     Method App\Livewire\Cart::clearCart() has no return type specified.
#          🪪  missingType.return
#   100    Method App\Livewire\Cart::refreshCart() has no return type specified.
#          🪪  missingType.return
#   102    Property App\Livewire\Cart::$cart (array) does not accept mixed.
#          🪪  assign.propertyType
#   105    Method App\Livewire\Cart::render() has no return type specified.
#          🪪  missingType.return
#   109    Method App\Livewire\Cart::proceedToCheckout() has no return type
#          specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Livewire/RockCard.php
#  ------ --------------------------------------------------------------------------------------
#   10     Property App\Livewire\RockCard::$data type has no value type
#          specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   17     Method App\Livewire\RockCard::mount() has no return type specified.
#          🪪  missingType.return
#   38     Method App\Livewire\RockCard::render() has invalid return type
#          App\Livewire\View.
#          🪪  class.notFound
#  ------ --------------------------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------------------------
#   Line   app/Models/Category.php
#  ------ --------------------------------------------------------------------------------------
#   21     PHPDoc type array of property App\Models\Category::$fillable is not
#          covariant with PHPDoc type list<string> of overridden property
#          Illuminate\Database\Eloquent\Model::$fillable.
#          🪪  property.phpDocType
#          💡 You can fix 3rd party PHPDoc types with stub files:
#          💡 https://phpstan.org/user-guide/stub-files
#
#   21     Property App\Models\Category::$fillable type has no value type
#          specified in iterable type array.
#          🪪  missingType.iterableValue
#          💡 See:
#             https://phpstan.org/blog/solving-phpstan-no-value-type-specified-in-iterable-type
#   26     Method App\Models\Category::parent() has no return type specified.
#          🪪  missingType.return
#   31     Method App\Models\Category::children() has no return type specified.
#          🪪  missingType.return
#   35     Method App\Models\Category::rocks() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------
#   Line   app/Models/Comment.php
#  ------ -----------------------------------------------------------------
#   10     Method App\Models\Comment::user() has no return type specified.
#          🪪  missingType.return
#   17     Method App\Models\Comment::rock() has no return type specified.
#          🪪  missingType.return
#  ------ -----------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/Order.php
#  ------ ---------------------------------------------------------------------
#   23     Method App\Models\Order::user() has no return type specified.
#          🪪  missingType.return
#   28     Method App\Models\Order::orderItems() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ ---------------------------------------------------------------------
#   Line   app/Models/OrderItems.php
#  ------ ---------------------------------------------------------------------
#   16     Method App\Models\OrderItems::order() has no return type specified.
#          🪪  missingType.return
#   23     Method App\Models\OrderItems::rocks() has no return type specified.
#          🪪  missingType.return
#  ------ ---------------------------------------------------------------------
#
#  ------ --------------------------------------------------------------------
#   Line   app/Models/Rock.php
#  ------ --------------------------------------------------------------------
#   16     Method App\Models\Rock::orderItems() has no return type specified.
#          🪪  missingType.return
#   20     Method App\Models\Rock::user() has no return type specified.
#          🪪  missingType.return
#   25     Method App\Models\Rock::comments() has no return type specified.
#          🪪  missingType.return
#   30     Method App\Models\Rock::category() has no return type specified.
#          🪪  missingType.return
#  ------ --------------------------------------------------------------------
#
#  ------ ------------------------------------------------------------------
#   Line   app/Models/User.php
#  ------ ------------------------------------------------------------------
#   50     Method App\Models\User::rocks() has no return type specified.
#          🪪  missingType.return
#   55     Method App\Models\User::orders() has no return type specified.
#          🪪  missingType.return
#   59     Method App\Models\User::comments() has no return type specified.
#          🪪  missingType.return
#  ------ ------------------------------------------------------------------
#
#  ------ ----------------------------------------------------------------------
#   Line   database/seeders/RockDatabaseSeeder.php
#  ------ ----------------------------------------------------------------------
#   16     Method Database\Seeders\RockDatabaseSeeder::run() has no return type
#          specified.
#          🪪  missingType.return
#   252    Cannot access property $id on App\Models\User|null.
#          🪪  property.nonObject
#  ------ ----------------------------------------------------------------------
#
#  ------ -----------------------------------------------------------------------
#   Line   tests/Unit/ExampleTest.php
#  ------ -----------------------------------------------------------------------
#   19     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   19     No error with identifier method.alreadyNarrowedType is reported on
#          line 19.
#   24     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   24     No error with identifier method.alreadyNarrowedType is reported on
#          line 24.
#   29     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   29     No error with identifier method.alreadyNarrowedType is reported on
#          line 29.
#   33     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   33     No error with identifier method.alreadyNarrowedType is reported on
#          line 33.
#   37     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   37     No error with identifier method.alreadyNarrowedType is reported on
#          line 37.
#   41     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   41     No error with identifier method.alreadyNarrowedType is reported on
#          line 41.
#   46     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   46     No error with identifier method.alreadyNarrowedType is reported on
#          line 46.
#   51     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   51     No error with identifier method.alreadyNarrowedType is reported on
#          line 51.
#   56     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   56     No error with identifier method.alreadyNarrowedType is reported on
#          line 56.
#   61     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   61     No error with identifier method.alreadyNarrowedType is reported on
#          line 61.
#   66     Call to method PHPUnit\Framework\Assert::assertTrue() with false will
#          always evaluate to false.
#          🪪  method.impossibleType
#   66     No error with identifier method.alreadyNarrowedType is reported on
#          line 66.
#  ------ -----------------------------------------------------------------------
#
#
#  [ERROR] Found 103 errors

# %%
! ~/.composer/vendor/bin/phpcpd . --fuzzy --min-lines 1 --min-tokens 35 --exclude vendor --exclude config --exclude storage --exclude tests_codeception/Support/_generated
# Out:
# phpcpd 6.0.3 by Sebastian Bergmann.
#
# Found 1 clones with 13 duplicated lines in 1 files:
#
#   - /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test04_RocksCest.php:87-100 (13 lines)
#     /home/student/Desktop/php_2024_iad_rocksa/rocksa/project/tests_codeception/Acceptance/Test04_RocksCest.php:105-118
#
# 0.22% duplicated lines out of 5901 total lines of code.
# Average size of duplication is 13 lines, largest clone has 13 of lines
#
# Time: 00:00.047, Memory: 4.00 MB

# %%
! cp .env.example .env

# %%
! php artisan key:generate
# Out:
#    INFO  Application key set successfully.

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/3306"; do echo "Waiting for MySQL..."; sleep 1; done

# %%
! php artisan migrate:fresh
# Out:
#   Dropping all tables ................................................ 1s DONE
#
#    INFO  Preparing database.
#
#   Creating migration table ..................................... 325.49ms DONE
#
#    INFO  Running migrations.
#
#   0001_01_01_000000_create_users_table ............................... 1s DONE
#   0001_01_01_000001_create_cache_table ......................... 419.34ms DONE
#   0001_01_01_000002_create_jobs_table ................................ 1s DONE
#   2024_01_19_230609_create_categories_table .................... 396.48ms DONE
#   2024_12_07_094911_create_books_table ............................... 1s DONE
#   2025_01_10_create_rocks_table ................................ 854.60ms DONE
#   2025_01_11_145411_create_comments_table ............................ 1s DONE
#   2025_01_11_create_orders_table ............................... 991.03ms DONE
#   2025_01_14_151420_add_user_id_to_rocks_table ....................... 1s DONE
#   2025_01_14_153906_order_items_table ................................ 1s DONE

# %%
! php artisan db:seed
# Out:
#    INFO  Seeding database.
#
#   Database\Seeders\UsersSeeder ....................................... RUNNING
#   Database\Seeders\UsersSeeder ................................... 454 ms DONE
#
#   Database\Seeders\InsertTestSeeder .................................. RUNNING
#   2025-01-22 02:11:48 /static/amethyst2.jpg ............................ ~ 1s
#   2025-01-22 02:11:49 /favicon.ico ................................. ~ 0.15ms
#   2025-01-22 02:12:15 /rocks/3 ................................... ~ 501.05ms
#   2025-01-22 02:12:15 /static/logo.svg ............................. ~ 4.60ms
#   2025-01-22 02:12:15 /static/gradient_bg.jpg ...................... ~ 1.45ms
#   2025-01-22 02:12:15 /favicon.ico ................................. ~ 0.22ms
#   2025-01-22 02:12:34 /rocks/3/comments .......................... ~ 500.98ms
#   2025-01-22 02:12:34 /rocks/3 ................................... ~ 522.68ms
#   2025-01-22 02:12:35 /static/logo.svg ............................. ~ 0.13ms
#   2025-01-22 02:12:35 /static/gradient_bg.jpg ...................... ~ 0.29ms
#   2025-01-22 02:12:35 /favicon.ico ................................. ~ 0.13ms
#   2025-01-22 02:12:42 /rocks/3/comments .......................... ~ 509.52ms
#   2025-01-22 02:12:42 /rocks/3 ................................... ~ 506.22ms
#   2025-01-22 02:12:43 /static/logo.svg ............................. ~ 0.47ms
#   2025-01-22 02:12:43 /static/gradient_bg.jpg ...................... ~ 2.85ms
#   2025-01-22 02:12:43 /favicon.ico ................................. ~ 1.98ms

# %%
! mysqldump -h127.0.0.1 -u root --password=root123 test > tests_codeception/Support/Data/dump.sql
# Out:
# mysqldump: [Warning] Using a password on the command line interface can be insecure.

# %%
! npm install
# Out:
# ⠙⠹⠸⠼⠴⠦⠧⠇⠏⠋⠙⠹⠸⠼
# up to date, audited 172 packages in 9s
# ⠼
# ⠼40 packages are looking for funding
# ⠼  run `npm fund` for details
# ⠼
# found 0 vulnerabilities
# ⠼

# %%
! npm run build
# Out:
# > build
# > vite build
#
# vite v5.4.11 building for production...
# transforming (1) resources/js/app.jstransforming (2) resources/js/bootstrap.jstransforming (4) node_modules/axios/index.jstransforming (20) node_modules/axios/lib/helpers/spread.jstransforming (23) node_modules/axios/lib/core/InterceptorManager.jstransforming (34) node_modules/axios/lib/adapters/fetch.jstransforming (39) node_modules/axios/lib/platform/browser/index.jstransforming (43) node_modules/axios/lib/helpers/progressEventReducer.js[2transforming (47) node_modules/axios/lib/platform/browser/classes/FormData.transforming (52) node_modules/axios/lib/helpers/cookies.js✓ 53 modules transformed.
# rendering chunks (1)...rendering chunks (2)...computing gzip size (0)...computing gzip size (1)...computing gzip size (2)...computing gzip size (3)...public/build/manifest.json             0.27 kB │ gzip:  0.15 kB
# public/build/assets/app-BIY6QqP4.css  41.44 kB │ gzip:  7.47 kB
# public/build/assets/app-D-FaURHc.js   34.85 kB │ gzip: 14.03 kB
# ✓ built in 15.48s
# ⠙

# %%
! php artisan test
# Out:
#    FAIL  Tests\Unit\ExampleTest
#   ✓ that true is true                                                    0.02s
#   ⨯ add to cart                                                          0.04s
#   ⨯ remove from cart
#   ⨯ edit name
#   ⨯ edit email
#   ⨯ edit phone number
#   ⨯ edit password
#   ⨯ calculate cost
#   ⨯ add rock
#   ⨯ remove rock
#   ⨯ add filter
#   ⨯ remove filter
#
#    PASS  Tests\Feature\Auth\AuthenticationTest
#   ✓ login screen can be rendered                                        17.16s
#   ✓ users can authenticate using the login screen                        1.08s
#   ✓ users can not authenticate with invalid password                     0.82s
#   ✓ users can logout                                                     1.05s
#
#    PASS  Tests\Feature\Auth\EmailVerificationTest
#   ✓ email verification screen can be rendered                            0.68s
#   ✓ email can be verified                                                0.58s
#   ✓ email is not verified with invalid hash                              0.32s
#
#    PASS  Tests\Feature\Auth\PasswordConfirmationTest
#   ✓ confirm password screen can be rendered                              0.29s
#   ✓ password can be confirmed                                            0.38s
#   ✓ password is not confirmed with invalid password                      0.80s
#
#    PASS  Tests\Feature\Auth\PasswordResetTest
#   ✓ reset password link screen can be rendered                           0.41s
#   ✓ reset password link can be requested                                 0.63s
#   ✓ reset password screen can be rendered                                0.56s
#   ✓ password can be reset with valid token                               1.25s
#
#    PASS  Tests\Feature\Auth\PasswordUpdateTest
#   ✓ password can be updated                                              0.72s
#   ✓ correct password must be provided to update password                 0.33s
#
#    PASS  Tests\Feature\Auth\RegistrationTest
#   ✓ registration screen can be rendered                                  0.32s
#   ✓ new users can register                                               0.26s
#
#    PASS  Tests\Feature\ExampleTest
#   ✓ the application returns a successful response                        0.29s
#
#    PASS  Tests\Feature\ProfileTest
#   ✓ profile page is displayed                                            0.35s
#   ✓ profile information can be updated                                   0.30s
#   ✓ email verification status is unchanged when the email address is un… 0.76s
#   ✓ user can delete their account                                        0.61s
#   ✓ correct password must be provided to delete account                  0.49s
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add to cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:19
#      15▕     }
#      16▕     // Add to cart
#      17▕     public function test_add_to_cart(): void
#      18▕     {
#   ➜  19▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#
#   1   tests/Unit/ExampleTest.php:19
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove from cart
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:24
#      20▕     }
#      21▕     // Remove from cart
#      22▕     public function test_remove_from_cart(): void
#      23▕     {
#   ➜  24▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#
#   1   tests/Unit/ExampleTest.php:24
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit name
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:29
#      25▕     }
#      26▕     // Edit name, etc
#      27▕     public function test_edit_name(): void
#      28▕     {
#   ➜  29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:29
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit email
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:33
#      29▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      30▕     }
#      31▕     public function test_edit_email(): void
#      32▕     {
#   ➜  33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:33
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit phone number
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:37
#      33▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      34▕     }
#      35▕     public function test_edit_phone_number(): void
#      36▕     {
#   ➜  37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#      41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#
#   1   tests/Unit/ExampleTest.php:37
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > edit password
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:41
#      37▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      38▕     }
#      39▕     public function test_edit_password(): void
#      40▕     {
#   ➜  41▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#
#   1   tests/Unit/ExampleTest.php:41
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > calculate cost
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:46
#      42▕     }
#      43▕     // Calculate cost
#      44▕     public function test_calculate_cost(): void
#      45▕     {
#   ➜  46▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#
#   1   tests/Unit/ExampleTest.php:46
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:51
#      47▕     }
#      48▕     // Add rock
#      49▕     public function test_add_rock(): void
#      50▕     {
#   ➜  51▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#
#   1   tests/Unit/ExampleTest.php:51
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove rock
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:56
#      52▕     }
#      53▕     // Remove rock
#      54▕     public function test_remove_rock(): void
#      55▕     {
#   ➜  56▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#
#   1   tests/Unit/ExampleTest.php:56
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > add filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:61
#      57▕     }
#      58▕     // Add filter
#      59▕     public function test_add_filter(): void
#      60▕     {
#   ➜  61▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#
#   1   tests/Unit/ExampleTest.php:61
#
#   ────────────────────────────────────────────────────────────────────────────
#    FAILED  Tests\Unit\ExampleTest > remove filter
#   Failed asserting that false is true.
#
#   at tests/Unit/ExampleTest.php:66
#      62▕     }
#      63▕     // Remove filter
#      64▕     public function test_remove_filter(): void
#      65▕     {
#   ➜  66▕         $this->assertTrue(false); // @phpstan-ignore method.alreadyNarrowedType
#      67▕     }
#      68▕ }
#      69▕
#
#   1   tests/Unit/ExampleTest.php:66
#
#
#   Tests:    11 failed, 25 passed (74 assertions)
#   Duration: 31.05s

# %%
import subprocess, os
os.environ["PATH"] += os.pathsep + '/opt/selenium/'
seleniumServer = subprocess.Popen(['java', '-jar', 'selenium-server-4.24.0.jar', 'standalone'], cwd='/opt/selenium/')

# %%
import subprocess
artisanServe = subprocess.Popen(['php', 'artisan', 'serve', '--port', '8888'])

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/4444"; do echo "Waiting for Selenium..."; sleep 1; done
# Out:
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
#
#    INFO  Server running on [http://127.0.0.1:8888].
#
#   Press Ctrl+C to stop the server
#
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 23:47:25.917 INFO [LoggingOptions.configureLogEncoding] - Using the system default encoding
# 23:47:25.987 INFO [OpenTelemetryTracer.createTracer] - Using OpenTelemetry for tracing
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
#   2025-01-21 23:47:27 / ................................................ ~ 3s
#   2025-01-21 23:47:31 /build/assets/app-BIY6QqP4.css ............... ~ 6.95ms
#   2025-01-21 23:47:31 /build/assets/app-D-FaURHc.js ................ ~ 3.45ms
#   2025-01-21 23:47:31 /static/logo.svg ............................. ~ 7.16ms
#   2025-01-21 23:47:31 /static/hand.png ............................ ~ 16.80ms
# 23:47:31.955 INFO [NodeOptions.getSessionFactories] - Detected 4 available processors
# 23:47:31.963 INFO [NodeOptions.discoverDrivers] - Looking for existing drivers on the PATH.
# 23:47:31.964 INFO [NodeOptions.discoverDrivers] - Add '--selenium-manager true' to the startup command to setup drivers automatically.
#   2025-01-21 23:47:31 /static/gradient_bg.jpg ..................... ~ 11.78ms
#   2025-01-21 23:47:31 /favicon.ico ................................. ~ 1.92ms
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 23:47:35.632 WARN [SeleniumManager.lambda$runCommand$1] - Exception managing chrome: Unable to discover proper chromedriver version in offline mode
# 23:47:35.673 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper msedgedriver version in offline mode
# 23:47:35.713 WARN [SeleniumManager.lambda$runCommand$1] - Unable to discover proper geckodriver version in offline mode
# 23:47:35.753 INFO [NodeOptions.report] - Adding Edge for {"browserName": "MicrosoftEdge","platformName": "linux"} 4 times
# 23:47:35.761 INFO [NodeOptions.report] - Adding Firefox for {"browserName": "firefox","platformName": "linux"} 4 times
# 23:47:35.769 INFO [NodeOptions.report] - Adding Chrome for {"browserName": "chrome","platformName": "linux"} 4 times
# 23:47:35.815 INFO [Node.<init>] - Binding additional locator mechanisms: relative
# 23:47:35.872 INFO [GridModel.setAvailability] - Switching Node 045301aa-6707-4999-a797-64d7c2587a71 (uri: http://172.17.0.1:4444) from DOWN to UP
# 23:47:35.873 INFO [LocalDistributor.add] - Added node 045301aa-6707-4999-a797-64d7c2587a71 at http://172.17.0.1:4444. Health check every 120s
# bash: connect: Connection refused
# bash: line 1: /dev/tcp/localhost/4444: Connection refused
# Waiting for Selenium...
# 23:47:36.560 INFO [Standalone.execute] - Started Selenium Standalone 4.24.0 (revision 748ffc9bc3): http://172.17.0.1:4444

# %%
! while ! timeout 1 bash -c "echo > /dev/tcp/localhost/8888"; do echo "Waiting for App..."; sleep 1; done
# Out:
#   2025-01-21 23:47:37 .............................................. ~ 0.39ms
#   2025-01-21 23:47:38 /login ..................................... ~ 502.90ms
#   2025-01-21 23:47:39 /build/assets/app-BIY6QqP4.css ............... ~ 0.72ms
#   2025-01-21 23:47:39 /build/assets/app-D-FaURHc.js ................ ~ 6.36ms
#   2025-01-21 23:47:39 /static/logo.svg ............................. ~ 8.47ms
#   2025-01-21 23:47:39 /static/gradient_bg.jpg ...................... ~ 7.33ms
#   2025-01-21 23:47:39 /favicon.ico ................................. ~ 2.29ms
#   2025-01-21 23:47:47 /login ........................................... ~ 1s
#   2025-01-21 23:47:48 /login ..................................... ~ 733.56ms
#   2025-01-21 23:47:49 /static/logo.svg ............................ ~ 11.32ms
#   2025-01-21 23:47:49 /build/assets/app-D-FaURHc.js ............... ~ 15.41ms
#   2025-01-21 23:47:49 /build/assets/app-BIY6QqP4.css .............. ~ 34.14ms
#   2025-01-21 23:47:49 /static/gradient_bg.jpg ...................... ~ 1.47ms
#   2025-01-21 23:47:49 /favicon.ico ................................. ~ 0.89ms
#   2025-01-21 23:47:58 /login ..................................... ~ 506.38ms
#   2025-01-21 23:47:59 /login ..................................... ~ 511.39ms
#   2025-01-21 23:47:59 /build/assets/app-D-FaURHc.js .............. ~ 501.13ms
#   2025-01-21 23:47:59 /static/logo.svg ........................... ~ 502.88ms
#   2025-01-21 23:47:59 /build/assets/app-BIY6QqP4.css ............. ~ 504.75ms
#   2025-01-21 23:47:59 /static/gradient_bg.jpg ...................... ~ 0.15ms
#   2025-01-21 23:47:59 /favicon.ico ................................. ~ 0.20ms

# %%
! vendor/bin/codecept run
# Out:
# /usr/bin/sh: 1: vendor/bin/codecept: not found

# %% [markdown]
# Edit the code:

# %%
! phpstorm .
# Out:
# Process "/usr/lib/jvm/java-21-openjdk-amd64/bin/java" (668) is still running.
# If the process is an instance of the IDE, please collect the logs and contact support.
# If it isn't, please delete the stale "/home/student/.config/JetBrains/PhpStorm2024.2/.lock" file and restart the IDE.

# %% [markdown]
# Stop the services:

# %%
! killall php php8.3

# %%
seleniumServer.kill()

# %%
# %cd ..
# Out:
# /home/student/Desktop/php_2024_iad_rocksa/rocksa

# %% [markdown]
# Stop database:

# %%
! docker container stop mysql
# Out:
# mysql
